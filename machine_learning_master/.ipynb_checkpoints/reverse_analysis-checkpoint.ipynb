# %%
## 必要なライブラリのimport
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Dense, Flatten
from keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
## データについて

### データファイルのpath
no_hole_path = './../vibration_simulation/vibration_data/no_hole_data.csv'
one_hole_path = './../vibration_simulation/vibration_data/one_hole_data.csv'
four_holes_path = './../vibration_simulation/vibration_data/four_holes_data.csv'
nine_holes_path = './../vibration_simulation/vibration_data/nine_holes_data.csv'
sixteen_holes_path = './../vibration_simulation/vibration_data/sixteen_holes_data.csv'
twentyfive_holes_path = './../vibration_simulation/vibration_data/twentyfive_holes_data.csv'

### 入力データと正解データ
no_hole_data1 = []
no_hole_data2 = []
no_hole_data3 = []
size_x_data = []
size_x_data1 = []
size_x_data2 = []
size_x_data3 = []
size_y_data = []
position_x_data = []
position_x_data1 = []
position_x_data2 = []
position_x_data3 = []
position_one_data1 = []
position_one_data2 = []
position_one_data3 = []
position_two_data1 = []
position_two_data2 = []
position_two_data3 = []
position_three_data1 = []
position_three_data2 = []
position_three_data3 = []
position_four_data1 = []
position_four_data2 = []
position_four_data3 = []
position_five_data1 = []
position_five_data2 = []
position_five_data3 = []
position_y_data = []

### ファイル読み込み

#### 欠陥がない場合のデータ
with open(no_hole_path) as f:
    for line in f:
        data_array = line.split(' ')
        no_hole_data1 = data_array[0:1251]
        no_hole_data2 = data_array[1251:2502]
        no_hole_data3 = data_array[2502:-1]
        
#### 大きさに関するデータ
with open(one_hole_path) as fs1:
  for line in fs1:
    data_array = line.split(' ')
    size_x_data1.append(data_array[3:1254])
    size_x_data2.append(data_array[1254:2505])
    size_x_data3.append(data_array[2505:-1])
    size_y_data.append(data_array[0])
with open(four_holes_path) as fs2:
  for line in fs2:
    data_array = line.split(' ')
    size_x_data1.append(data_array[3:1254])
    size_x_data2.append(data_array[1254:2505])
    size_x_data3.append(data_array[2505:-1])
    size_y_data.append(data_array[0])
with open(nine_holes_path) as fs3:
  for line in fs3:
    data_array = line.split(' ')
    size_x_data1.append(data_array[3:1254])
    size_x_data2.append(data_array[1254:2505])
    size_x_data3.append(data_array[2505:-1])
    size_y_data.append(data_array[0])
with open(sixteen_holes_path) as fs4:
  for line in fs4:
    data_array = line.split(' ')
    size_x_data1.append(data_array[3:1254])
    size_x_data2.append(data_array[1254:2505])
    size_x_data3.append(data_array[2505:-1])
    size_y_data.append(data_array[0])
with open(twentyfive_holes_path) as fs5:
  for line in fs5:
    data_array = line.split(' ')
    size_x_data1.append(data_array[3:1254])
    size_x_data2.append(data_array[1254:2505])
    size_x_data3.append(data_array[2505:-1])
    size_y_data.append(data_array[0])

#### 位置に関するデータ
with open(one_hole_path) as fp1:
  for line in fp1:
    data_array = line.split(' ')
    position_x_data1.append(data_array[3:1254])
    position_x_data2.append(data_array[1254:2505])
    position_x_data3.append(data_array[2505:-1])
    position_one_data1.append(data_array[3:1254])
    position_one_data2.append(data_array[1254:2505])
    position_one_data3.append(data_array[2505:-1])
    position_y_data.append(data_array[1:3])
with open(four_holes_path) as fp2:
  for line in fp2:
    data_array = line.split(' ')
    position_x_data1.append(data_array[3:1254])
    position_x_data2.append(data_array[1254:2505])
    position_x_data3.append(data_array[2505:-1])
    position_two_data1.append(data_array[3:1254])
    position_two_data2.append(data_array[1254:2505])
    position_two_data3.append(data_array[2505:-1])
    position_y_data.append(data_array[1:3])
with open(nine_holes_path) as fp3:
  for line in fp3:
    data_array = line.split(' ')
    position_x_data1.append(data_array[3:1254])
    position_x_data2.append(data_array[1254:2505])
    position_x_data3.append(data_array[2505:-1])
    position_three_data1.append(data_array[3:1254])
    position_three_data2.append(data_array[1254:2505])
    position_three_data3.append(data_array[2505:-1])
    position_y_data.append(data_array[1:3])
with open(sixteen_holes_path) as fp4:
  for line in fp4:
    data_array = line.split(' ')
    position_x_data1.append(data_array[3:1254])
    position_x_data2.append(data_array[1254:2505])
    position_x_data3.append(data_array[2505:-1])
    position_four_data1.append(data_array[3:1254])
    position_four_data2.append(data_array[1254:2505])
    position_four_data3.append(data_array[2505:-1])
    position_y_data.append(data_array[1:3])
with open(twentyfive_holes_path) as fp5:
  for line in fp5:
    data_array = line.split(' ')
    position_x_data1.append(data_array[3:1254])
    position_x_data2.append(data_array[1254:2505])
    position_x_data3.append(data_array[2505:-1])
    position_five_data1.append(data_array[3:1254])
    position_five_data2.append(data_array[1254:2505])
    position_five_data3.append(data_array[2505:-1])
    position_y_data.append(data_array[1:3])

### 各配列をnp.array型にして各要素を型変換
no_hole_data1 = np.array(no_hole_data1, dtype=float)
no_hole_data2 = np.array(no_hole_data2, dtype=float)
no_hole_data3 = np.array(no_hole_data3, dtype=float)
size_x_data1 = np.array(size_x_data1, dtype=float)
size_x_data2 = np.array(size_x_data2, dtype=float)
size_x_data3 = np.array(size_x_data3, dtype=float)
size_y_data = np.array(size_y_data, dtype=int)
position_x_data1 = np.array(position_x_data1, dtype=float)
position_x_data2 = np.array(position_x_data2, dtype=float)
position_x_data3 = np.array(position_x_data3, dtype=float)
position_one_data1 = np.array(position_one_data1, dtype=float)
position_two_data1 = np.array(position_two_data1, dtype=float)
position_three_data1 = np.array(position_three_data1, dtype=float)
position_four_data1 = np.array(position_four_data1, dtype=float)
position_five_data1 = np.array(position_five_data1, dtype=float)
position_one_data2 = np.array(position_one_data2, dtype=float)
position_two_data2 = np.array(position_two_data2, dtype=float)
position_three_data2 = np.array(position_three_data2, dtype=float)
position_four_data2 = np.array(position_four_data2, dtype=float)
position_five_data2 = np.array(position_five_data2, dtype=float)
position_one_data3 = np.array(position_one_data3, dtype=float)
position_two_data3 = np.array(position_two_data3, dtype=float)
position_three_data3 = np.array(position_three_data3, dtype=float)
position_four_data3 = np.array(position_four_data3, dtype=float)
position_five_data3 = np.array(position_five_data3, dtype=float)
position_y_data = np.array(position_y_data, dtype=float)

### データの加工
# 最大値で割る
max_displacement = size_x_data2.max()
size_x_data1 = size_x_data1/max_displacement
size_x_data2 = size_x_data2/max_displacement
size_x_data3 = size_x_data3/max_displacement
position_x_data1 = position_x_data1/max_displacement
position_x_data2 = position_x_data2/max_displacement
position_x_data3 = position_x_data3/max_displacement
position_one_data1 = position_one_data1/max_displacement
position_one_data2 = position_one_data2/max_displacement
position_one_data3 = position_one_data3/max_displacement
position_two_data1 = position_two_data1/max_displacement
position_two_data2 = position_two_data2/max_displacement
position_two_data3 = position_two_data3/max_displacement
position_three_data1 = position_three_data1/max_displacement
position_three_data2 = position_three_data2/max_displacement
position_three_data3 = position_three_data3/max_displacement
position_four_data1 = position_four_data1/max_displacement
position_four_data2 = position_four_data2/max_displacement
position_four_data3 = position_four_data3/max_displacement
position_five_data1 = position_five_data1/max_displacement
position_five_data2 = position_five_data2/max_displacement
position_five_data3 = position_five_data3/max_displacement

# 実験2:差をとると精度が向上するか
# size_x_data = (size_x_data-no_hole_data)
# position_x_data = (position_x_data-no_hole_data)

# position_one_data = (position_one_data-no_hole_data)
# position_two_data = (position_two_data-no_hole_data)
# position_three_data = (position_three_data-no_hole_data)
# position_four_data = (position_four_data-no_hole_data)
# position_five_data = (position_five_data-no_hole_data)
position_y_data = position_y_data/50

### train用とtest用に分割(4:1)
size_x_train1, size_x_test1, size_x_train2, size_x_test2, size_x_train3, size_x_test3, size_y_train, size_y_test = train_test_split(size_x_data1, size_x_data2, size_x_data3, size_y_data, test_size=0.20)
position_x_train1, position_x_test1, position_x_train2, position_x_test2, position_x_train3, position_x_test3, position_y_train, position_y_test = train_test_split(position_x_data1, position_x_data2, position_x_data3, position_y_data, test_size=0.20)

# %%
print(size_x_train1.shape)
print(size_x_test1.shape)
print(position_five_data1.shape)
print(position_four_data1.shape)
print(position_three_data1.shape)
print(position_two_data1.shape)
print(position_one_data1.shape)
# Out:
# (2155, 1251)
# (539, 1251)
# (484, 1251)
# (529, 1251)
# (529, 1251)
# (576, 1251)
# (576, 1251)

# %%
### reshape(数を見て修正する必要あり)
size_x_train = size_x_train.reshape(8108, 50, 1)
size_x_test = size_x_test.reshape(2027, 50, 1)
position_x_train = position_x_train.reshape(8108, 50, 1)
position_x_test = position_x_test.reshape(2027, 50, 1)

# %%
#単純モデル
# import
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, concatenate, Dense
from tensorflow.keras.models import Model
from tensorflow.python.keras.utils.vis_utils import plot_model

# 入力を定義
input1 = Input(shape=(1251,))
input2 = Input(shape=(1251,))
input3 = Input(shape=(1251,))

# 入力1から結合前まで
x = Dense(1, activation="linear")(input1)
x = Model(inputs=input1, outputs=x)
# 入力2から結合前まで
y = Dense(1, activation="linear")(input2)
y = Model(inputs=input2, outputs=y)
# 入力3から結合前まで
z = Dense(1, activation="linear")(input3)
z = Model(inputs=input3, outputs=z)

# 結合
combined = concatenate([x.output, y.output, z.output])

# 密結合
w = Dense(32, activation="tanh")(combined)
w = Dense(1, activation="linear")(w)

# モデル定義とコンパイル
model = Model(inputs=[x.input, y.input, z.input], outputs=w)
model.compile(loss='mse', optimizer='adam', metrics=['acc'])
model.summary()
plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 1251)]       0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 1251)]       0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 1251)]       0
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            1252        input_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            1252        input_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            1252        input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3)            0           dense_5[0][0]
#                                                                  dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 32)           128         concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            33          dense_8[0][0]
# ==================================================================================================
# Total params: 3,917
# Trainable params: 3,917
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# CNNモデルで大きさ推定
# import
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, concatenate, Dense
from tensorflow.keras.models import Model
from tensorflow.python.keras.utils.vis_utils import plot_model

# 入力を定義
input1 = Input(shape=(1251,1))
input2 = Input(shape=(1251,1))
input3 = Input(shape=(1251,1))

# 入力1から結合前まで
x = Conv1D(32, 3, padding='same', activation='tanh')(input1)
x = MaxPooling1D(2, padding='same')(x)
x = Model(inputs=input1, outputs=x)
# 入力2から結合前まで
y = Conv1D(32, 3, padding='same', activation='tanh')(input2)
y = MaxPooling1D(2, padding='same')(y)
y = Model(inputs=input2, outputs=y)
# 入力3から結合前まで
z = Conv1D(32, 3, padding='same', activation='tanh')(input3)
z = MaxPooling1D(2, padding='same')(z)
z = Model(inputs=input3, outputs=z)

# 結合
combined = concatenate([x.output, y.output, z.output])

# 密結合
cnn = Flatten()(combined)
cnn = Dense(1, activation="linear")(cnn)

# モデル定義とコンパイル
cnn_size_model = Model(inputs=[x.input, y.input, z.input], outputs=cnn)
cnn_size_model.compile(loss='mse', optimizer='adam', metrics=['acc'])
cnn_size_model.summary()
plot_model(cnn_size_model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "model_35"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_25 (InputLayer)           [(None, 1251, 1)]    0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, 1251, 1)]    0
# __________________________________________________________________________________________________
# input_27 (InputLayer)           [(None, 1251, 1)]    0
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 1251, 32)     128         input_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1251, 32)     128         input_26[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1251, 32)     128         input_27[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 626, 32)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 626, 32)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 626, 32)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 626, 96)      0           max_pooling1d_6[0][0]
#                                                                  max_pooling1d_7[0][0]
#                                                                  max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 60096)        0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1)            60097       flatten_2[0][0]
# ==================================================================================================
# Total params: 60,481
# Trainable params: 60,481
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
size_history = cnn_size_model.fit([size_x_train1, size_x_train2, size_x_train3], size_y_train, epochs=1000, validation_data=([size_x_test1,size_x_test2,size_x_test3], size_y_test))
# Out:
# Epoch 1/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 2.5179 - acc: 0.2056 - val_loss: 1.9836 - val_acc: 0.2263
# Epoch 2/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 1.9872 - acc: 0.2107 - val_loss: 2.0170 - val_acc: 0.2263
# Epoch 3/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 1.9386 - acc: 0.2107 - val_loss: 1.9367 - val_acc: 0.2263
# Epoch 4/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 1.8929 - acc: 0.2107 - val_loss: 1.8764 - val_acc: 0.2263
# Epoch 5/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.8809 - acc: 0.2107 - val_loss: 1.9658 - val_acc: 0.2263
# Epoch 6/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.8222 - acc: 0.2107 - val_loss: 1.9873 - val_acc: 0.2263
# Epoch 7/1000
# 68/68 [==============================] - 3s 41ms/step - loss: 1.7991 - acc: 0.2107 - val_loss: 1.7664 - val_acc: 0.2263
# Epoch 8/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 1.7475 - acc: 0.2107 - val_loss: 1.8647 - val_acc: 0.2263
# Epoch 9/1000
# 68/68 [==============================] - 3s 40ms/step - loss: 1.7347 - acc: 0.2107 - val_loss: 1.7092 - val_acc: 0.2263
# Epoch 10/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 1.7073 - acc: 0.2107 - val_loss: 1.7277 - val_acc: 0.2263
# Epoch 11/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.7024 - acc: 0.2107 - val_loss: 1.6542 - val_acc: 0.2263
# Epoch 12/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.6365 - acc: 0.2107 - val_loss: 1.8019 - val_acc: 0.2263
# Epoch 13/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.6324 - acc: 0.2107 - val_loss: 1.6361 - val_acc: 0.2263
# Epoch 14/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.5877 - acc: 0.2107 - val_loss: 1.6130 - val_acc: 0.2263
# Epoch 15/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.5407 - acc: 0.2107 - val_loss: 1.6085 - val_acc: 0.2263
# Epoch 16/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.5461 - acc: 0.2107 - val_loss: 1.5151 - val_acc: 0.2263
# Epoch 17/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.5196 - acc: 0.2107 - val_loss: 1.4969 - val_acc: 0.2263
# Epoch 18/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.4732 - acc: 0.2107 - val_loss: 1.5142 - val_acc: 0.2263
# Epoch 19/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.4578 - acc: 0.2107 - val_loss: 1.5786 - val_acc: 0.2263
# Epoch 20/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.4270 - acc: 0.2107 - val_loss: 1.4932 - val_acc: 0.2263
# Epoch 21/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.4124 - acc: 0.2107 - val_loss: 1.4037 - val_acc: 0.2263
# Epoch 22/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 1.3938 - acc: 0.2107 - val_loss: 1.5756 - val_acc: 0.2263
# Epoch 23/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.3520 - acc: 0.2107 - val_loss: 1.4095 - val_acc: 0.2263
# Epoch 24/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.3251 - acc: 0.2107 - val_loss: 1.5247 - val_acc: 0.2263
# Epoch 25/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.4048 - acc: 0.2107 - val_loss: 1.3210 - val_acc: 0.2263
# Epoch 26/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.2942 - acc: 0.2107 - val_loss: 1.7904 - val_acc: 0.2263
# Epoch 27/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 1.2837 - acc: 0.2107 - val_loss: 1.2872 - val_acc: 0.2263
# Epoch 28/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.2919 - acc: 0.2107 - val_loss: 1.4073 - val_acc: 0.2263
# Epoch 29/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.2617 - acc: 0.2107 - val_loss: 1.2330 - val_acc: 0.2263
# Epoch 30/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.2581 - acc: 0.2107 - val_loss: 1.2583 - val_acc: 0.2263
# Epoch 31/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.2166 - acc: 0.2107 - val_loss: 1.2506 - val_acc: 0.2263
# Epoch 32/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.1854 - acc: 0.2107 - val_loss: 1.3237 - val_acc: 0.2263
# Epoch 33/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.2016 - acc: 0.2107 - val_loss: 1.3996 - val_acc: 0.2263
# Epoch 34/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 1.1810 - acc: 0.2107 - val_loss: 1.1986 - val_acc: 0.2263
# Epoch 35/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.1461 - acc: 0.2107 - val_loss: 1.4701 - val_acc: 0.2263
# Epoch 36/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.2029 - acc: 0.2107 - val_loss: 1.1579 - val_acc: 0.2263
# Epoch 37/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.1306 - acc: 0.2107 - val_loss: 1.3566 - val_acc: 0.2263
# Epoch 38/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.1493 - acc: 0.2107 - val_loss: 1.2818 - val_acc: 0.2263
# Epoch 39/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.2035 - acc: 0.2107 - val_loss: 1.5863 - val_acc: 0.2263
# Epoch 40/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.1439 - acc: 0.2107 - val_loss: 1.1707 - val_acc: 0.2263
# Epoch 41/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.1535 - acc: 0.2107 - val_loss: 1.4126 - val_acc: 0.2263
# Epoch 42/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.0769 - acc: 0.2107 - val_loss: 1.0651 - val_acc: 0.2263
# Epoch 43/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 1.0557 - acc: 0.2107 - val_loss: 1.2288 - val_acc: 0.2263
# Epoch 44/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 1.1151 - acc: 0.2107 - val_loss: 1.6779 - val_acc: 0.2263
# Epoch 45/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.1023 - acc: 0.2107 - val_loss: 1.1628 - val_acc: 0.2263
# Epoch 46/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.1511 - acc: 0.2107 - val_loss: 1.1474 - val_acc: 0.2263
# Epoch 47/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 1.0536 - acc: 0.2107 - val_loss: 1.1478 - val_acc: 0.2263
# Epoch 48/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.1195 - acc: 0.2107 - val_loss: 1.2067 - val_acc: 0.2263
# Epoch 49/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.0479 - acc: 0.2107 - val_loss: 1.2304 - val_acc: 0.2263
# Epoch 50/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.0777 - acc: 0.2107 - val_loss: 1.0486 - val_acc: 0.2263
# Epoch 51/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 1.0041 - acc: 0.2107 - val_loss: 1.0111 - val_acc: 0.2263
# Epoch 52/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 1.0222 - acc: 0.2107 - val_loss: 1.1571 - val_acc: 0.2263
# Epoch 53/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 1.0584 - acc: 0.2107 - val_loss: 1.0459 - val_acc: 0.2263
# Epoch 54/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.9922 - acc: 0.2107 - val_loss: 1.1670 - val_acc: 0.2263
# Epoch 55/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 0.9677 - acc: 0.2107 - val_loss: 0.9555 - val_acc: 0.2263
# Epoch 56/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.9895 - acc: 0.2107 - val_loss: 1.0289 - val_acc: 0.2263
# Epoch 57/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.9842 - acc: 0.2107 - val_loss: 1.0468 - val_acc: 0.2263
# Epoch 58/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.9809 - acc: 0.2107 - val_loss: 1.2659 - val_acc: 0.2263
# Epoch 59/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.1078 - acc: 0.2107 - val_loss: 1.0409 - val_acc: 0.2263
# Epoch 60/1000
# 68/68 [==============================] - 3s 46ms/step - loss: 1.0736 - acc: 0.2107 - val_loss: 1.0505 - val_acc: 0.2263
# Epoch 61/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 1.3136 - acc: 0.2107 - val_loss: 1.1346 - val_acc: 0.2263
# Epoch 62/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 1.0008 - acc: 0.2107 - val_loss: 1.4359 - val_acc: 0.2263
# Epoch 63/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.9657 - acc: 0.2107 - val_loss: 1.1630 - val_acc: 0.2263
# Epoch 64/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.9644 - acc: 0.2107 - val_loss: 0.9756 - val_acc: 0.2263
# Epoch 65/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.9647 - acc: 0.2107 - val_loss: 0.9966 - val_acc: 0.2263
# Epoch 66/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.9122 - acc: 0.2107 - val_loss: 0.9434 - val_acc: 0.2263
# Epoch 67/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.9160 - acc: 0.2107 - val_loss: 0.9312 - val_acc: 0.2263
# Epoch 68/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.9286 - acc: 0.2107 - val_loss: 0.9063 - val_acc: 0.2263
# Epoch 69/1000
# 68/68 [==============================] - 480s 7s/step - loss: 0.9023 - acc: 0.2107 - val_loss: 1.0335 - val_acc: 0.2263
# Epoch 70/1000
# 68/68 [==============================] - 4s 61ms/step - loss: 0.9026 - acc: 0.2107 - val_loss: 0.9201 - val_acc: 0.2263
# Epoch 71/1000
# 68/68 [==============================] - 3s 48ms/step - loss: 0.9193 - acc: 0.2107 - val_loss: 0.9239 - val_acc: 0.2263
# Epoch 72/1000
# 68/68 [==============================] - 3s 45ms/step - loss: 0.9164 - acc: 0.2107 - val_loss: 0.9329 - val_acc: 0.2263
# Epoch 73/1000
# 68/68 [==============================] - 3s 44ms/step - loss: 0.9416 - acc: 0.2107 - val_loss: 0.9242 - val_acc: 0.2263
# Epoch 74/1000
# 68/68 [==============================] - 3s 42ms/step - loss: 0.9245 - acc: 0.2107 - val_loss: 0.9362 - val_acc: 0.2263
# Epoch 75/1000
# 68/68 [==============================] - 3s 40ms/step - loss: 0.9017 - acc: 0.2107 - val_loss: 0.9520 - val_acc: 0.2263
# Epoch 76/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.9174 - acc: 0.2107 - val_loss: 1.5050 - val_acc: 0.2263
# Epoch 77/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.9599 - acc: 0.2107 - val_loss: 1.1523 - val_acc: 0.2263
# Epoch 78/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.9075 - acc: 0.2107 - val_loss: 1.3690 - val_acc: 0.2263
# Epoch 79/1000
# 68/68 [==============================] - 3s 41ms/step - loss: 0.8926 - acc: 0.2107 - val_loss: 0.8938 - val_acc: 0.2263
# Epoch 80/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 1.1803 - acc: 0.2107 - val_loss: 1.8158 - val_acc: 0.2263
# Epoch 81/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 1.0341 - acc: 0.2107 - val_loss: 0.9321 - val_acc: 0.2263
# Epoch 82/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.8863 - acc: 0.2107 - val_loss: 1.0008 - val_acc: 0.2263
# Epoch 83/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.8757 - acc: 0.2107 - val_loss: 0.9023 - val_acc: 0.2263
# Epoch 84/1000
# 68/68 [==============================] - 3s 42ms/step - loss: 0.8617 - acc: 0.2107 - val_loss: 0.8758 - val_acc: 0.2263
# Epoch 85/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.8471 - acc: 0.2107 - val_loss: 0.8867 - val_acc: 0.2263
# Epoch 86/1000
# 68/68 [==============================] - 4s 55ms/step - loss: 0.8584 - acc: 0.2107 - val_loss: 0.8289 - val_acc: 0.2263
# Epoch 87/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.8548 - acc: 0.2107 - val_loss: 0.8764 - val_acc: 0.2263
# Epoch 88/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.8345 - acc: 0.2107 - val_loss: 0.8827 - val_acc: 0.2263
# Epoch 89/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.8510 - acc: 0.2102 - val_loss: 0.8208 - val_acc: 0.2263
# Epoch 90/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.9087 - acc: 0.2102 - val_loss: 0.9439 - val_acc: 0.2263
# Epoch 91/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.9025 - acc: 0.2107 - val_loss: 0.8754 - val_acc: 0.2263
# Epoch 92/1000
# 68/68 [==============================] - 3s 46ms/step - loss: 0.9531 - acc: 0.2102 - val_loss: 0.9358 - val_acc: 0.2263
# Epoch 93/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.8110 - acc: 0.2102 - val_loss: 0.8211 - val_acc: 0.2263
# Epoch 94/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.8215 - acc: 0.2107 - val_loss: 0.8623 - val_acc: 0.2263
# Epoch 95/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.8317 - acc: 0.2107 - val_loss: 0.8773 - val_acc: 0.2263
# Epoch 96/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.8573 - acc: 0.2102 - val_loss: 0.9689 - val_acc: 0.2263
# Epoch 97/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.8243 - acc: 0.2102 - val_loss: 0.8529 - val_acc: 0.2263
# Epoch 98/1000
# 68/68 [==============================] - 3s 42ms/step - loss: 0.8086 - acc: 0.2107 - val_loss: 1.0380 - val_acc: 0.2263
# Epoch 99/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.8518 - acc: 0.2102 - val_loss: 1.1081 - val_acc: 0.2263
# Epoch 100/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.8503 - acc: 0.2102 - val_loss: 0.8938 - val_acc: 0.2263
# Epoch 101/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8205 - acc: 0.2102 - val_loss: 0.8590 - val_acc: 0.2263
# Epoch 102/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.8043 - acc: 0.2102 - val_loss: 0.7957 - val_acc: 0.2263
# Epoch 103/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8215 - acc: 0.2107 - val_loss: 0.9221 - val_acc: 0.2263
# Epoch 104/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.8652 - acc: 0.2102 - val_loss: 0.8278 - val_acc: 0.2263
# Epoch 105/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7906 - acc: 0.2102 - val_loss: 1.0325 - val_acc: 0.2263
# Epoch 106/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.8572 - acc: 0.2102 - val_loss: 0.9182 - val_acc: 0.2263
# Epoch 107/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.8943 - acc: 0.2107 - val_loss: 0.9898 - val_acc: 0.2263
# Epoch 108/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.8613 - acc: 0.2102 - val_loss: 0.8759 - val_acc: 0.2263
# Epoch 109/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.8329 - acc: 0.2102 - val_loss: 0.8808 - val_acc: 0.2263
# Epoch 110/1000
# 68/68 [==============================] - 3s 41ms/step - loss: 0.8485 - acc: 0.2102 - val_loss: 0.9089 - val_acc: 0.2263
# Epoch 111/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.8854 - acc: 0.2102 - val_loss: 1.5743 - val_acc: 0.2245
# Epoch 112/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.9875 - acc: 0.2107 - val_loss: 1.1617 - val_acc: 0.2263
# Epoch 113/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.8372 - acc: 0.2107 - val_loss: 0.9204 - val_acc: 0.2263
# Epoch 114/1000
# 68/68 [==============================] - 3s 41ms/step - loss: 0.8140 - acc: 0.2107 - val_loss: 0.8181 - val_acc: 0.2263
# Epoch 115/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.7843 - acc: 0.2102 - val_loss: 0.7756 - val_acc: 0.2263
# Epoch 116/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7664 - acc: 0.2102 - val_loss: 0.8164 - val_acc: 0.2263
# Epoch 117/1000
# 68/68 [==============================] - 3s 40ms/step - loss: 0.7647 - acc: 0.2102 - val_loss: 0.7547 - val_acc: 0.2263
# Epoch 118/1000
# 68/68 [==============================] - 3s 42ms/step - loss: 0.8129 - acc: 0.2102 - val_loss: 0.8116 - val_acc: 0.2263
# Epoch 119/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7683 - acc: 0.2102 - val_loss: 0.7474 - val_acc: 0.2263
# Epoch 120/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.7364 - acc: 0.2102 - val_loss: 0.9666 - val_acc: 0.2263
# Epoch 121/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.7933 - acc: 0.2102 - val_loss: 1.1458 - val_acc: 0.2263
# Epoch 122/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.8241 - acc: 0.2102 - val_loss: 0.8471 - val_acc: 0.2263
# Epoch 123/1000
# 68/68 [==============================] - 3s 41ms/step - loss: 0.7689 - acc: 0.2097 - val_loss: 0.7552 - val_acc: 0.2263
# Epoch 124/1000
# 68/68 [==============================] - 3s 46ms/step - loss: 0.8801 - acc: 0.2102 - val_loss: 0.8135 - val_acc: 0.2263
# Epoch 125/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.7750 - acc: 0.2102 - val_loss: 0.7531 - val_acc: 0.2263
# Epoch 126/1000
# 68/68 [==============================] - 3s 40ms/step - loss: 0.8153 - acc: 0.2097 - val_loss: 0.9103 - val_acc: 0.2263
# Epoch 127/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8067 - acc: 0.2102 - val_loss: 0.8859 - val_acc: 0.2263
# Epoch 128/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7961 - acc: 0.2102 - val_loss: 0.7995 - val_acc: 0.2263
# Epoch 129/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8375 - acc: 0.2097 - val_loss: 0.7827 - val_acc: 0.2263
# Epoch 130/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7671 - acc: 0.2102 - val_loss: 0.8366 - val_acc: 0.2263
# Epoch 131/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7679 - acc: 0.2102 - val_loss: 0.7305 - val_acc: 0.2263
# Epoch 132/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7310 - acc: 0.2102 - val_loss: 0.7844 - val_acc: 0.2263
# Epoch 133/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7603 - acc: 0.2102 - val_loss: 1.0093 - val_acc: 0.2263
# Epoch 134/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7868 - acc: 0.2097 - val_loss: 0.8930 - val_acc: 0.2263
# Epoch 135/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7801 - acc: 0.2097 - val_loss: 1.6059 - val_acc: 0.2263
# Epoch 136/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8356 - acc: 0.2093 - val_loss: 0.7420 - val_acc: 0.2263
# Epoch 137/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7282 - acc: 0.2102 - val_loss: 0.8489 - val_acc: 0.2263
# Epoch 138/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7766 - acc: 0.2102 - val_loss: 0.8033 - val_acc: 0.2263
# Epoch 139/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7200 - acc: 0.2102 - val_loss: 0.9928 - val_acc: 0.2263
# Epoch 140/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8350 - acc: 0.2097 - val_loss: 0.8098 - val_acc: 0.2263
# Epoch 141/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.8167 - acc: 0.2097 - val_loss: 0.7228 - val_acc: 0.2263
# Epoch 142/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8042 - acc: 0.2102 - val_loss: 1.0177 - val_acc: 0.2263
# Epoch 143/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8758 - acc: 0.2097 - val_loss: 0.7354 - val_acc: 0.2263
# Epoch 144/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7742 - acc: 0.2102 - val_loss: 0.9550 - val_acc: 0.2263
# Epoch 145/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8581 - acc: 0.2102 - val_loss: 0.9330 - val_acc: 0.2263
# Epoch 146/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7713 - acc: 0.2102 - val_loss: 0.8566 - val_acc: 0.2263
# Epoch 147/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8332 - acc: 0.2097 - val_loss: 1.7548 - val_acc: 0.2263
# Epoch 148/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.8774 - acc: 0.2102 - val_loss: 1.3085 - val_acc: 0.2263
# Epoch 149/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7847 - acc: 0.2097 - val_loss: 0.9070 - val_acc: 0.2263
# Epoch 150/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.7136 - acc: 0.2102 - val_loss: 0.7674 - val_acc: 0.2263
# Epoch 151/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7449 - acc: 0.2102 - val_loss: 0.7014 - val_acc: 0.2263
# Epoch 152/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7235 - acc: 0.2102 - val_loss: 0.7318 - val_acc: 0.2263
# Epoch 153/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7321 - acc: 0.2097 - val_loss: 0.7383 - val_acc: 0.2263
# Epoch 154/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7270 - acc: 0.2097 - val_loss: 0.7866 - val_acc: 0.2263
# Epoch 155/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7151 - acc: 0.2097 - val_loss: 0.8200 - val_acc: 0.2263
# Epoch 156/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7877 - acc: 0.2102 - val_loss: 0.7483 - val_acc: 0.2263
# Epoch 157/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7343 - acc: 0.2102 - val_loss: 0.7315 - val_acc: 0.2263
# Epoch 158/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7529 - acc: 0.2102 - val_loss: 0.8186 - val_acc: 0.2263
# Epoch 159/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7640 - acc: 0.2102 - val_loss: 1.0147 - val_acc: 0.2263
# Epoch 160/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.8008 - acc: 0.2097 - val_loss: 0.8343 - val_acc: 0.2263
# Epoch 161/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7254 - acc: 0.2097 - val_loss: 0.8670 - val_acc: 0.2263
# Epoch 162/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.7111 - acc: 0.2102 - val_loss: 0.7079 - val_acc: 0.2263
# Epoch 163/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.8321 - acc: 0.2097 - val_loss: 1.0895 - val_acc: 0.2263
# Epoch 164/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7548 - acc: 0.2102 - val_loss: 0.7120 - val_acc: 0.2263
# Epoch 165/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7409 - acc: 0.2097 - val_loss: 0.8053 - val_acc: 0.2263
# Epoch 166/1000
# 68/68 [==============================] - 3s 47ms/step - loss: 0.7736 - acc: 0.2102 - val_loss: 1.0478 - val_acc: 0.2263
# Epoch 167/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.8383 - acc: 0.2102 - val_loss: 0.6842 - val_acc: 0.2263
# Epoch 168/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.7982 - acc: 0.2093 - val_loss: 0.8090 - val_acc: 0.2263
# Epoch 169/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7354 - acc: 0.2102 - val_loss: 0.7032 - val_acc: 0.2263
# Epoch 170/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7117 - acc: 0.2097 - val_loss: 1.3555 - val_acc: 0.2263
# Epoch 171/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7537 - acc: 0.2102 - val_loss: 0.6713 - val_acc: 0.2263
# Epoch 172/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7150 - acc: 0.2097 - val_loss: 0.7381 - val_acc: 0.2263
# Epoch 173/1000
# 68/68 [==============================] - 3s 41ms/step - loss: 0.7147 - acc: 0.2102 - val_loss: 0.7341 - val_acc: 0.2263
# Epoch 174/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.7486 - acc: 0.2102 - val_loss: 0.7039 - val_acc: 0.2263
# Epoch 175/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7507 - acc: 0.2097 - val_loss: 1.0370 - val_acc: 0.2263
# Epoch 176/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7441 - acc: 0.2097 - val_loss: 0.7607 - val_acc: 0.2263
# Epoch 177/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7186 - acc: 0.2102 - val_loss: 0.7357 - val_acc: 0.2263
# Epoch 178/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7655 - acc: 0.2102 - val_loss: 1.3016 - val_acc: 0.2263
# Epoch 179/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7137 - acc: 0.2102 - val_loss: 0.8905 - val_acc: 0.2263
# Epoch 180/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7453 - acc: 0.2102 - val_loss: 1.3145 - val_acc: 0.2263
# Epoch 181/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7931 - acc: 0.2097 - val_loss: 0.7593 - val_acc: 0.2263
# Epoch 182/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7257 - acc: 0.2097 - val_loss: 1.3059 - val_acc: 0.2263
# Epoch 183/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7058 - acc: 0.2097 - val_loss: 0.8267 - val_acc: 0.2263
# Epoch 184/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6859 - acc: 0.2102 - val_loss: 0.6688 - val_acc: 0.2263
# Epoch 185/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6560 - acc: 0.2097 - val_loss: 0.6912 - val_acc: 0.2263
# Epoch 186/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6643 - acc: 0.2102 - val_loss: 1.0069 - val_acc: 0.2263
# Epoch 187/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6979 - acc: 0.2102 - val_loss: 0.9701 - val_acc: 0.2263
# Epoch 188/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.7560 - acc: 0.2097 - val_loss: 0.6808 - val_acc: 0.2263
# Epoch 189/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7052 - acc: 0.2102 - val_loss: 0.8834 - val_acc: 0.2263
# Epoch 190/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.7533 - acc: 0.2093 - val_loss: 0.6612 - val_acc: 0.2263
# Epoch 191/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6685 - acc: 0.2097 - val_loss: 0.6683 - val_acc: 0.2263
# Epoch 192/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.7402 - acc: 0.2102 - val_loss: 0.6506 - val_acc: 0.2263
# Epoch 193/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6653 - acc: 0.2097 - val_loss: 0.7174 - val_acc: 0.2263
# Epoch 194/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7720 - acc: 0.2102 - val_loss: 0.7645 - val_acc: 0.2263
# Epoch 195/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.7096 - acc: 0.2097 - val_loss: 0.6969 - val_acc: 0.2263
# Epoch 196/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.6731 - acc: 0.2102 - val_loss: 0.7276 - val_acc: 0.2263
# Epoch 197/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.7263 - acc: 0.2097 - val_loss: 0.7050 - val_acc: 0.2263
# Epoch 198/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.7028 - acc: 0.2097 - val_loss: 0.9197 - val_acc: 0.2263
# Epoch 199/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7068 - acc: 0.2102 - val_loss: 0.7073 - val_acc: 0.2263
# Epoch 200/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6556 - acc: 0.2097 - val_loss: 0.9370 - val_acc: 0.2263
# Epoch 201/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6978 - acc: 0.2097 - val_loss: 0.6599 - val_acc: 0.2263
# Epoch 202/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.6835 - acc: 0.2093 - val_loss: 0.7949 - val_acc: 0.2263
# Epoch 203/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6915 - acc: 0.2093 - val_loss: 0.9666 - val_acc: 0.2263
# Epoch 204/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7712 - acc: 0.2093 - val_loss: 2.7037 - val_acc: 0.2263
# Epoch 205/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.8214 - acc: 0.2093 - val_loss: 1.7112 - val_acc: 0.2263
# Epoch 206/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 0.9184 - acc: 0.2097 - val_loss: 1.4594 - val_acc: 0.2263
# Epoch 207/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.8177 - acc: 0.2097 - val_loss: 0.7802 - val_acc: 0.2263
# Epoch 208/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7503 - acc: 0.2102 - val_loss: 0.7712 - val_acc: 0.2263
# Epoch 209/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.7194 - acc: 0.2102 - val_loss: 0.6800 - val_acc: 0.2263
# Epoch 210/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 0.6424 - acc: 0.2102 - val_loss: 0.6405 - val_acc: 0.2263
# Epoch 211/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6883 - acc: 0.2097 - val_loss: 0.9243 - val_acc: 0.2263
# Epoch 212/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6830 - acc: 0.2102 - val_loss: 1.1966 - val_acc: 0.2263
# Epoch 213/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6946 - acc: 0.2097 - val_loss: 0.6552 - val_acc: 0.2263
# Epoch 214/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6632 - acc: 0.2097 - val_loss: 0.6453 - val_acc: 0.2263
# Epoch 215/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 0.7045 - acc: 0.2097 - val_loss: 0.8010 - val_acc: 0.2263
# Epoch 216/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6844 - acc: 0.2102 - val_loss: 0.6701 - val_acc: 0.2263
# Epoch 217/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6419 - acc: 0.2097 - val_loss: 0.7548 - val_acc: 0.2263
# Epoch 218/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6967 - acc: 0.2093 - val_loss: 0.6583 - val_acc: 0.2263
# Epoch 219/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.6330 - acc: 0.2102 - val_loss: 0.7431 - val_acc: 0.2263
# Epoch 220/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6339 - acc: 0.2102 - val_loss: 0.7960 - val_acc: 0.2263
# Epoch 221/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6674 - acc: 0.2097 - val_loss: 0.6933 - val_acc: 0.2263
# Epoch 222/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6827 - acc: 0.2097 - val_loss: 0.7610 - val_acc: 0.2263
# Epoch 223/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7179 - acc: 0.2093 - val_loss: 0.6929 - val_acc: 0.2263
# Epoch 224/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7279 - acc: 0.2093 - val_loss: 0.7979 - val_acc: 0.2263
# Epoch 225/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6672 - acc: 0.2102 - val_loss: 0.6197 - val_acc: 0.2263
# Epoch 226/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6485 - acc: 0.2097 - val_loss: 0.9429 - val_acc: 0.2263
# Epoch 227/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6633 - acc: 0.2102 - val_loss: 0.6775 - val_acc: 0.2263
# Epoch 228/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6683 - acc: 0.2088 - val_loss: 0.9652 - val_acc: 0.2263
# Epoch 229/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6910 - acc: 0.2088 - val_loss: 0.7835 - val_acc: 0.2263
# Epoch 230/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6518 - acc: 0.2097 - val_loss: 0.7063 - val_acc: 0.2263
# Epoch 231/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.6458 - acc: 0.2097 - val_loss: 0.7884 - val_acc: 0.2263
# Epoch 232/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7074 - acc: 0.2093 - val_loss: 0.7623 - val_acc: 0.2263
# Epoch 233/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6280 - acc: 0.2093 - val_loss: 0.6518 - val_acc: 0.2263
# Epoch 234/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7150 - acc: 0.2097 - val_loss: 0.6377 - val_acc: 0.2263
# Epoch 235/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7865 - acc: 0.2088 - val_loss: 0.6724 - val_acc: 0.2263
# Epoch 236/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7296 - acc: 0.2097 - val_loss: 0.6246 - val_acc: 0.2263
# Epoch 237/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7523 - acc: 0.2097 - val_loss: 0.8243 - val_acc: 0.2263
# Epoch 238/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6998 - acc: 0.2102 - val_loss: 0.7612 - val_acc: 0.2263
# Epoch 239/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6853 - acc: 0.2097 - val_loss: 0.6633 - val_acc: 0.2263
# Epoch 240/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 0.6885 - acc: 0.2102 - val_loss: 1.1017 - val_acc: 0.2263
# Epoch 241/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7463 - acc: 0.2084 - val_loss: 0.7955 - val_acc: 0.2263
# Epoch 242/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6684 - acc: 0.2093 - val_loss: 0.7541 - val_acc: 0.2263
# Epoch 243/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7085 - acc: 0.2102 - val_loss: 0.8925 - val_acc: 0.2263
# Epoch 244/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 0.6704 - acc: 0.2097 - val_loss: 0.7062 - val_acc: 0.2263
# Epoch 245/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6157 - acc: 0.2097 - val_loss: 0.6461 - val_acc: 0.2263
# Epoch 246/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6407 - acc: 0.2093 - val_loss: 0.6597 - val_acc: 0.2263
# Epoch 247/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6277 - acc: 0.2102 - val_loss: 0.8774 - val_acc: 0.2245
# Epoch 248/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.7131 - acc: 0.2093 - val_loss: 0.6229 - val_acc: 0.2263
# Epoch 249/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6244 - acc: 0.2093 - val_loss: 0.6127 - val_acc: 0.2263
# Epoch 250/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6135 - acc: 0.2102 - val_loss: 0.8290 - val_acc: 0.2263
# Epoch 251/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6209 - acc: 0.2097 - val_loss: 0.6573 - val_acc: 0.2263
# Epoch 252/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6599 - acc: 0.2097 - val_loss: 0.6189 - val_acc: 0.2263
# Epoch 253/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6337 - acc: 0.2093 - val_loss: 0.6891 - val_acc: 0.2263
# Epoch 254/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6040 - acc: 0.2093 - val_loss: 0.6548 - val_acc: 0.2263
# Epoch 255/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6640 - acc: 0.2097 - val_loss: 1.6903 - val_acc: 0.2263
# Epoch 256/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.8041 - acc: 0.2093 - val_loss: 1.0209 - val_acc: 0.2263
# Epoch 257/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6734 - acc: 0.2088 - val_loss: 1.1718 - val_acc: 0.2263
# Epoch 258/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6745 - acc: 0.2093 - val_loss: 1.3932 - val_acc: 0.2263
# Epoch 259/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6912 - acc: 0.2093 - val_loss: 1.4269 - val_acc: 0.2263
# Epoch 260/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6968 - acc: 0.2102 - val_loss: 0.8309 - val_acc: 0.2263
# Epoch 261/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6934 - acc: 0.2102 - val_loss: 0.8912 - val_acc: 0.2263
# Epoch 262/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6615 - acc: 0.2093 - val_loss: 0.7700 - val_acc: 0.2263
# Epoch 263/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6620 - acc: 0.2093 - val_loss: 0.9259 - val_acc: 0.2263
# Epoch 264/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6762 - acc: 0.2102 - val_loss: 0.6522 - val_acc: 0.2263
# Epoch 265/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6779 - acc: 0.2097 - val_loss: 1.3640 - val_acc: 0.2263
# Epoch 266/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7186 - acc: 0.2088 - val_loss: 0.8193 - val_acc: 0.2263
# Epoch 267/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6355 - acc: 0.2097 - val_loss: 0.8516 - val_acc: 0.2263
# Epoch 268/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6280 - acc: 0.2102 - val_loss: 0.7083 - val_acc: 0.2263
# Epoch 269/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6596 - acc: 0.2097 - val_loss: 0.6094 - val_acc: 0.2263
# Epoch 270/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6239 - acc: 0.2097 - val_loss: 0.6357 - val_acc: 0.2263
# Epoch 271/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6375 - acc: 0.2102 - val_loss: 0.6037 - val_acc: 0.2263
# Epoch 272/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5966 - acc: 0.2093 - val_loss: 0.6936 - val_acc: 0.2263
# Epoch 273/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6516 - acc: 0.2102 - val_loss: 0.6216 - val_acc: 0.2263
# Epoch 274/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6151 - acc: 0.2093 - val_loss: 0.7104 - val_acc: 0.2263
# Epoch 275/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6205 - acc: 0.2097 - val_loss: 1.0503 - val_acc: 0.2263
# Epoch 276/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.7042 - acc: 0.2088 - val_loss: 0.6101 - val_acc: 0.2263
# Epoch 277/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5973 - acc: 0.2093 - val_loss: 0.8008 - val_acc: 0.2263
# Epoch 278/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6354 - acc: 0.2097 - val_loss: 0.8328 - val_acc: 0.2263
# Epoch 279/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6627 - acc: 0.2093 - val_loss: 1.0246 - val_acc: 0.2263
# Epoch 280/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.6243 - acc: 0.2093 - val_loss: 0.7313 - val_acc: 0.2263
# Epoch 281/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6237 - acc: 0.2102 - val_loss: 0.7900 - val_acc: 0.2263
# Epoch 282/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6106 - acc: 0.2097 - val_loss: 0.6278 - val_acc: 0.2263
# Epoch 283/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6496 - acc: 0.2097 - val_loss: 0.6789 - val_acc: 0.2263
# Epoch 284/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6515 - acc: 0.2088 - val_loss: 0.6526 - val_acc: 0.2263
# Epoch 285/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.6071 - acc: 0.2093 - val_loss: 0.6709 - val_acc: 0.2263
# Epoch 286/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6382 - acc: 0.2093 - val_loss: 0.7982 - val_acc: 0.2263
# Epoch 287/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6491 - acc: 0.2088 - val_loss: 0.7437 - val_acc: 0.2263
# Epoch 288/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6181 - acc: 0.2097 - val_loss: 0.8727 - val_acc: 0.2263
# Epoch 289/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6390 - acc: 0.2093 - val_loss: 0.6671 - val_acc: 0.2263
# Epoch 290/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6513 - acc: 0.2097 - val_loss: 0.8150 - val_acc: 0.2263
# Epoch 291/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6024 - acc: 0.2088 - val_loss: 0.7669 - val_acc: 0.2263
# Epoch 292/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7170 - acc: 0.2093 - val_loss: 1.8193 - val_acc: 0.2263
# Epoch 293/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.6745 - acc: 0.2097 - val_loss: 1.2591 - val_acc: 0.2263
# Epoch 294/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6957 - acc: 0.2097 - val_loss: 1.4942 - val_acc: 0.2263
# Epoch 295/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.5944 - acc: 0.2097 - val_loss: 0.6031 - val_acc: 0.2263
# Epoch 296/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 0.6441 - acc: 0.2097 - val_loss: 1.3967 - val_acc: 0.2263
# Epoch 297/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.6802 - acc: 0.2102 - val_loss: 0.8252 - val_acc: 0.2263
# Epoch 298/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6730 - acc: 0.2093 - val_loss: 1.0181 - val_acc: 0.2263
# Epoch 299/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6409 - acc: 0.2093 - val_loss: 0.7058 - val_acc: 0.2263
# Epoch 300/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7733 - acc: 0.2093 - val_loss: 1.3922 - val_acc: 0.2226
# Epoch 301/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7252 - acc: 0.2102 - val_loss: 0.6231 - val_acc: 0.2263
# Epoch 302/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6342 - acc: 0.2097 - val_loss: 1.5138 - val_acc: 0.2263
# Epoch 303/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7188 - acc: 0.2093 - val_loss: 0.8097 - val_acc: 0.2263
# Epoch 304/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6296 - acc: 0.2097 - val_loss: 0.6316 - val_acc: 0.2263
# Epoch 305/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 1.1458 - acc: 0.2093 - val_loss: 1.4699 - val_acc: 0.2263
# Epoch 306/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.7621 - acc: 0.2097 - val_loss: 0.7158 - val_acc: 0.2263
# Epoch 307/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6453 - acc: 0.2097 - val_loss: 0.6415 - val_acc: 0.2263
# Epoch 308/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5928 - acc: 0.2093 - val_loss: 0.6131 - val_acc: 0.2263
# Epoch 309/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6027 - acc: 0.2093 - val_loss: 0.5937 - val_acc: 0.2263
# Epoch 310/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5839 - acc: 0.2097 - val_loss: 0.6749 - val_acc: 0.2263
# Epoch 311/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.5915 - acc: 0.2093 - val_loss: 0.5938 - val_acc: 0.2263
# Epoch 312/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5921 - acc: 0.2093 - val_loss: 0.6529 - val_acc: 0.2263
# Epoch 313/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6149 - acc: 0.2093 - val_loss: 0.7303 - val_acc: 0.2263
# Epoch 314/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6721 - acc: 0.2093 - val_loss: 0.6135 - val_acc: 0.2263
# Epoch 315/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6068 - acc: 0.2102 - val_loss: 0.6451 - val_acc: 0.2263
# Epoch 316/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6017 - acc: 0.2097 - val_loss: 0.6367 - val_acc: 0.2263
# Epoch 317/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.5664 - acc: 0.2097 - val_loss: 0.6359 - val_acc: 0.2263
# Epoch 318/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.5686 - acc: 0.2102 - val_loss: 1.0125 - val_acc: 0.2263
# Epoch 319/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6051 - acc: 0.2097 - val_loss: 0.6439 - val_acc: 0.2263
# Epoch 320/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.5963 - acc: 0.2093 - val_loss: 0.6838 - val_acc: 0.2263
# Epoch 321/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6025 - acc: 0.2093 - val_loss: 0.6499 - val_acc: 0.2263
# Epoch 322/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6029 - acc: 0.2093 - val_loss: 0.6364 - val_acc: 0.2263
# Epoch 323/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6020 - acc: 0.2102 - val_loss: 0.5997 - val_acc: 0.2263
# Epoch 324/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.5739 - acc: 0.2097 - val_loss: 0.5945 - val_acc: 0.2263
# Epoch 325/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.5736 - acc: 0.2097 - val_loss: 0.7969 - val_acc: 0.2245
# Epoch 326/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6360 - acc: 0.2084 - val_loss: 0.7791 - val_acc: 0.2263
# Epoch 327/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6203 - acc: 0.2097 - val_loss: 0.6170 - val_acc: 0.2263
# Epoch 328/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6044 - acc: 0.2093 - val_loss: 0.6299 - val_acc: 0.2263
# Epoch 329/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 0.6261 - acc: 0.2088 - val_loss: 0.8572 - val_acc: 0.2263
# Epoch 330/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6104 - acc: 0.2097 - val_loss: 1.0452 - val_acc: 0.2263
# Epoch 331/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6776 - acc: 0.2097 - val_loss: 0.8315 - val_acc: 0.2263
# Epoch 332/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.7650 - acc: 0.2088 - val_loss: 1.2098 - val_acc: 0.2189
# Epoch 333/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6785 - acc: 0.2097 - val_loss: 0.5949 - val_acc: 0.2263
# Epoch 334/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6010 - acc: 0.2097 - val_loss: 0.6344 - val_acc: 0.2263
# Epoch 335/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.9159 - acc: 0.2102 - val_loss: 1.2699 - val_acc: 0.2263
# Epoch 336/1000
# 68/68 [==============================] - 3s 41ms/step - loss: 0.6507 - acc: 0.2097 - val_loss: 0.5632 - val_acc: 0.2263
# Epoch 337/1000
# 68/68 [==============================] - 3s 40ms/step - loss: 0.5891 - acc: 0.2093 - val_loss: 0.8326 - val_acc: 0.2263
# Epoch 338/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.5868 - acc: 0.2102 - val_loss: 0.6574 - val_acc: 0.2263
# Epoch 339/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6031 - acc: 0.2097 - val_loss: 0.7293 - val_acc: 0.2263
# Epoch 340/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.5685 - acc: 0.2097 - val_loss: 0.6269 - val_acc: 0.2263
# Epoch 341/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.5974 - acc: 0.2097 - val_loss: 0.6696 - val_acc: 0.2263
# Epoch 342/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.5709 - acc: 0.2097 - val_loss: 0.5754 - val_acc: 0.2263
# Epoch 343/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6145 - acc: 0.2093 - val_loss: 0.6284 - val_acc: 0.2263
# Epoch 344/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6099 - acc: 0.2088 - val_loss: 0.5989 - val_acc: 0.2263
# Epoch 345/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.5975 - acc: 0.2093 - val_loss: 0.5769 - val_acc: 0.2263
# Epoch 346/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.5645 - acc: 0.2097 - val_loss: 0.8382 - val_acc: 0.2263
# Epoch 347/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.5805 - acc: 0.2093 - val_loss: 0.5722 - val_acc: 0.2263
# Epoch 348/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6121 - acc: 0.2097 - val_loss: 0.6248 - val_acc: 0.2263
# Epoch 349/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6299 - acc: 0.2084 - val_loss: 0.7117 - val_acc: 0.2263
# Epoch 350/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.6183 - acc: 0.2093 - val_loss: 0.7033 - val_acc: 0.2263
# Epoch 351/1000
# 68/68 [==============================] - 3s 37ms/step - loss: 0.6009 - acc: 0.2093 - val_loss: 0.6420 - val_acc: 0.2263
# Epoch 352/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.5969 - acc: 0.2097 - val_loss: 0.6555 - val_acc: 0.2263
# Epoch 353/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.5891 - acc: 0.2102 - val_loss: 0.7575 - val_acc: 0.2245
# Epoch 354/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6316 - acc: 0.2088 - val_loss: 0.6477 - val_acc: 0.2263
# Epoch 355/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.6233 - acc: 0.2093 - val_loss: 0.7792 - val_acc: 0.2263
# Epoch 356/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.5980 - acc: 0.2097 - val_loss: 0.9358 - val_acc: 0.2263
# Epoch 357/1000
# ...
# Epoch 883/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.4647 - acc: 0.2084 - val_loss: 0.6050 - val_acc: 0.2263
# Epoch 884/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4763 - acc: 0.2074 - val_loss: 0.8340 - val_acc: 0.2263
# Epoch 885/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.4881 - acc: 0.2084 - val_loss: 0.8600 - val_acc: 0.2263
# Epoch 886/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.5128 - acc: 0.2084 - val_loss: 0.6367 - val_acc: 0.2263
# Epoch 887/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.4840 - acc: 0.2088 - val_loss: 0.6358 - val_acc: 0.2245
# Epoch 888/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4576 - acc: 0.2088 - val_loss: 0.6660 - val_acc: 0.2263
# Epoch 889/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5102 - acc: 0.2084 - val_loss: 0.6533 - val_acc: 0.2245
# Epoch 890/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.4637 - acc: 0.2088 - val_loss: 0.5889 - val_acc: 0.2263
# Epoch 891/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.4725 - acc: 0.2084 - val_loss: 0.4966 - val_acc: 0.2263
# Epoch 892/1000
# 68/68 [==============================] - 2s 37ms/step - loss: 0.4530 - acc: 0.2088 - val_loss: 0.6964 - val_acc: 0.2245
# Epoch 893/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4712 - acc: 0.2084 - val_loss: 0.8722 - val_acc: 0.2263
# Epoch 894/1000
# 68/68 [==============================] - 3s 38ms/step - loss: 0.4761 - acc: 0.2088 - val_loss: 0.8706 - val_acc: 0.2245
# Epoch 895/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5007 - acc: 0.2088 - val_loss: 0.4929 - val_acc: 0.2263
# Epoch 896/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5177 - acc: 0.2093 - val_loss: 1.0315 - val_acc: 0.2263
# Epoch 897/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5295 - acc: 0.2084 - val_loss: 0.5254 - val_acc: 0.2245
# Epoch 898/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5945 - acc: 0.2079 - val_loss: 0.6417 - val_acc: 0.2245
# Epoch 899/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.6061 - acc: 0.2084 - val_loss: 0.9519 - val_acc: 0.2189
# Epoch 900/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7716 - acc: 0.2093 - val_loss: 0.5626 - val_acc: 0.2263
# Epoch 901/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6331 - acc: 0.2088 - val_loss: 0.6086 - val_acc: 0.2263
# Epoch 902/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5392 - acc: 0.2093 - val_loss: 1.3569 - val_acc: 0.2263
# Epoch 903/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5642 - acc: 0.2079 - val_loss: 0.5081 - val_acc: 0.2245
# Epoch 904/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4821 - acc: 0.2093 - val_loss: 0.8148 - val_acc: 0.2263
# Epoch 905/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4454 - acc: 0.2079 - val_loss: 0.5322 - val_acc: 0.2263
# Epoch 906/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4671 - acc: 0.2084 - val_loss: 0.6177 - val_acc: 0.2263
# Epoch 907/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5154 - acc: 0.2088 - val_loss: 0.6329 - val_acc: 0.2245
# Epoch 908/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5481 - acc: 0.2079 - val_loss: 0.9085 - val_acc: 0.2263
# Epoch 909/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4693 - acc: 0.2093 - val_loss: 0.6034 - val_acc: 0.2263
# Epoch 910/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4746 - acc: 0.2093 - val_loss: 0.6406 - val_acc: 0.2263
# Epoch 911/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4648 - acc: 0.2088 - val_loss: 0.5245 - val_acc: 0.2263
# Epoch 912/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.4865 - acc: 0.2093 - val_loss: 0.6513 - val_acc: 0.2263
# Epoch 913/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4472 - acc: 0.2088 - val_loss: 0.6784 - val_acc: 0.2263
# Epoch 914/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4811 - acc: 0.2084 - val_loss: 0.6328 - val_acc: 0.2245
# Epoch 915/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4727 - acc: 0.2088 - val_loss: 0.7487 - val_acc: 0.2263
# Epoch 916/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4706 - acc: 0.2088 - val_loss: 0.5148 - val_acc: 0.2245
# Epoch 917/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.4546 - acc: 0.2088 - val_loss: 0.6834 - val_acc: 0.2263
# Epoch 918/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4704 - acc: 0.2093 - val_loss: 0.6414 - val_acc: 0.2245
# Epoch 919/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.4809 - acc: 0.2084 - val_loss: 0.7778 - val_acc: 0.2189
# Epoch 920/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4818 - acc: 0.2088 - val_loss: 0.6200 - val_acc: 0.2263
# Epoch 921/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4785 - acc: 0.2088 - val_loss: 0.7485 - val_acc: 0.2263
# Epoch 922/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4658 - acc: 0.2084 - val_loss: 0.6514 - val_acc: 0.2263
# Epoch 923/1000
# 68/68 [==============================] - 3s 39ms/step - loss: 0.4482 - acc: 0.2088 - val_loss: 0.5172 - val_acc: 0.2263
# Epoch 924/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5250 - acc: 0.2088 - val_loss: 0.7370 - val_acc: 0.2245
# Epoch 925/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4775 - acc: 0.2088 - val_loss: 0.5146 - val_acc: 0.2245
# Epoch 926/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4851 - acc: 0.2093 - val_loss: 0.8220 - val_acc: 0.2263
# Epoch 927/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5123 - acc: 0.2084 - val_loss: 0.5900 - val_acc: 0.2263
# Epoch 928/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5390 - acc: 0.2088 - val_loss: 1.3213 - val_acc: 0.2263
# Epoch 929/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5936 - acc: 0.2088 - val_loss: 0.7860 - val_acc: 0.2263
# Epoch 930/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.7453 - acc: 0.2084 - val_loss: 1.3346 - val_acc: 0.2245
# Epoch 931/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5885 - acc: 0.2079 - val_loss: 0.4963 - val_acc: 0.2263
# Epoch 932/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4876 - acc: 0.2084 - val_loss: 0.6660 - val_acc: 0.2263
# Epoch 933/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.7883 - acc: 0.2079 - val_loss: 1.3268 - val_acc: 0.2263
# Epoch 934/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.6524 - acc: 0.2093 - val_loss: 1.7199 - val_acc: 0.2263
# Epoch 935/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5610 - acc: 0.2088 - val_loss: 0.4924 - val_acc: 0.2263
# Epoch 936/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5257 - acc: 0.2093 - val_loss: 0.7078 - val_acc: 0.2263
# Epoch 937/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.4552 - acc: 0.2088 - val_loss: 0.9347 - val_acc: 0.2263
# Epoch 938/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4868 - acc: 0.2088 - val_loss: 0.6560 - val_acc: 0.2263
# Epoch 939/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4507 - acc: 0.2084 - val_loss: 0.5989 - val_acc: 0.2263
# Epoch 940/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4530 - acc: 0.2084 - val_loss: 0.6056 - val_acc: 0.2245
# Epoch 941/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4423 - acc: 0.2084 - val_loss: 0.5765 - val_acc: 0.2263
# Epoch 942/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4778 - acc: 0.2097 - val_loss: 1.0502 - val_acc: 0.2263
# Epoch 943/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4754 - acc: 0.2093 - val_loss: 0.4843 - val_acc: 0.2263
# Epoch 944/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4771 - acc: 0.2084 - val_loss: 0.9232 - val_acc: 0.2263
# Epoch 945/1000
# 68/68 [==============================] - 3s 47ms/step - loss: 0.4832 - acc: 0.2088 - val_loss: 0.6363 - val_acc: 0.2263
# Epoch 946/1000
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4798 - acc: 0.2079 - val_loss: 0.5517 - val_acc: 0.2263
# Epoch 947/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4580 - acc: 0.2088 - val_loss: 0.7959 - val_acc: 0.2263
# Epoch 948/1000
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4834 - acc: 0.2093 - val_loss: 0.6529 - val_acc: 0.2263
# Epoch 949/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4994 - acc: 0.2088 - val_loss: 0.6457 - val_acc: 0.2263
# Epoch 950/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4841 - acc: 0.2084 - val_loss: 0.5209 - val_acc: 0.2263
# Epoch 951/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5730 - acc: 0.2088 - val_loss: 0.8708 - val_acc: 0.2263
# Epoch 952/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5036 - acc: 0.2070 - val_loss: 0.5895 - val_acc: 0.2263
# Epoch 953/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5523 - acc: 0.2084 - val_loss: 1.4779 - val_acc: 0.2263
# Epoch 954/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5072 - acc: 0.2074 - val_loss: 0.7277 - val_acc: 0.2263
# Epoch 955/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5034 - acc: 0.2093 - val_loss: 0.9554 - val_acc: 0.2263
# Epoch 956/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5192 - acc: 0.2088 - val_loss: 0.4994 - val_acc: 0.2263
# Epoch 957/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4753 - acc: 0.2088 - val_loss: 0.7548 - val_acc: 0.2263
# Epoch 958/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4984 - acc: 0.2079 - val_loss: 0.7243 - val_acc: 0.2263
# Epoch 959/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4896 - acc: 0.2093 - val_loss: 0.6357 - val_acc: 0.2263
# Epoch 960/1000
# 68/68 [==============================] - 2s 36ms/step - loss: 0.4450 - acc: 0.2088 - val_loss: 0.5211 - val_acc: 0.2263
# Epoch 961/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4807 - acc: 0.2084 - val_loss: 1.0628 - val_acc: 0.2263
# Epoch 962/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4790 - acc: 0.2097 - val_loss: 0.5662 - val_acc: 0.2263
# Epoch 963/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4494 - acc: 0.2084 - val_loss: 0.4919 - val_acc: 0.2245
# Epoch 964/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4784 - acc: 0.2084 - val_loss: 0.6222 - val_acc: 0.2263
# Epoch 965/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4673 - acc: 0.2088 - val_loss: 0.6797 - val_acc: 0.2263
# Epoch 966/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4575 - acc: 0.2079 - val_loss: 0.5940 - val_acc: 0.2263
# Epoch 967/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5085 - acc: 0.2079 - val_loss: 0.8477 - val_acc: 0.2263
# Epoch 968/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4827 - acc: 0.2093 - val_loss: 0.7236 - val_acc: 0.2263
# Epoch 969/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4594 - acc: 0.2088 - val_loss: 0.9688 - val_acc: 0.2189
# Epoch 970/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4815 - acc: 0.2084 - val_loss: 0.5202 - val_acc: 0.2263
# Epoch 971/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4785 - acc: 0.2093 - val_loss: 0.7292 - val_acc: 0.2263
# Epoch 972/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4709 - acc: 0.2093 - val_loss: 1.0082 - val_acc: 0.2152
# Epoch 973/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.5335 - acc: 0.2093 - val_loss: 0.6718 - val_acc: 0.2226
# Epoch 974/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5094 - acc: 0.2088 - val_loss: 0.4916 - val_acc: 0.2263
# Epoch 975/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5843 - acc: 0.2084 - val_loss: 1.2423 - val_acc: 0.2189
# Epoch 976/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5610 - acc: 0.2088 - val_loss: 0.5399 - val_acc: 0.2245
# Epoch 977/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5223 - acc: 0.2084 - val_loss: 0.9048 - val_acc: 0.2245
# Epoch 978/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5183 - acc: 0.2093 - val_loss: 0.5162 - val_acc: 0.2263
# Epoch 979/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5843 - acc: 0.2084 - val_loss: 1.1285 - val_acc: 0.2245
# Epoch 980/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5156 - acc: 0.2088 - val_loss: 0.5025 - val_acc: 0.2245
# Epoch 981/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4862 - acc: 0.2084 - val_loss: 1.1465 - val_acc: 0.2263
# Epoch 982/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4842 - acc: 0.2093 - val_loss: 0.6565 - val_acc: 0.2226
# Epoch 983/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.5081 - acc: 0.2088 - val_loss: 1.0923 - val_acc: 0.2263
# Epoch 984/1000
# 68/68 [==============================] - 2s 34ms/step - loss: 0.4668 - acc: 0.2088 - val_loss: 0.4672 - val_acc: 0.2263
# Epoch 985/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4867 - acc: 0.2093 - val_loss: 1.1602 - val_acc: 0.2263
# Epoch 986/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4869 - acc: 0.2084 - val_loss: 0.6991 - val_acc: 0.2208
# Epoch 987/1000
# 68/68 [==============================] - 2s 33ms/step - loss: 0.4712 - acc: 0.2093 - val_loss: 1.3891 - val_acc: 0.2263
# Epoch 988/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.4956 - acc: 0.2079 - val_loss: 0.5447 - val_acc: 0.2263
# Epoch 989/1000
# 68/68 [==============================] - 2s 32ms/step - loss: 0.5157 - acc: 0.2093 - val_loss: 0.7634 - val_acc: 0.2263
# Epoch 990/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4855 - acc: 0.2093 - val_loss: 0.6991 - val_acc: 0.2263
# Epoch 991/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4609 - acc: 0.2093 - val_loss: 0.6713 - val_acc: 0.2263
# Epoch 992/1000
# 68/68 [==============================] - 2s 30ms/step - loss: 0.4553 - acc: 0.2097 - val_loss: 0.6354 - val_acc: 0.2263
# Epoch 993/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4690 - acc: 0.2088 - val_loss: 0.7628 - val_acc: 0.2245
# Epoch 994/1000
# 68/68 [==============================] - 2s 35ms/step - loss: 0.4790 - acc: 0.2088 - val_loss: 0.5400 - val_acc: 0.2245
# Epoch 995/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5045 - acc: 0.2093 - val_loss: 0.5197 - val_acc: 0.2263
# Epoch 996/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.4890 - acc: 0.2093 - val_loss: 0.7223 - val_acc: 0.2263
# Epoch 997/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5717 - acc: 0.2084 - val_loss: 1.4153 - val_acc: 0.2263
# Epoch 998/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5360 - acc: 0.2088 - val_loss: 0.5217 - val_acc: 0.2263
# Epoch 999/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5279 - acc: 0.2079 - val_loss: 0.6570 - val_acc: 0.2245
# Epoch 1000/1000
# 68/68 [==============================] - 2s 31ms/step - loss: 0.5191 - acc: 0.2084 - val_loss: 0.6703 - val_acc: 0.2263

# %%
# モデルの評価(大きさ)
score = cnn_model.evaluate([size_x_test1, size_x_test2, size_x_test3], size_y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 17/17 [==============================] - 0s 10ms/step - loss: 0.8111 - acc: 0.2263
# Test loss: 0.8110945224761963
# Test accuracy: 0.22634507715702057

# %%
# 学習経過の可視化(大きさ)
loss     = size_history.history['loss']
val_loss = size_history.history['val_loss']

nb_epoch = len(loss)
plt.plot(range(nb_epoch), loss,     marker='.', label='loss')
plt.plot(range(nb_epoch), val_loss, marker='.', label='val_loss')
plt.legend(loc='best', fontsize=10)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
#大きさごとの推定精度の確認：20%以下
size_predict = cnn_size_model.predict([size_x_test1,size_x_test2,size_x_test3])
size_answer = size_y_test
one_total = 0
one_ok = 0
two_total = 0
two_ok = 0
three_total = 0
three_ok = 0
four_total = 0
four_ok = 0
five_total = 0
five_ok = 0
for i in range(len(size_predict)):
    if size_answer[i] == 1:
        one_total = one_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 0.2):
            one_ok = one_ok + 1
    if size_answer[i] == 2:
        two_total = two_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 0.4):
            two_ok = two_ok + 1
    if size_answer[i] == 3:
        three_total = three_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 0.6):
            three_ok = three_ok + 1
    if size_answer[i] == 4:
        four_total = four_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 0.8):
            four_ok = four_ok + 1
    if size_answer[i] == 5:
        five_total = five_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 1):
            five_ok = five_ok + 1
print("大きさ1の正答率："+str(one_ok/one_total))
print("大きさ2の正答率："+str(two_ok/two_total))
print("大きさ3の正答率："+str(three_ok/three_total))
print("大きさ4の正答率："+str(four_ok/four_total))
print("大きさ5の正答率："+str(five_ok/five_total))
# Out:
# 大きさ1の正答率：0.02459016393442623
# 大きさ2の正答率：0.8650793650793651
# 大きさ3の正答率：0.83
# 大きさ4の正答率：0.7291666666666666
# 大きさ5の正答率：0.6105263157894737

# %%
import numpy as np
import matplotlib.pyplot as plt
left = np.array([1,2,3,4,5])
height = np.array([one_ok/one_total,two_ok/two_total,three_ok/three_total,four_ok/four_total,five_ok/five_total])
plt.bar(left, height)
plt.xlabel("size")
plt.ylabel("size acc")
plt.ylim(top=1, bottom=0)
plt.show()

# %%
#大きさごとの推定精度の確認：最も近く予測
size_predict = cnn_size_model.predict([size_x_test1,size_x_test2,size_x_test3])
size_answer = size_y_test
one_total = 0
one_ok = 0
two_total = 0
two_ok = 0
three_total = 0
three_ok = 0
four_total = 0
four_ok = 0
five_total = 0
five_ok = 0
for i in range(len(size_predict)):
    if size_answer[i] == 1:
        one_total = one_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 0.5):
            one_ok = one_ok + 1
    if size_answer[i] == 2:
        two_total = two_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 0.5):
            two_ok = two_ok + 1
    if size_answer[i] == 3:
        three_total = three_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 0.5):
            three_ok = three_ok + 1
    if size_answer[i] == 4:
        four_total = four_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 0.5):
            four_ok = four_ok + 1
    if size_answer[i] == 5:
        five_total = five_total + 1
        if (abs(size_predict[i] - size_answer[i]) < 0.5):
            five_ok = five_ok + 1
print("大きさ1の正答率："+str(one_ok/one_total))
print("大きさ2の正答率："+str(two_ok/two_total))
print("大きさ3の正答率："+str(three_ok/three_total))
print("大きさ4の正答率："+str(four_ok/four_total))
print("大きさ5の正答率："+str(five_ok/five_total))
# Out:
# 大きさ1の正答率：0.09016393442622951
# 大きさ2の正答率：0.9047619047619048
# 大きさ3の正答率：0.68
# 大きさ4の正答率：0.53125
# 大きさ5の正答率：0.29473684210526313

# %%
import numpy as np
import matplotlib.pyplot as plt
left = np.array([1,2,3,4,5])
height = np.array([one_ok/one_total,two_ok/two_total,three_ok/three_total,four_ok/four_total,five_ok/five_total])
plt.bar(left, height)
plt.xlabel("size")
plt.ylabel("size acc")
plt.ylim(top=1, bottom=0)
plt.show()

# %%
one_predict = []
size_predict = cnn_size_model.predict([size_x_test1,size_x_test2,size_x_test3])
size_answer = size_y_test
for i in range(len(size_y_test)):
    if size_answer[i] == 1:
        one_predict.append(size_predict[i][0])
print(one_predict)
# Out:
# [1.2134696, 1.6661559, 1.7480451, 1.6204435, 2.6542702, 1.7087451, 1.8479491, 1.0290567, 2.7077856, 2.126976, 1.7083312, 1.964408, 1.6251241, 2.0236492, 1.720832, 1.21725, 1.6554977, 1.6818658, 1.7969505, 1.6366035, 1.6814986, 1.7662688, 1.579753, 1.9947568, 1.7457267, 1.7089206, 1.6414806, 1.672558, 1.8195792, 1.7441398, 1.7856637, 3.0185757, 1.6428863, 1.6718379, 1.8187362, 1.744773, 1.637354, 1.6334411, 1.7026016, 1.6644737, 1.396165, 1.6115981, 1.6678954, 1.6630441, 1.7100984, 1.650798, 1.6587573, 1.6584817, 1.632682, 1.7165157, 1.8138019, 1.6055204, 1.6478244, 1.6882316, 1.6580936, 1.7068864, 1.7117435, 1.6997224, 1.6153814, 1.9441501, 1.6806346, 1.6944858, 1.7074653, 1.6938506, 1.6621333, 1.6572744, 1.7638847, 1.4912664, 1.6455861, 1.8059932, 1.9989825, 1.8530065, 2.101304, 1.7473212, 1.6424419, 1.6714889, 1.6408712, 1.5341579, 1.0337774, 1.3965389, 1.6633931, 1.3242122, 1.9347316, 1.7020284, 1.71093, 1.7353288, 1.7121478, 1.6559955, 1.4930831, 1.8081199, 1.5703565, 1.6714164, 1.6822387, 1.5849525, 1.6763412, 1.8174669, 2.061346, 1.6561004, 1.7074081, 1.6036226, 1.505704, 1.6872245, 1.6794893, 1.645917, 1.741211, 1.510379, 1.6495115, 1.5257999, 1.6614181, 1.666526, 1.6769248, 1.6339351, 1.7168523, 0.89264596, 1.6444207, 1.7151214, 1.6568595, 1.6448108, 1.6411372, 0.675068, 1.6686269, 1.6717349]

# %%
# CNNモデルで位置推定
# import
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, concatenate, Dense
from tensorflow.keras.models import Model
from tensorflow.python.keras.utils.vis_utils import plot_model

# 入力を定義
input1 = Input(shape=(1251,1))
input2 = Input(shape=(1251,1))
input3 = Input(shape=(1251,1))

# 入力1から結合前まで
x = Conv1D(32, 3, padding='same', activation='tanh')(input1)
x = MaxPooling1D(2, padding='same')(x)
x = Model(inputs=input1, outputs=x)
# 入力2から結合前まで
y = Conv1D(32, 3, padding='same', activation='tanh')(input2)
y = MaxPooling1D(2, padding='same')(y)
y = Model(inputs=input2, outputs=y)
# 入力3から結合前まで
z = Conv1D(32, 3, padding='same', activation='tanh')(input3)
z = MaxPooling1D(2, padding='same')(z)
z = Model(inputs=input3, outputs=z)

# 結合
combined = concatenate([x.output, y.output, z.output])

# 密結合
cnn = Flatten()(combined)
cnn = Dense(2, activation="linear")(cnn)

# モデル定義とコンパイル
cnn_position_model = Model(inputs=[x.input, y.input, z.input], outputs=cnn)
cnn_position_model.compile(loss='mse', optimizer='adam', metrics=['acc'])
cnn_position_model.summary()
plot_model(cnn_position_model, show_shapes=True, show_layer_names=False)
