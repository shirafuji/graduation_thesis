# %%
## 必要なライブラリのimport
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Dense, Flatten
from keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import random

# %%
## データについて

### データファイルのpath
no_hole_path = './../tmp_simulation/tmp_data/no_hole_data.csv'
one_hole_path = './../tmp_simulation/tmp_data/one_hole_data.csv'
four_holes_path = './../tmp_simulation/tmp_data/four_holes_data.csv'
nine_holes_path = './../tmp_simulation/tmp_data/nine_holes_data.csv'
sixteen_holes_path = './../tmp_simulation/tmp_data/sixteen_holes_data.csv'
twentyfive_holes_path = './../tmp_simulation/tmp_data/twentyfive_holes_data.csv'

### 入力データと正解データ
size_x_data_list = []
size_y_data_list = []
position_x_data_list = []
position_y_data_list = []
no_hole_data = []
one_one_one = []
one_one_two = []
one_one_three = []
one_one_four = []
one_one_five = []
one_two_one = []
one_two_two = []
one_two_three = []
one_two_four = []
one_two_five = []
one_three_one = []
one_three_two = []
one_three_three = []
one_three_four = []
one_three_five = []
one_four_one = []
one_four_two = []
one_four_three = []
one_four_four = []
one_four_five = []
one_five_one = []
one_five_two = []
one_five_three = []
one_five_four = []
one_five_five = []
two_one_one = []
two_one_two = []
two_one_three = []
two_one_four = []
two_one_five = []
two_two_one = []
two_two_two = []
two_two_three = []
two_two_four = []
two_two_five = []
two_three_one = []
two_three_two = []
two_three_three = []
two_three_four = []
two_three_five = []
two_four_one = []
two_four_two = []
two_four_three = []
two_four_four = []
two_four_five = []
two_five_one = []
two_five_two = []
two_five_three = []
two_five_four = []
two_five_five = []
three_one_one = []
three_one_two = []
three_one_three = []
three_one_four = []
three_one_five = []
three_two_one = []
three_two_two = []
three_two_three = []
three_two_four = []
three_two_five = []
three_three_one = []
three_three_two = []
three_three_three = []
three_three_four = []
three_three_five = []
three_four_one = []
three_four_two = []
three_four_three = []
three_four_four = []
three_four_five = []
three_five_one = []
three_five_two = []
three_five_three = []
three_five_four = []
three_five_five = []
four_one_one = []
four_one_two = []
four_one_three = []
four_one_four = []
four_one_five = []
four_two_one = []
four_two_two = []
four_two_three = []
four_two_four = []
four_two_five = []
four_three_one = []
four_three_two = []
four_three_three = []
four_three_four = []
four_three_five = []
four_four_one = []
four_four_two = []
four_four_three = []
four_four_four = []
four_four_five = []
four_five_one = []
four_five_two = []
four_five_three = []
four_five_four = []
four_five_five = []
five_one_one = []
five_one_two = []
five_one_three = []
five_one_four = []
five_one_five = []
five_two_one = []
five_two_two = []
five_two_three = []
five_two_four = []
five_two_five = []
five_three_one = []
five_three_two = []
five_three_three = []
five_three_four = []
five_three_five = []
five_four_one = []
five_four_two = []
five_four_three = []
five_four_four = []
five_four_five = []
five_five_one = []
five_five_two = []
five_five_three = []
five_five_four = []
five_five_five = []


### ファイル読み込み

#### 欠陥がない場合の温度データ
with open(no_hole_path) as f:
    for line in f:
        no_hole_data = line.split(',')[:-1]

#### データ分類
with open(one_hole_path) as fs1:
  for line in fs1:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        one_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        one_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        one_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        one_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        one_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        one_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        one_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        one_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        one_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        one_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        one_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        one_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        one_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        one_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        one_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        one_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        one_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        one_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        one_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        one_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        one_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        one_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        one_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        one_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        one_five_five.append(data_array)

with open(four_holes_path) as fs2:
  for line in fs2:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        two_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        two_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        two_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        two_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        two_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        two_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        two_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        two_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        two_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        two_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        two_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        two_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        two_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        two_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        two_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        two_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        two_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        two_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        two_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        two_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        two_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        two_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        two_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        two_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        two_five_five.append(data_array)
with open(nine_holes_path) as fs3:
  for line in fs3:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        three_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        three_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        three_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        three_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        three_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        three_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        three_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        three_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        three_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        three_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        three_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        three_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        three_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        three_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        three_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        three_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        three_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        three_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        three_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        three_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        three_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        three_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        three_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        three_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        three_five_five.append(data_array)
with open(sixteen_holes_path) as fs4:
  for line in fs4:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        four_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        four_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        four_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        four_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        four_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        four_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        four_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        four_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        four_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        four_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        four_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        four_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        four_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        four_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        four_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        four_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        four_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        four_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        four_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        four_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        four_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        four_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        four_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        four_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        four_five_five.append(data_array)
with open(twentyfive_holes_path) as fs5:
  for line in fs5:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        five_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        five_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        five_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        five_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        five_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        five_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        five_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        five_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        five_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        five_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        five_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        five_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        five_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        five_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        five_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        five_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        five_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        five_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        five_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        five_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        five_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        five_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        five_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        five_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        five_five_five.append(data_array)

### 利用データの決定
for j in range(4):
    size_x_data = []
    size_y_data = []
    position_x_data = []
    position_y_data = []
    #### one_one_oneについて
    index = []
    for i in range(len(one_one_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_one_twoについて
    index = []
    for i in range(len(one_one_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_one_threeについて
    index = []
    for i in range(len(one_one_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_one_fourについて
    index = []
    for i in range(len(one_one_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_one_fiveについて
    index = []
    for i in range(len(one_one_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_oneについて
    index = []
    for i in range(len(one_two_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_twoについて
    index = []
    for i in range(len(one_two_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_threeについて
    index = []
    for i in range(len(one_two_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_fourについて
    index = []
    for i in range(len(one_two_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_fiveについて
    index = []
    for i in range(len(one_two_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_oneについて
    index = []
    for i in range(len(one_three_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_twoについて
    index = []
    for i in range(len(one_three_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_threeについて
    index = []
    for i in range(len(one_three_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_fourについて
    index = []
    for i in range(len(one_three_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_fiveについて
    index = []
    for i in range(len(one_three_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_oneについて
    index = []
    for i in range(len(one_four_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_twoについて
    index = []
    for i in range(len(one_four_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_threeについて
    index = []
    for i in range(len(one_four_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_fourについて
    index = []
    for i in range(len(one_four_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_fiveについて
    index = []
    for i in range(len(one_four_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_oneについて
    index = []
    for i in range(len(one_five_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_twoについて
    index = []
    for i in range(len(one_five_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_threeについて
    index = []
    for i in range(len(one_five_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_fourについて
    index = []
    for i in range(len(one_five_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_fiveについて
    index = []
    for i in range(len(one_five_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_oneについて
    index = []
    for i in range(len(two_one_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_twoについて
    index = []
    for i in range(len(two_one_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_threeについて
    index = []
    for i in range(len(two_one_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_fourについて
    index = []
    for i in range(len(two_one_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_fiveについて
    index = []
    for i in range(len(two_one_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_oneについて
    index = []
    for i in range(len(two_two_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_twoについて
    index = []
    for i in range(len(two_two_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_threeについて
    index = []
    for i in range(len(two_two_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_fourについて
    index = []
    for i in range(len(two_two_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_fiveについて
    index = []
    for i in range(len(two_two_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_oneについて
    index = []
    for i in range(len(two_three_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_twoについて
    index = []
    for i in range(len(two_three_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_threeについて
    index = []
    for i in range(len(two_three_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_fourについて
    index = []
    for i in range(len(two_three_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_fiveについて
    index = []
    for i in range(len(two_three_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_oneについて
    index = []
    for i in range(len(two_four_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_twoについて
    index = []
    for i in range(len(two_four_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_threeについて
    index = []
    for i in range(len(two_four_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_fourについて
    index = []
    for i in range(len(two_four_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_fiveについて
    index = []
    for i in range(len(two_four_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_oneについて
    index = []
    for i in range(len(two_five_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_twoについて
    index = []
    for i in range(len(two_five_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_threeについて
    index = []
    for i in range(len(two_five_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_fourについて
    index = []
    for i in range(len(two_five_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_fiveについて
    index = []
    for i in range(len(two_five_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_oneについて
    index = []
    for i in range(len(three_one_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_twoについて
    index = []
    for i in range(len(three_one_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_threeについて
    index = []
    for i in range(len(three_one_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_fourについて
    index = []
    for i in range(len(three_one_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_fiveについて
    index = []
    for i in range(len(three_one_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_oneについて
    index = []
    for i in range(len(three_two_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_twoについて
    index = []
    for i in range(len(three_two_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_threeについて
    index = []
    for i in range(len(three_two_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_fourについて
    index = []
    for i in range(len(three_two_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_fiveについて
    index = []
    for i in range(len(three_two_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_oneについて
    index = []
    for i in range(len(three_three_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_twoについて
    index = []
    for i in range(len(three_three_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_threeについて
    index = []
    for i in range(len(three_three_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_fourについて
    index = []
    for i in range(len(three_three_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_fiveについて
    index = []
    for i in range(len(three_three_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_oneについて
    index = []
    for i in range(len(three_four_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_twoについて
    index = []
    for i in range(len(three_four_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_threeについて
    index = []
    for i in range(len(three_four_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_fourについて
    index = []
    for i in range(len(three_four_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_fiveについて
    index = []
    for i in range(len(three_four_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_oneについて
    index = []
    for i in range(len(three_five_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_twoについて
    index = []
    for i in range(len(three_five_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_threeについて
    index = []
    for i in range(len(three_five_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_fourについて
    index = []
    for i in range(len(three_five_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_fiveについて
    index = []
    for i in range(len(three_five_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_oneについて
    index = []
    for i in range(len(four_one_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_twoについて
    index = []
    for i in range(len(four_one_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_threeについて
    index = []
    for i in range(len(four_one_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_fourについて
    index = []
    for i in range(len(four_one_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_fiveについて
    index = []
    for i in range(len(four_one_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_oneについて
    index = []
    for i in range(len(four_two_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_twoについて
    index = []
    for i in range(len(four_two_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_threeについて
    index = []
    for i in range(len(four_two_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_fourについて
    index = []
    for i in range(len(four_two_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_fiveについて
    index = []
    for i in range(len(four_two_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_oneについて
    index = []
    for i in range(len(four_three_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_twoについて
    index = []
    for i in range(len(four_three_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_threeについて
    index = []
    for i in range(len(four_three_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_fourについて
    index = []
    for i in range(len(four_three_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_fiveについて
    index = []
    for i in range(len(four_three_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_oneについて
    index = []
    for i in range(len(four_four_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_twoについて
    index = []
    for i in range(len(four_four_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_threeについて
    index = []
    for i in range(len(four_four_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_fourについて
    index = []
    for i in range(len(four_four_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_fiveについて
    index = []
    for i in range(len(four_four_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_oneについて
    index = []
    for i in range(len(four_five_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_twoについて
    index = []
    for i in range(len(four_five_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_threeについて
    index = []
    for i in range(len(four_five_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_fourについて
    index = []
    for i in range(len(four_five_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_fiveについて
    index = []
    for i in range(len(four_five_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_oneについて
    index = []
    for i in range(len(five_one_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_twoについて
    index = []
    for i in range(len(five_one_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_threeについて
    index = []
    for i in range(len(five_one_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_fourについて
    index = []
    for i in range(len(five_one_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_fiveについて
    index = []
    for i in range(len(five_one_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_oneについて
    index = []
    for i in range(len(five_two_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_twoについて
    index = []
    for i in range(len(five_two_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_threeについて
    index = []
    for i in range(len(five_two_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_fourについて
    index = []
    for i in range(len(five_two_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_fiveについて
    index = []
    for i in range(len(five_two_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_oneについて
    index = []
    for i in range(len(five_three_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_twoについて
    index = []
    for i in range(len(five_three_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_threeについて
    index = []
    for i in range(len(five_three_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_fourについて
    index = []
    for i in range(len(five_three_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_fiveについて
    index = []
    for i in range(len(five_three_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_oneについて
    index = []
    for i in range(len(five_four_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_twoについて
    index = []
    for i in range(len(five_four_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_threeについて
    index = []
    for i in range(len(five_four_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_fourについて
    index = []
    for i in range(len(five_four_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_fiveについて
    index = []
    for i in range(len(five_four_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_oneについて
    index = []
    for i in range(len(five_five_one)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_twoについて
    index = []
    for i in range(len(five_five_two)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_threeについて
    index = []
    for i in range(len(five_five_three)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_fourについて
    index = []
    for i in range(len(five_five_four)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_fiveについて
    index = []
    for i in range(len(five_five_five)):
        index.append(i)
    data_count = 2*(j+1)
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])

    ### 各配列をnp.array型にして各要素を型変換
    no_hole_data = np.array(no_hole_data, dtype=float)
    size_x_data = np.array(size_x_data, dtype=float)
    size_y_data = np.array(size_y_data, dtype=int)
    position_x_data = np.array(position_x_data, dtype=float)
    position_y_data = np.array(position_y_data, dtype=float)

    ### データの加工
    size_x_data = (size_x_data-no_hole_data)
    position_x_data = (position_x_data-no_hole_data)
    position_y_data = position_y_data/50
    
    size_x_data_list.append(size_x_data)
    size_y_data_list.append(size_y_data)
    position_x_data_list.append(position_x_data)
    position_y_data_list.append(position_y_data)

size_x_train_list = []
size_x_test_list = []
size_y_train_list = []
size_y_test_list = []
position_x_train_list = []
position_x_test_list = []
position_y_train_list = []
position_y_test_list = []
### train用とtest用に分割(4:1)
for i in range(4):
    #### 大きさ
    size_x_data = size_x_data_list[i]
    size_y_data = size_y_data_list[i]
    size_x_train, size_x_test, size_y_train, size_y_test = train_test_split(size_x_data, size_y_data, test_size=0.20)
    #### 位置
    position_x_data = position_x_data_list[i]
    position_y_data = position_y_data_list[i]
    position_x_train, position_x_test, position_y_train, position_y_test = train_test_split(position_x_data, position_y_data, test_size=0.20)
    #### reshape
    size_x_train = size_x_train.reshape(200*(i+1), 50, 1)
    size_x_test = size_x_test.reshape(50*(i+1), 50, 1)
    position_x_train = position_x_train.reshape(200*(i+1), 50, 1)
    position_x_test = position_x_test.reshape(50*(i+1), 50, 1)
    #### リスト格納
    size_x_train_list.append(size_x_train)
    size_x_test_list.append(size_x_test)
    size_y_train_list.append(size_y_train)
    size_y_test_list.append(size_y_test)
    position_x_train_list.append(position_x_train)
    position_x_test_list.append(position_x_test)
    position_y_train_list.append(position_y_train)
    position_y_test_list.append(position_y_test)

# %%
# 大きさ推定のモデル
model_size_array = []

for i in range(4):
    size_model = Sequential()
    ### 畳み込み層
    size_model.add(Conv1D(32, 3, padding='same', activation='tanh', input_shape=(50, 1)))
    ### プーリング層
    size_model.add(MaxPooling1D(2, padding='same'))
    ### Flatten層
    size_model.add(Flatten())
    ### 全結合層
    size_model.add(Dense(1, activation='linear'))
    ### optimizer
    adam = keras.optimizers.Adam()
    ### コンパイル
    size_model.compile(loss='mse', optimizer=adam, metrics=['accuracy'])
    ### 配列にいれる
    model_size_array.append(size_model)

# %%
# 学習ループ
history_size_array = []
for i in range(len(model_size_array)):
    epochs = 1000
    batch_size = 128
    history_size_array.append(model_size_array[i].fit(size_x_train_list[i], size_y_train_list[i], batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(size_x_test_list[i], size_y_test_list[i])))
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 0s 82ms/step - loss: 8.9334 - accuracy: 0.0550 - val_loss: 4.7519 - val_accuracy: 0.3400
# Epoch 2/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 6.1681 - accuracy: 0.1650 - val_loss: 3.1948 - val_accuracy: 0.3400
# Epoch 3/1000
# 2/2 [==============================] - 0s 18ms/step - loss:
1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.2924 - accuracy: 0.1650 - val_loss: 1.3049 - val_accuracy: 0.3200
# Epoch 205/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.2863 - accuracy: 0.1650 - val_loss: 1.2715 - val_accuracy: 0.3200
# Epoch 206/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.2815 - accuracy: 0.1650 - val_loss: 1.2579 - val_accuracy: 0.3200
# Epoch 207/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.2760 - accuracy: 0.1650 - val_loss: 1.2678 - val_accuracy: 0.3200
# Epoch 208/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2713 - accuracy: 0.1650 - val_loss: 1.2641 - val_accuracy: 0.3200
# Epoch 209/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.2658 - accuracy: 0.1650 - val_loss: 1.2504 - val_accuracy: 0.3200
# Epoch 210/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2608 - accuracy: 0.1650 - val_loss: 1.2548 - val_accuracy: 0.3200
# Epoch 211/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.2565 - accuracy: 0.1650 - val_loss: 1.2747 - val_accuracy: 0.3200
# Epoch 212/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.2513 - accuracy: 0.1650 - val_loss: 1.2661 - val_accuracy: 0.3200
# Epoch 213/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.2464 - accuracy: 0.1650 - val_loss: 1.2581 - val_accuracy: 0.3200
# Epoch 214/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2408 - accuracy: 0.1650 - val_loss: 1.2402 - val_accuracy: 0.3200
# Epoch 215/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.2387 - accuracy: 0.1650 - val_loss: 1.2198 - val_accuracy: 0.3200
# Epoch 216/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2341 - accuracy: 0.1650 - val_loss: 1.2359 - val_accuracy: 0.3200
# Epoch 217/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2243 - accuracy: 0.1650 - val_loss: 1.2856 - val_accuracy: 0.3200
# Epoch 218/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.2262 - accuracy: 0.1650 - val_loss: 1.3091 - val_accuracy: 0.3200
# Epoch 219/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.2225 - accuracy: 0.1650 - val_loss: 1.2647 - val_accuracy: 0.3200
# Epoch 220/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.2115 - accuracy: 0.1650 - val_loss: 1.2021 - val_accuracy: 0.3200
# Epoch 221/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.2077 - accuracy: 0.1650 - val_loss: 1.1677 - val_accuracy: 0.3200
# Epoch 222/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.2121 - accuracy: 0.1650 - val_loss: 1.1710 - val_accuracy: 0.3200
# Epoch 223/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2026 - accuracy: 0.1650 - val_loss: 1.2313 - val_accuracy: 0.3200
# Epoch 224/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1960 - accuracy: 0.1650 - val_loss: 1.2584 - val_accuracy: 0.3200
# Epoch 225/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 1.1928 - accuracy: 0.1650 - val_loss: 1.2204 - val_accuracy: 0.3200
# Epoch 226/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 1.1926 - accuracy: 0.1650 - val_loss: 1.1539 - val_accuracy: 0.3200
# Epoch 227/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1842 - accuracy: 0.1650 - val_loss: 1.1593 - val_accuracy: 0.3200
# Epoch 228/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.1765 - accuracy: 0.1650 - val_loss: 1.1718 - val_accuracy: 0.3200
# Epoch 229/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 1.1690 - accuracy: 0.1650 - val_loss: 1.1800 - val_accuracy: 0.3200
# Epoch 230/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.1671 - accuracy: 0.1650 - val_loss: 1.1849 - val_accuracy: 0.3200
# Epoch 231/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1601 - accuracy: 0.1650 - val_loss: 1.1645 - val_accuracy: 0.3200
# Epoch 232/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.1557 - accuracy: 0.1650 - val_loss: 1.1597 - val_accuracy: 0.3200
# Epoch 233/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1510 - accuracy: 0.1650 - val_loss: 1.1477 - val_accuracy: 0.3200
# Epoch 234/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.1486 - accuracy: 0.1650 - val_loss: 1.1334 - val_accuracy: 0.3200
# Epoch 235/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.1424 - accuracy: 0.1650 - val_loss: 1.1572 - val_accuracy: 0.3200
# Epoch 236/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.1367 - accuracy: 0.1650 - val_loss: 1.1684 - val_accuracy: 0.3200
# Epoch 237/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1363 - accuracy: 0.1650 - val_loss: 1.1711 - val_accuracy: 0.3200
# Epoch 238/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1324 - accuracy: 0.1650 - val_loss: 1.1278 - val_accuracy: 0.3200
# Epoch 239/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1273 - accuracy: 0.1650 - val_loss: 1.1190 - val_accuracy: 0.3200
# Epoch 240/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 1.1218 - accuracy: 0.1650 - val_loss: 1.1468 - val_accuracy: 0.3200
# Epoch 241/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1204 - accuracy: 0.1650 - val_loss: 1.1868 - val_accuracy: 0.3200
# Epoch 242/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1202 - accuracy: 0.1650 - val_loss: 1.1481 - val_accuracy: 0.3200
# Epoch 243/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.1085 - accuracy: 0.1650 - val_loss: 1.1216 - val_accuracy: 0.3200
# Epoch 244/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.1015 - accuracy: 0.1650 - val_loss: 1.0774 - val_accuracy: 0.3200
# Epoch 245/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1033 - accuracy: 0.1650 - val_loss: 1.0636 - val_accuracy: 0.3200
# Epoch 246/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.0982 - accuracy: 0.1650 - val_loss: 1.1021 - val_accuracy: 0.3200
# Epoch 247/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.0946 - accuracy: 0.1650 - val_loss: 1.1695 - val_accuracy: 0.3200
# Epoch 248/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.0898 - accuracy: 0.1650 - val_loss: 1.1460 - val_accuracy: 0.3200
# Epoch 249/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 1.0814 - accuracy: 0.1650 - val_loss: 1.0885 - val_accuracy: 0.3200
# Epoch 250/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.0800 - accuracy: 0.1650 - val_loss: 1.0378 - val_accuracy: 0.3200
# Epoch 251/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.0796 - accuracy: 0.1650 - val_loss: 1.0532 - val_accuracy: 0.3200
# Epoch 252/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 1.0759 - accuracy: 0.1650 - val_loss: 1.0929 - val_accuracy: 0.3200
# Epoch 253/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.0663 - accuracy: 0.1650 - val_loss: 1.0915 - val_accuracy: 0.3200
# Epoch 254/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.0601 - accuracy: 0.1650 - val_loss: 1.0595 - val_accuracy: 0.3200
# Epoch 255/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.0562 - accuracy: 0.1650 - val_loss: 1.0519 - val_accuracy: 0.3200
# Epoch 256/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 1.0518 - accuracy: 0.1650 - val_loss: 1.0525 - val_accuracy: 0.3200
# Epoch 257/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0511 - accuracy: 0.1650 - val_loss: 1.0629 - val_accuracy: 0.3200
# Epoch 258/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0458 - accuracy: 0.1650 - val_loss: 1.0497 - val_accuracy: 0.3200
# Epoch 259/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.0392 - accuracy: 0.1650 - val_loss: 1.0709 - val_accuracy: 0.3200
# Epoch 260/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0356 - accuracy: 0.1650 - val_loss: 1.0761 - val_accuracy: 0.3200
# Epoch 261/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0304 - accuracy: 0.1650 - val_loss: 1.0536 - val_accuracy: 0.3200
# Epoch 262/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0269 - accuracy: 0.1650 - val_loss: 1.0468 - val_accuracy: 0.3200
# Epoch 263/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0222 - accuracy: 0.1650 - val_loss: 1.0582 - val_accuracy: 0.3200
# Epoch 264/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0200 - accuracy: 0.1650 - val_loss: 1.0544 - val_accuracy: 0.3200
# Epoch 265/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0165 - accuracy: 0.1650 - val_loss: 1.0670 - val_accuracy: 0.3200
# Epoch 266/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0104 - accuracy: 0.1650 - val_loss: 1.0328 - val_accuracy: 0.3200
# Epoch 267/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0077 - accuracy: 0.1650 - val_loss: 1.0087 - val_accuracy: 0.3200
# Epoch 268/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.0032 - accuracy: 0.1650 - val_loss: 1.0273 - val_accuracy: 0.3200
# Epoch 269/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9976 - accuracy: 0.1650 - val_loss: 1.0449 - val_accuracy: 0.3200
# Epoch 270/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.9940 - accuracy: 0.1650 - val_loss: 1.0486 - val_accuracy: 0.3200
# Epoch 271/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9911 - accuracy: 0.1650 - val_loss: 1.0447 - val_accuracy: 0.3200
# Epoch 272/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9874 - accuracy: 0.1650 - val_loss: 1.0348 - val_accuracy: 0.3200
# Epoch 273/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.9814 - accuracy: 0.1650 - val_loss: 1.0002 - val_accuracy: 0.3200
# Epoch 274/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9782 - accuracy: 0.1650 - val_loss: 0.9819 - val_accuracy: 0.3200
# Epoch 275/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9787 - accuracy: 0.1650 - val_loss: 0.9897 - val_accuracy: 0.3200
# Epoch 276/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9690 - accuracy: 0.1650 - val_loss: 1.0436 - val_accuracy: 0.3200
# Epoch 277/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.9704 - accuracy: 0.1650 - val_loss: 1.0608 - val_accuracy: 0.3200
# Epoch 278/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.9666 - accuracy: 0.1650 - val_loss: 1.0022 - val_accuracy: 0.3200
# Epoch 279/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9568 - accuracy: 0.1650 - val_loss: 0.9551 - val_accuracy: 0.3200
# Epoch 280/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9581 - accuracy: 0.1650 - val_loss: 0.9448 - val_accuracy: 0.3200
# Epoch 281/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9569 - accuracy: 0.1650 - val_loss: 0.9758 - val_accuracy: 0.3200
# Epoch 282/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.9484 - accuracy: 0.1650 - val_loss: 0.9935 - val_accuracy: 0.3200
# Epoch 283/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9470 - accuracy: 0.1650 - val_loss: 0.9779 - val_accuracy: 0.3200
# Epoch 284/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.9429 - accuracy: 0.1650 - val_loss: 0.9385 - val_accuracy: 0.3200
# Epoch 285/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9392 - accuracy: 0.1650 - val_loss: 0.9555 - val_accuracy: 0.3200
# Epoch 286/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9331 - accuracy: 0.1650 - val_loss: 1.0024 - val_accuracy: 0.3200
# Epoch 287/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.9301 - accuracy: 0.1650 - val_loss: 1.0058 - val_accuracy: 0.3200
# Epoch 288/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.9352 - accuracy: 0.1650 - val_loss: 0.9733 - val_accuracy: 0.3200
# Epoch 289/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0
1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8316 - accuracy: 0.1650 - val_loss: 0.8840 - val_accuracy: 0.3200
# Epoch 319/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8243 - accuracy: 0.1650 - val_loss: 0.8400 - val_accuracy: 0.3200
# Epoch 320/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.8267 - accuracy: 0.1650 - val_loss: 0.8317 - val_accuracy: 0.3200
# Epoch 321/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.8283 - accuracy: 0.1650 - val_loss: 0.8362 - val_accuracy: 0.3200
# Epoch 322/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8132 - accuracy: 0.1650 - val_loss: 0.9093 - val_accuracy: 0.3200
# Epoch 323/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8172 - accuracy: 0.1650 - val_loss: 0.9528 - val_accuracy: 0.3200
# Epoch 324/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8257 - accuracy: 0.1650 - val_loss: 0.8869 - val_accuracy: 0.3200
# Epoch 325/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8069 - accuracy: 0.1650 - val_loss: 0.8027 - val_accuracy: 0.3200
# Epoch 326/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.8169 - accuracy: 0.1650 - val_loss: 0.8000 - val_accuracy: 0.3200
# Epoch 327/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8105 - accuracy: 0.1650 - val_loss: 0.8692 - val_accuracy: 0.3200
# Epoch 328/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8029 - accuracy: 0.1650 - val_loss: 0.9089 - val_accuracy: 0.3200
# Epoch 329/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8027 - accuracy: 0.1650 - val_loss: 0.8548 - val_accuracy: 0.3200
# Epoch 330/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.7964 - accuracy: 0.1650 - val_loss: 0.8076 - val_accuracy: 0.3200
# Epoch 331/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.8011 - accuracy: 0.1650 - val_loss: 0.8141 - val_accuracy: 0.3200
# Epoch 332/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.7902 - accuracy: 0.1650 - val_loss: 0.8097 - val_accuracy: 0.3200
# Epoch 333/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.7862 - accuracy: 0.1650 - val_loss: 0.8420 - val_accuracy: 0.3200
# Epoch 334/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.7819 - accuracy: 0.1650 - val_loss: 0.8848 - val_accuracy: 0.3200
# Epoch 335/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.7901 - accuracy: 0.1650 - val_loss: 0.8724 - val_accuracy: 0.3200
# Epoch 336/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.7788 - accuracy: 0.1650 - val_loss: 0.7913 - val_accuracy: 0.3200
# Epoch 337/1000
# ...
# Epoch 889/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1730 - accuracy: 0.2000 - val_loss: 0.1915 - val_accuracy: 0.1900
# Epoch 890/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1709 - accuracy: 0.2000 - val_loss: 0.1931 - val_accuracy: 0.1900
# Epoch 891/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1737 - accuracy: 0.1988 - val_loss: 0.1904 - val_accuracy: 0.1900
# Epoch 892/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1729 - accuracy: 0.1988 - val_loss: 0.1913 - val_accuracy: 0.1900
# Epoch 893/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1810 - accuracy: 0.2000 - val_loss: 0.2037 - val_accuracy: 0.1900
# Epoch 894/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1913 - accuracy: 0.1988 - val_loss: 0.1923 - val_accuracy: 0.1900
# Epoch 895/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1706 - accuracy: 0.2000 - val_loss: 0.2233 - val_accuracy: 0.1900
# Epoch 896/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1862 - accuracy: 0.2000 - val_loss: 0.2078 - val_accuracy: 0.1900
# Epoch 897/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1770 - accuracy: 0.2000 - val_loss: 0.1920 - val_accuracy: 0.1900
# Epoch 898/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1753 - accuracy: 0.2000 - val_loss: 0.1994 - val_accuracy: 0.1900
# Epoch 899/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1783 - accuracy: 0.1975 - val_loss: 0.1902 - val_accuracy: 0.1900
# Epoch 900/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.
1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1693 - accuracy: 0.2000 - val_loss: 0.1916 - val_accuracy: 0.1900
# Epoch 931/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1700 - accuracy: 0.1988 - val_loss: 0.1906 - val_accuracy: 0.1900
# Epoch 932/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1686 - accuracy: 0.1988 - val_loss: 0.1929 - val_accuracy: 0.1900
# Epoch 933/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1718 - accuracy: 0.1988 - val_loss: 0.1923 - val_accuracy: 0.1900
# Epoch 934/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1691 - accuracy: 0.2000 - val_loss: 0.2026 - val_accuracy: 0.1900
# Epoch 935/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1736 - accuracy: 0.1988 - val_loss: 0.1887 - val_accuracy: 0.1900
# Epoch 936/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1688 - accuracy: 0.2000 - val_loss: 0.1887 - val_accuracy: 0.1900
# Epoch 937/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1698 - accuracy: 0.2000 - val_loss: 0.1926 - val_accuracy: 0.1900
# Epoch 938/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1718 - accuracy: 0.2000 - val_loss: 0.1900 - val_accuracy: 0.1900
# Epoch 939/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1713 - accuracy: 0.1988 - val_loss: 0.1883 - val_accuracy: 0.1900
# Epoch 940/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1784 - accuracy: 0.1988 - val_loss: 0.1889 - val_accuracy: 0.1900
# Epoch 941/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1778 - accuracy: 0.1988 - val_loss: 0.1887 - val_accuracy: 0.1900
# Epoch 942/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1686 - accuracy: 0.2000 - val_loss: 0.1926 - val_accuracy: 0.1900
# Epoch 943/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1714 - accuracy: 0.2000 - val_loss: 0.1906 - val_accuracy: 0.1900
# Epoch 944/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1738 - accuracy: 0.2000 - val_loss: 0.1887 - val_accuracy: 0.1900
# Epoch 945/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1687 - accuracy: 0.2000 - val_loss: 0.1903 - val_accuracy: 0.1900
# Epoch 946/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1667 - accuracy: 0.2000 - val_loss: 0.1891 - val_accuracy: 0.1900
# Epoch 947/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1688 - accuracy: 0.2000 - val_loss: 0.1901 - val_accuracy: 0.1900
# Epoch 948/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1697 - accuracy: 0.1988 - val_loss: 0.1916 - val_accuracy: 0.1900
# Epoch 949/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1693 - accuracy: 0.2000 - val_loss: 0.1894 - val_accuracy: 0.1900
# Epoch 950/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1691 - accuracy: 0.1988 - val_loss: 0.1882 - val_accuracy: 0.1900
# Epoch 951/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1727 - accuracy: 0.1988 - val_loss: 0.1896 - val_accuracy: 0.1900
# Epoch 952/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1689 - accuracy: 0.2000 - val_loss: 0.1910 - val_accuracy: 0.1900
# Epoch 953/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1710 - accuracy: 0.1988 - val_loss: 0.1999 - val_accuracy: 0.1900
# Epoch 954/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1708 - accuracy: 0.1988 - val_loss: 0.1876 - val_accuracy: 0.1900
# Epoch 955/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1692 - accuracy: 0.2000 - val_loss: 0.1894 - val_accuracy: 0.1900
# Epoch 956/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1798 - accuracy: 0.1988 - val_loss: 0.1940 - val_accuracy: 0.1900
# Epoch 957/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1799 - accuracy: 0.1975 - val_loss: 0.1930 - val_accuracy: 0.1900
# Epoch 958/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1717 - accuracy: 0.2000 - val_loss: 0.2063 - val_accuracy: 0.1900
# Epoch 959/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1732 - accuracy: 0.1988 - val_loss: 0.1958 - val_accuracy: 0.1900
# Epoch 960/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1671 - accuracy: 0.2000 - val_loss: 0.1877 - val_accuracy: 0.1900
# Epoch 961/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1696 - accuracy: 0.1988 - val_loss: 0.1928 - val_accuracy: 0.1900
# Epoch 962/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1676 - accuracy: 0.1988 - val_loss: 0.1956 - val_accuracy: 0.1900
# Epoch 963/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1720 - accuracy: 0.2000 - val_loss: 0.2132 - val_accuracy: 0.1900
# Epoch 964/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1788 - accuracy: 0.1975 - val_loss: 0.1873 - val_accuracy: 0.1900
# Epoch 965/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1730 - accuracy: 0.1988 - val_loss: 0.1883 - val_accuracy: 0.1900
# Epoch 966/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1758 - accuracy: 0.2000 - val_loss: 0.2129 - val_accuracy: 0.1900
# Epoch 967/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1793 - accuracy: 0.2000 - val_loss: 0.1944 - val_accuracy: 0.1900
# Epoch 968/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1759 - accuracy: 0.2000 - val_loss: 0.1890 - val_accuracy: 0.1900
# Epoch 969/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1776 - accuracy: 0.2000 - val_loss: 0.1981 - val_accuracy: 0.1900
# Epoch 970/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1670 - accuracy: 0.1988 - val_loss: 0.1931 - val_accuracy: 0.1900
# Epoch 971/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1741 - accuracy: 0.1988 - val_loss: 0.1886 - val_accuracy: 0.1900
# Epoch 972/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1730 - accuracy: 0.1988 - val_loss: 0.2016 - val_accuracy: 0.1900
# Epoch 973/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2025 - accuracy: 0.2000 - val_loss: 0.1924 - val_accuracy: 0.1900
# Epoch 974/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1837 - accuracy: 0.1975 - val_loss: 0.1974 - val_accuracy: 0.1900
# Epoch 975/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1806 - accuracy: 0.1988 - val_loss: 0.1937 - val_accuracy: 0.1900
# Epoch 976/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1685 - accuracy: 0.2000 - val_loss: 0.1879 - val_accuracy: 0.1900
# Epoch 977/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1647 - accuracy: 0.2000 - val_loss: 0.1891 - val_accuracy: 0.1900
# Epoch 978/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1664 - accuracy: 0.2000 - val_loss: 0.1955 - val_accuracy: 0.1900
# Epoch 979/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1684 - accuracy: 0.2000 - val_loss: 0.1879 - val_accuracy: 0.1900
# Epoch 980/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1714 - accuracy: 0.1988 - val_loss: 0.1877 - val_accuracy: 0.1900
# Epoch 981/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1759 - accuracy: 0.1988 - val_loss: 0.1875 - val_accuracy: 0.1900
# Epoch 982/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1709 - accuracy: 0.2000 - val_loss: 0.1894 - val_accuracy: 0.1900
# Epoch 983/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1688 - accuracy: 0.1988 - val_loss: 0.1902 - val_accuracy: 0.1900
# Epoch 984/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1689 - accuracy: 0.2000 - val_loss: 0.1900 - val_accuracy: 0.1900
# Epoch 985/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1677 - accuracy: 0.1988 - val_loss: 0.1874 - val_accuracy: 0.1900
# Epoch 986/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1666 - accuracy: 0.1988 - val_loss: 0.1889 - val_accuracy: 0.1900
# Epoch 987/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1684 - accuracy: 0.2000 - val_loss: 0.1871 - val_accuracy: 0.1900
# Epoch 988/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1655 - accuracy: 0.2000 - val_loss: 0.1912 - val_accuracy: 0.1900
# Epoch 989/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1663 - accuracy: 0.1988 - val_loss: 0.1918 - val_accuracy: 0.1900
# Epoch 990/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1695 - accuracy: 0.2000 - val_loss: 0.1954 - val_accuracy: 0.1900
# Epoch 991/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1730 - accuracy: 0.1988 - val_loss: 0.1893 - val_accuracy: 0.1900
# Epoch 992/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1664 - accuracy: 0.2000 - val_loss: 0.1869 - val_accuracy: 0.1900
# Epoch 993/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1663 - accuracy: 0.1988 - val_loss: 0.1866 - val_accuracy: 0.1900
# Epoch 994/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1651 - accuracy: 0.1988 - val_loss: 0.1885 - val_accuracy: 0.1900
# Epoch 995/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1676 - accuracy: 0.2000 - val_loss: 0.1877 - val_accuracy: 0.1900
# Epoch 996/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1799 - accuracy: 0.1975 - val_loss: 0.1900 - val_accuracy: 0.1900
# Epoch 997/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1895 - accuracy: 0.1988 - val_loss: 0.1951 - val_accuracy: 0.1900
# Epoch 998/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1959 - accuracy: 0.1988 - val_loss: 0.1916 - val_accuracy: 0.1900
# Epoch 999/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1812 - accuracy: 0.1988 - val_loss: 0.1867 - val_accuracy: 0.1900
# Epoch 1000/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1734 - accuracy: 0.1988 - val_loss: 0.1877 - val_accuracy: 0.1900

# %%
# 学習経過の可視化(大きさ)

val_loss_array = []
for i in range(len(history_size_array)):
    val_loss_array.append(history_size_array[i].history['val_loss'])
plt.figure(figsize=(10,6))
nb_epoch = len(val_loss_array[i])
for i in range(len(val_loss_array)):
    plt.plot(range(nb_epoch), val_loss_array[i], marker='.', label='val_loss_data%d'%(250*(i+1)))
plt.legend(loc='best', fontsize=10)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('val_loss')
plt.show()

# %%
for i in range(len(val_loss_array)):
    print(val_loss_array[i][-1])
# Out:
# 0.4012444317340851
# 0.3010593354701996
# 0.2779354751110077
# 0.18774551153182983

# %%
# 位置推定のモデル
model_position_array = []

for i in range(4):
    position_model = Sequential()
    ### 畳み込み層
    position_model.add(Conv1D(32, 3, padding='same', activation='tanh', input_shape=(50, 1)))
    ### プーリング層
    position_model.add(MaxPooling1D(2, padding='same'))
    ### Flatten層
    position_model.add(Flatten())
    ### 全結合層
    position_model.add(Dense(2, activation='linear'))
    ### optimizer
    adam = keras.optimizers.Adam()
    ### コンパイル
    position_model.compile(loss='mse', optimizer=adam, metrics=['accuracy'])
    ### 配列にいれる
    model_position_array.append(position_model)

# %%
# 学習ループ
history_position_array = []
for i in range(len(model_position_array)):
    epochs = 3000
    batch_size = 128
    history_position_array.append(model_position_array[i].fit(position_x_train_list[i], position_y_train_list[i], batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(position_x_test_list[i], position_y_test_list[i])))
# Out:
# Epoch 1/3000
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1380 - accuracy: 0.5800 - val_loss: 0.0995 - val_accuracy: 0.6400
# Epoch 2/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1017 - accuracy: 0.5150 - val_loss: 0.1196 - val_accuracy: 0.5800
# Epoch 3/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1180 - accuracy: 0.4300 - val_loss: 0.0887 - val_accuracy: 0.6000
# Epoch 4/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0845 - accuracy: 0.5400 - val_loss: 0.0996 - val_accuracy: 0.4200
# Epoch 5/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0902 - accuracy: 0.5750 - val_loss: 0.1058 - val_accuracy: 0.4200
# Epoch 6/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0925 - accuracy: 0.5750 - val_loss: 0.0882 - val_accuracy: 0.4200
# Epoch 7/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0806 - accuracy: 0.6400 - val_loss: 0.0813 - val_accuracy: 0.6400
# Epoch 8/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0778 - accuracy: 0.5300 - val_loss: 0.0845 - val_accuracy: 0.6400
# Epoch 9/3000
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0783 - accuracy: 0.5050 - val_loss: 0.0854 - val_accuracy: 0.7000
# Epoch 10/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0756 - accuracy: 0.6200 - val_loss: 0.0828 - val_accuracy: 0.5200
# Epoch 11/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0723 - accuracy: 0.6450 - val_loss: 0.0807 - val_accuracy: 0.4800
# Epoch 12/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0724 - accuracy: 0.6350 - val_loss: 0.0804 - val_accuracy: 0.5000
# Epoch 13/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0731 - accuracy: 0.6400 - val_loss: 0.0781 - val_accuracy: 0.5200
# Epoch 14/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0699 - accuracy: 0.6650 - val_loss: 0.0793 - val_accuracy: 0.5200
# Epoch 15/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0698 - accuracy: 0.6850 - val_loss: 0.0797 - val_accuracy: 0.7400
# Epoch 16/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0705 - accuracy: 0.6800 - val_loss: 0.0758 - val_accuracy: 0.6800
# Epoch 17/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0686 - accuracy: 0.6550 - val_loss: 0.0748 - val_accuracy: 0.7200
# Epoch 18/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0681 - accuracy: 0.7000 - val_loss: 0.0762 - val_accuracy: 0.5200
# Epoch 19/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0678 - accuracy: 0.6800 - val_loss: 0.0759 - val_accuracy: 0.5200
# Epoch 20/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0672 - accuracy: 0.6850 - val_loss: 0.0747 - val_accuracy: 0.5200
# Epoch 21/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0664 - accuracy: 0.6850 - val_loss: 0.0739 - val_accuracy: 0.7600
# Epoch 22/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0667 - accuracy: 0.6900 - val_loss: 0.0738 - val_accuracy: 0.7400
# Epoch 23/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0663 - accuracy: 0.6700 - val_loss: 0.0742 - val_accuracy: 0.5200
# Epoch 24/3000
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0659 - accuracy: 0.6900 - val_loss: 0.0761 - val_accuracy: 0.5400
# Epoch 25/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0658 - accuracy: 0.6850 - val_loss: 0.0734 - val_accuracy: 0.5200
# Epoch 26/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0656 - accuracy: 0.7200 - val_loss: 0.0719 - val_accuracy: 0.7400
# Epoch 27/3000
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0651 - accuracy: 0.6700 - val_loss: 0.0740 - val_accuracy: 0.6800
# Epoch 28/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0650 - accuracy: 0.6950 - val_loss: 0.0764 - val_accuracy: 0.5200
# Epoch 29/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0651 - accuracy: 0.7000 - val_loss: 0.0732 - val_accuracy: 0.5200
# Epoch 30/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0642 - accuracy: 0.7100 - val_loss: 0.0716 - val_accuracy: 0.6600
# Epoch 31/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0643 - accuracy: 0.7000 - val_loss: 0.0720 - val_accuracy: 0.6400
# Epoch 32/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0635 - accuracy: 0.7100 - val_loss: 0.0748 - val_accuracy: 0.5400
# Epoch 33/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0640 - accuracy: 0.7050 - val_loss: 0.0733 - val_accuracy: 0.6200
# Epoch 34/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0631 - accuracy: 0.7100 - val_loss: 0.0710 - val_accuracy: 0.7000
# Epoch 35/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0637 - accuracy: 0.7150 - val_loss: 0.0713 - val_accuracy: 0.5400
# Epoch 36/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0628 - accuracy: 0.7000 - val_loss: 0.0751 - val_accuracy: 0.5400
# Epoch 37/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0631 - accuracy: 0.7050 - val_loss: 0.0729 - val_accuracy: 0.5600
# Epoch 38/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0622 - accuracy: 0.7050 - val_loss: 0.0700 - val_accuracy: 0.8200
# Epoch 39/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0626 - accuracy: 0.7100 - val_loss: 0.0699 - val_accuracy: 0.7200
# Epoch 40/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0619 - accuracy: 0.7200 - val_loss: 0.0733 - val_accuracy: 0.5400
# Epoch 41/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0623 - accuracy: 0.6850 - val_loss: 0.0760 - val_accuracy: 0.5400
# Epoch 42/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0628 - accuracy: 0.7100 - val_loss: 0.0698 - val_accuracy: 0.7200
# Epoch 43/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0611 - accuracy: 0.6950 - val_loss: 0.0689 - val_accuracy: 0.7800
# Epoch 44/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0614 - accuracy: 0.7150 - val_loss: 0.0705 - val_accuracy: 0.5400
# Epoch 45/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0606 - accuracy: 0.7200 - val_loss: 0.0727 - val_accuracy: 0.5400
# Epoch 46/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0610 - accuracy: 0.7000 - val_loss: 0.0705 - val_accuracy: 0.5400
# Epoch 47/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0601 - accuracy: 0.7250 - val_loss: 0.0682 - val_accuracy: 0.7600
# Epoch 48/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0609 - accuracy: 0.7150 - val_loss: 0.0691 - val_accuracy: 0.6800
# Epoch 49/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0596 - accuracy: 0.7400 - val_loss: 0.0730 - val_accuracy: 0.5600
# Epoch 50/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0605 - accuracy: 0.7200 - val_loss: 0.0706 - val_accuracy: 0.5600
# Epoch 51/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0598 - accuracy: 0.7250 - val_loss: 0.0681 - val_accuracy: 0.6400
# Epoch 52/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0599 - accuracy: 0.7250 - val_loss: 0.0687 - val_accuracy: 0.5600
# Epoch 53/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0592 - accuracy: 0.7200 - val_loss: 0.0682 - val_accuracy: 0.6200
# Epoch 54/3000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0590 - accuracy: 0.7450 - val_loss: 0.0680 - val_accuracy: 0.7200
# Epoch 55/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0589 - accuracy: 0.7450 - val_loss: 0.0693 - val_accuracy: 0.6400
# Epoch 56/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0586 - accuracy: 0.7300 - val_loss: 0.0684 - val_accuracy: 0.6000
# Epoch 57/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0583 - accuracy: 0.7300 - val_loss: 0.0677 - val_accuracy: 0.6000
# Epoch 58/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0582 - accuracy: 0.7200 - val_loss: 0.0678 - val_accuracy: 0.5600
# Epoch 59/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0584 - accuracy: 0.7300 - val_loss: 0.0686 - val_accuracy: 0.5600
# Epoch 60/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0580 - accuracy: 0.7250 - val_loss: 0.0698 - val_accuracy: 0.5400
# Epoch 61/3000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0579 - accuracy: 0.7150 - val_loss: 0.0666 - val_accuracy: 0.7400
# Epoch 62/3000
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0577 - accuracy: 0.7400 - val_loss: 0.0662 - val_accuracy: 0.7600
# Epoch 63/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0576 - accuracy: 0.7500 - val_loss: 0.0687 - val_accuracy: 0.5400
# Epoch 64/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0575 - accuracy: 0.7200 - val_loss: 0.0698 - val_accuracy: 0.6000
# Epoch 65/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0579 - accuracy: 0.7300 - val_loss: 0.0660 - val_accuracy: 0.7600
# Epoch 66/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0572 - accuracy: 0.7400 - val_loss: 0.0662 - val_accuracy: 0.6200
# Epoch 67/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0571 - accuracy: 0.7250 - val_loss: 0.0674 - val_accuracy: 0.5600
# Epoch 68/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0570 - accuracy: 0.7150 - val_loss: 0.0682 - val_accuracy: 0.5600
# Epoch 69/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0567 - accuracy: 0.7400 - val_loss: 0.0661 - val_accuracy: 0.8000
# Epoch 70/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0566 - accuracy: 0.7200 - val_loss: 0.0658 - val_accuracy: 0.7400
# Epoch 71/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0562 - accuracy: 0.7550 - val_loss: 0.0660 - val_accuracy: 0.6000
# Epoch 72/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0561 - accuracy: 0.7250 - val_loss: 0.0656 - val_accuracy: 0.6000
# Epoch 73/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0559 - accuracy: 0.7350 - val_loss: 0.0659 - val_accuracy: 0.6600
# Epoch 74/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0558 - accuracy: 0.7550 - val_loss: 0.0666 - val_accuracy: 0.6600
# Epoch 75/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0560 - accuracy: 0.7300 - val_loss: 0.0657 - val_accuracy: 0.6000
# Epoch 76/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0554 - accuracy: 0.7300 - val_loss: 0.0650 - val_accuracy: 0.7600
# Epoch 77/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0555 - accuracy: 0.7500 - val_loss: 0.0654 - val_accuracy: 0.6600
# Epoch 78/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0554 - accuracy: 0.7350 - val_loss: 0.0668 - val_accuracy: 0.5600
# Epoch 79/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0555 - accuracy: 0.7200 - val_loss: 0.0668 - val_accuracy: 0.5600
# Epoch 80/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0552 - accuracy: 0.7350 - val_loss: 0.0650 - val_accuracy: 0.8200
# Epoch 81/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0555 - accuracy: 0.7500 - val_loss: 0.0640 - val_accuracy: 0.7600
# Epoch 82/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0558 - accuracy: 0.7400 - val_loss: 0.0656 - val_accuracy: 0.5400
# Epoch 83/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0546 - accuracy: 0.7300 - val_loss: 0.0634 - val_accuracy: 0.7600
# Epoch 84/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0549 - accuracy: 0.7550 - val_loss: 0.0645 - val_accuracy: 0.7800
# Epoch 85/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0548 - accuracy: 0.7650 - val_loss: 0.0669 - val_accuracy: 0.5400
# Epoch 86/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0548 - accuracy: 0.7300 - val_loss: 0.0643 - val_accuracy: 0.5600
# Epoch 87/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0547 - accuracy: 0.7250 - val_loss: 0.0643 - val_accuracy: 0.6000
# Epoch 88/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0553 - accuracy: 0.7200 - val_loss: 0.0651 - val_accuracy: 0.7200
# Epoch 89/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0541 - accuracy: 0.7600 - val_loss: 0.0648 - val_accuracy: 0.5600
# Epoch 90/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0543 - accuracy: 0.7250 - val_loss: 0.0643 - val_accuracy: 0.5600
# Epoch 91/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0544 - accuracy: 0.7300 - val_loss: 0.0643 - val_accuracy: 0.6400
# Epoch 92/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0544 - accuracy: 0.7500 - val_loss: 0.0650 - val_accuracy: 0.6200
# Epoch 93/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0540 - accuracy: 0.7450 - val_loss: 0.0655 - val_accuracy: 0.5600
# Epoch 94/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0541 - accuracy: 0.7250 - val_loss: 0.0625 - val_accuracy: 0.7000
# Epoch 95/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0538 - accuracy: 0.7500 - val_loss: 0.0643 - val_accuracy: 0.7200
# Epoch 96/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0535 - accuracy: 0.7450 - val_loss: 0.0666 - val_accuracy: 0.5800
# Epoch 97/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0541 - accuracy: 0.7250 - val_loss: 0.0628 - val_accuracy: 0.6600
# Epoch 98/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0540 - accuracy: 0.7350 - val_loss: 0.0627 - val_accuracy: 0.7000
# Epoch 99/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0535 - accuracy: 0.7300 - val_loss: 0.0662 - val_accuracy: 0.5400
# Epoch 100/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0536 - accuracy: 0.7300 - val_loss: 0.0623 - val_accuracy: 0.7000
# Epoch 101/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0534 - accuracy: 0.7600 - val_loss: 0.0621 - val_accuracy: 0.6800
# Epoch 102/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0546 - accuracy: 0.7250 - val_loss: 0.0622 - val_accuracy: 0.6800
# Epoch 103/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0530 - accuracy: 0.7750 - val_loss: 0.0646 - val_accuracy: 0.8600
# Epoch 104/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0549 - accuracy: 0.7550 - val_loss: 0.0642 - val_accuracy: 0.6200
# Epoch 105/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0528 - accuracy: 0.7300 - val_loss: 0.0626 - val_accuracy: 0.6000
# Epoch 106/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0548 - accuracy: 0.7350 - val_loss: 0.0634 - val_accuracy: 0.5800
# Epoch 107/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0527 - accuracy: 0.7300 - val_loss: 0.0684 - val_accuracy: 0.5800
# Epoch 108/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0543 - accuracy: 0.7300 - val_loss: 0.0615 - val_accuracy: 0.7400
# Epoch 109/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0534 - accuracy: 0.7550 - val_loss: 0.0612 - val_accuracy: 0.7000
# Epoch 110/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0530 - accuracy: 0.7550 - val_loss: 0.0661 - val_accuracy: 0.5600
# Epoch 111/3000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0538 - accuracy: 0.7350 - val_loss: 0.0623 - val_accuracy: 0.8400
# Epoch 112/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0532 - accuracy: 0.7400 - val_loss: 0.0608 - val_accuracy: 0.7200
# Epoch 113/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0528 - accuracy: 0.7500 - val_loss: 0.0648 - val_accuracy: 0.5600
# Epoch 114/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0538 - accuracy: 0.7450 - val_loss: 0.0642 - val_accuracy: 0.6000
# Epoch 115/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0533 - accuracy: 0.7400 - val_loss: 0.0603 - val_accuracy: 0.8200
# Epoch 116/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0528 - accuracy: 0.7500 - val_loss: 0.0632 - val_accuracy: 0.6600
# Epoch 117/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0527 - accuracy: 0.7450 - val_loss: 0.0638 - val_accuracy: 0.6000
# Epoch 118/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0527 - accuracy: 0.7350 - val_loss: 0.0610 - val_accuracy: 0.6400
# Epoch 119/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0531 - accuracy: 0.7400 - val_loss: 0.0619 - val_accuracy: 0.7400
# Epoch 120/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0524 - accuracy: 0.7400 - val_loss: 0.0662 - val_accuracy: 0.6000
# Epoch 121/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0531 - accuracy: 0.7300 - val_loss: 0.0606 - val_accuracy: 0.6800
# Epoch 122/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0526 - accuracy: 0.7550 - val_loss: 0.0619 - val_accuracy: 0.5600
# Epoch 123/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0519 - accuracy: 0.7400 - val_loss: 0.0652 - val_accuracy: 0.6000
# Epoch 124/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0536 - accuracy: 0.7500 - val_loss: 0.0613 - val_accuracy: 0.8800
# Epoch 125/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0516 - accuracy: 0.7500 - val_loss: 0.0610 - val_accuracy: 0.6400
# Epoch 126/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0537 - accuracy: 0.7400 - val_loss: 0.0634 - val_accuracy: 0.5400
# Epoch 127/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0519 - accuracy: 0.7300 - val_loss: 0.0668 - val_accuracy: 0.6000
# Epoch 128/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0528 - accuracy: 0.7400 - val_loss: 0.0602 - val_accuracy: 0.8200
# Epoch 129/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0527 - accuracy: 0.6800 - val_loss: 0.0596 - val_accuracy: 0.8200
# Epoch 130/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0526 - accuracy: 0.7400 - val_loss: 0.0652 - val_accuracy: 0.5400
# Epoch 131/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0529 - accuracy: 0.7250 - val_loss: 0.0638 - val_accuracy: 0.6600
# Epoch 132/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0515 - accuracy: 0.7650 - val_loss: 0.0593 - val_accuracy: 0.8600
# Epoch 133/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0529 - accuracy: 0.7450 - val_loss: 0.0608 - val_accuracy: 0.6000
# Epoch 134/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0531 - accuracy: 0.7400 - val_loss: 0.0645 - val_accuracy: 0.5600
# Epoch 135/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0513 - accuracy: 0.7350 - val_loss: 0.0593 - val_accuracy: 0.8400
# Epoch 136/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0531 - accuracy: 0.7350 - val_loss: 0.0593 - val_accuracy: 0.8400
# Epoch 137/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0510 - accuracy: 0.7450 - val_loss: 0.0676 - val_accuracy: 0.5400
# Epoch 138/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0536 - accuracy: 0.7250 - val_loss: 0.0633 - val_accuracy: 0.5600
# Epoch 139/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0513 - accuracy: 0.7500 - val_loss: 0.0593 - val_accuracy: 0.8600
# Epoch 140/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0532 - accuracy: 0.7900 - val_loss: 0.0612 - val_accuracy: 0.8200
# Epoch 141/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0523 - accuracy: 0.7450 - val_loss: 0.0654 - val_accuracy: 0.5600
# Epoch 142/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0519 - accuracy: 0.7450 - val_loss: 0.0594 - val_accuracy: 0.7200
# Epoch 143/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0523 - accuracy: 0.7650 - val_loss: 0.0597 - val_accuracy: 0.7400
# Epoch 144/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0506 - accuracy: 0.7650 - val_loss: 0.0661 - val_accuracy: 0.5800
# Epoch 145/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0525 - accuracy: 0.7350 - val_loss: 0.0606 - val_accuracy: 0.6400
# Epoch 146/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0515 - accuracy: 0.7600 - val_loss: 0.0591 - val_accuracy: 0.7600
# Epoch 147/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0509 - accuracy: 0.7750 - val_loss: 0.0633 - val_accuracy: 0.7000
# Epoch 148/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0519 - accuracy: 0.7650 - val_loss: 0.0629 - val_accuracy: 0.6400
# Epoch 149/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0516 - accuracy: 0.7600 - val_loss: 0.0595 - val_accuracy: 0.6800
# Epoch 150/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0516 - accuracy: 0.7600 - val_loss: 0.0599 - val_accuracy: 0.7400
# Epoch 151/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0507 - accuracy: 0.7700 - val_loss: 0.0610 - val_accuracy: 0.7200
# Epoch 152/3000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0507 - accuracy: 0.7550 - val_loss: 0.0611 - val_accuracy: 0.5800
# Epoch 153/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0508 - accuracy: 0.7400 - val_loss: 0.0600 - val_accuracy: 0.6400
# Epoch 154/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0505 - accuracy: 0.7550 - val_loss: 0.0613 - val_accuracy: 0.6400
# Epoch 155/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0508 - accuracy: 0.7550 - val_loss: 0.0608 - val_accuracy: 0.6800
# Epoch 156/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.
3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0501 - accuracy: 0.7500 - val_loss: 0.0621 - val_accuracy: 0.6000
# Epoch 187/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0501 - accuracy: 0.7400 - val_loss: 0.0583 - val_accuracy: 0.7400
# Epoch 188/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0503 - accuracy: 0.7700 - val_loss: 0.0600 - val_accuracy: 0.6000
# Epoch 189/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0497 - accuracy: 0.7550 - val_loss: 0.0630 - val_accuracy: 0.6000
# Epoch 190/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0507 - accuracy: 0.7650 - val_loss: 0.0585 - val_accuracy: 0.7400
# Epoch 191/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0500 - accuracy: 0.7900 - val_loss: 0.0585 - val_accuracy: 0.7400
# Epoch 192/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0498 - accuracy: 0.7700 - val_loss: 0.0595 - val_accuracy: 0.6000
# Epoch 193/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0494 - accuracy: 0.7500 - val_loss: 0.0621 - val_accuracy: 0.5800
# Epoch 194/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0504 - accuracy: 0.7500 - val_loss: 0.0584 - val_accuracy: 0.8200
# Epoch 195/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0509 - accuracy: 0.7550 - val_loss: 0.0578 - val_accuracy: 0.8000
# Epoch 196/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0499 - accuracy: 0.7750 - val_loss: 0.0653 - val_accuracy: 0.5400
# Epoch 197/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0522 - accuracy: 0.7300 - val_loss: 0.0592 - val_accuracy: 0.7400
# Epoch 198/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0502 - accuracy: 0.7650 - val_loss: 0.0579 - val_accuracy: 0.8000
# Epoch 199/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0518 - accuracy: 0.7500 - val_loss: 0.0628 - val_accuracy: 0.5600
# Epoch 200/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0505 - accuracy: 0.7450 - val_loss: 0.0626 - val_accuracy: 0.5800
# Epoch 201/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0502 - accuracy: 0.7650 - val_loss: 0.0577 - val_accuracy: 0.8600
# Epoch 202/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0500 - accuracy: 0.7950 - val_loss: 0.0589 - val_accuracy: 0.6400
# Epoch 203/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0495 - accuracy: 0.7400 - val_loss: 0.0618 - val_accuracy: 0.5600
# Epoch 204/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0500 - accuracy: 0.7650 - val_loss: 0.0591 - val_accuracy: 0.7600
# Epoch 205/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0496 - accuracy: 0.7700 - val_loss: 0.0584 - val_accuracy: 0.7600
# Epoch 206/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0494 - accuracy: 0.7700 - val_loss: 0.0584 - val_accuracy: 0.6600
# Epoch 207/3000
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0499 - accuracy: 0.7600 - val_loss: 0.0591 - val_accuracy: 0.6800
# Epoch 208/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0492 - accuracy: 0.7800 - val_loss: 0.0584 - val_accuracy: 0.7200
# Epoch 209/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0495 - accuracy: 0.7600 - val_loss: 0.0596 - val_accuracy: 0.6000
# Epoch 210/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0495 - accuracy: 0.7650 - val_loss: 0.0594 - val_accuracy: 0.7400
# Epoch 211/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0492 - accuracy: 0.7800 - val_loss: 0.0581 - val_accuracy: 0.6800
# Epoch 212/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0498 - accuracy: 0.7600 - val_loss: 0.0597 - val_accuracy: 0.5800
# Epoch 213/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0496 - accuracy: 0.7550 - val_loss: 0.0594 - val_accuracy: 0.7600
# Epoch 214/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0497 - accuracy: 0.8100 - val_loss: 0.0580 - val_accuracy: 0.8200
# Epoch 215/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0493 - accuracy: 0.7700 - val_loss: 0.0599 - val_accuracy: 0.5600
# Epoch 216/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0497 - accuracy: 0.7550 - val_loss: 0.0599 - val_accuracy: 0.6400
# Epoch 217/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0493 - accuracy: 0.7700 - val_loss: 0.0599 - val_accuracy: 0.7800
# Epoch 218/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0493 - accuracy: 0.7800 - val_loss: 0.0593 - val_accuracy: 0.5800
# Epoch 219/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0494 - accuracy: 0.7450 - val_loss: 0.0590 - val_accuracy: 0.6000
# Epoch 220/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0488 - accuracy: 0.7700 - val_loss: 0.0587 - val_accuracy: 0.8600
# Epoch 221/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0499 - accuracy: 0.7900 - val_loss: 0.0582 - val_accuracy: 0.7600
# Epoch 222/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0489 - accuracy: 0.7800 - val_loss: 0.0589 - val_accuracy: 0.5800
# Epoch 223/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0497 - accuracy: 0.7550 - val_loss: 0.0587 - val_accuracy: 0.7400
# Epoch 224/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0488 - accuracy: 0.7650 - val_loss: 0.0605 - val_accuracy: 0.8400
# Epoch 225/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0505 - accuracy: 0.7750 - val_loss: 0.0594 - val_accuracy: 0.6000
# Epoch 226/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0494 - accuracy: 0.7500 - val_loss: 0.0620 - val_accuracy: 0.5400
# Epoch 227/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0510 - accuracy: 0.7500 - val_loss: 0.0592 - val_accuracy: 0.7800
# Epoch 228/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0500 - accuracy: 0.7800 - val_loss: 0.0582 - val_accuracy: 0.8600
# Epoch 229/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0492 - accuracy: 0.7800 - val_loss: 0.0616 - val_accuracy: 0.5400
# Epoch 230/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0500 - accuracy: 0.7300 - val_loss: 0.0582 - val_accuracy: 0.7000
# Epoch 231/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0499 - accuracy: 0.7500 - val_loss: 0.0592 - val_accuracy: 0.7800
# Epoch 232/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0496 - accuracy: 0.7300 - val_loss: 0.0653 - val_accuracy: 0.5600
# Epoch 233/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0521 - accuracy: 0.7250 - val_loss: 0.0594 - val_accuracy: 0.5800
# Epoch 234/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0514 - accuracy: 0.6550 - val_loss: 0.0573 - val_accuracy: 0.7800
# Epoch 235/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0502 - accuracy: 0.7200 - val_loss: 0.0654 - val_accuracy: 0.5600
# Epoch 236/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0513 - accuracy: 0.7450 - val_loss: 0.0623 - val_accuracy: 0.5800
# Epoch 237/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0488 - accuracy: 0.7700 - val_loss: 0.0572 - val_accuracy: 0.8600
# Epoch 238/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0511 - accuracy: 0.8100 - val_loss: 0.0583 - val_accuracy: 0.7200
# Epoch 239/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0490 - accuracy: 0.7700 - val_loss: 0.0639 - val_accuracy: 0.5600
# Epoch 240/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0497 - accuracy: 0.7450 - val_loss: 0.0571 - val_accuracy: 0.8400
# Epoch 241/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0493 - accuracy: 0.7750 - val_loss: 0.0570 - val_accuracy: 0.8600
# Epoch 242/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0489 - accuracy: 0.8100 - val_loss: 0.0629 - val_accuracy: 0.5600
# Epoch 243/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0506 - accuracy: 0.7250 - val_loss: 0.0607 - val_accuracy: 0.5800
# Epoch 244/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0493 - accuracy: 0.7950 - val_loss: 0.0570 - val_accuracy: 0.7800
# Epoch 245/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0507 - accuracy: 0.7200 - val_loss: 0.0594 - val_accuracy: 0.7200
# Epoch 246/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0492 - accuracy: 0.7700 - val_loss: 0.0596 - val_accuracy: 0.6000
# Epoch 247/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0493 - accuracy: 0.7650 - val_loss: 0.0574 - val_accuracy: 0.7400
# Epoch 248/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0484 - accuracy: 0.7800 - val_loss: 0.0608 - val_accuracy: 0.6000
# Epoch 249/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0491 - accuracy: 0.7600 - val_loss: 0.0592 - val_accuracy: 0.6600
# Epoch 250/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0485 - accuracy: 0.7750 - val_loss: 0.0569 - val_accuracy: 0.8400
# Epoch 251/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0492 - accuracy: 0.7900 - val_loss: 0.0593 - val_accuracy: 0.6600
# Epoch 252/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0487 - accuracy: 0.7600 - val_loss: 0.0612 - val_accuracy: 0.6200
# Epoch 253/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0490 - accuracy: 0.7650 - val_loss: 0.0581 - val_accuracy: 0.6400
# Epoch 254/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0491 - accuracy: 0.8100 - val_loss: 0.0572 - val_accuracy: 0.7600
# Epoch 255/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0490 - accuracy: 0.7850 - val_loss: 0.0601 - val_accuracy: 0.6000
# Epoch 256/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0486 - accuracy: 0.7750 - val_loss: 0.0579 - val_accuracy: 0.7200
# Epoch 257/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0484 - accuracy: 0.7800 - val_loss: 0.0576 - val_accuracy: 0.7400
# Epoch 258/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0485 - accuracy: 0.7800 - val_loss: 0.0573 - val_accuracy: 0.7400
# Epoch 259/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0487 - accuracy: 0.7800 - val_loss: 0.0575 - val_accuracy: 0.7000
# Epoch 260/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0484 - accuracy: 0.7800 - val_loss: 0.0589 - val_accuracy: 0.7400
# Epoch 261/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0486 - accuracy: 0.7850 - val_loss: 0.0595 - val_accuracy: 0.6800
# Epoch 262/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0485 - accuracy: 0.7550 - val_loss: 0.0570 - val_accuracy: 0.7400
# Epoch 263/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0488 - accuracy: 0.7850 - val_loss: 0.0570 - val_accuracy: 0.8800
# Epoch 264/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0493 - accuracy: 0.8050 - val_loss: 0.0585 - val_accuracy: 0.7000
# Epoch 265/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0482 - accuracy: 0.7750 - val_loss: 0.0580 - val_accuracy: 0.6200
# Epoch 266/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0486 - accuracy: 0.7600 - val_loss: 0.0572 - val_accuracy: 0.7400
# Epoch 267/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0482 - accuracy: 0.7800 - val_loss: 0.0594 - val_accuracy: 0.7000
# Epoch 268/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0486 - accuracy: 0.7800 - val_loss: 0.0590 - val_accuracy: 0.6600
# Epoch 269/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0485 - accuracy: 0.7750 - val_loss: 0.0580 - val_accuracy: 0.6000
# Epoch 270/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0485 - accuracy: 0.7650 - val_loss: 0.0601 - val_accuracy: 0.6000
# Epoch 271/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0483 - accuracy: 0.7650 - val_loss: 0.0595 - val_accuracy: 0.7600
# Epoch 272/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0491 - accuracy: 0.7950 - val_loss: 0.0573 - val_accuracy: 0.7600
# Epoch 273/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0485 - accuracy: 0.7750 - val_loss: 0.0593 - val_accuracy: 0.5800
# Epoch 274/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0482 - accuracy: 0.7550 - val_loss: 0.0578 - val_accuracy: 0.7600
# Epoch 275/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0485 - accuracy: 0.7850 - val_loss: 0.0580 - val_accuracy: 0.7400
# Epoch 276/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0483 - accuracy: 0.7700 - val_loss: 0.0594 - val_accuracy: 0.6000
# Epoch 277/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0484 - accuracy: 0.7600 - val_loss: 0.0593 - val_accuracy: 0.7000
# Epoch 278/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0484 - accuracy: 0.7800 - val_loss: 0.0582 - val_accuracy: 0.7400
# Epoch 279/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0480 - accuracy: 0.7950 - val_loss: 0.0569 - val_accuracy: 0.7400
# Epoch 280/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0488 - accuracy: 0.7700 - val_loss: 0.0586 - val_accuracy: 0.6000
# Epoch 281/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0481 - accuracy: 0.7550 - val_loss: 0.0591 - val_accuracy: 0.7600
# Epoch 282/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0487 - accuracy: 0.7800 - val_loss: 0.0568 - val_accuracy: 0.8800
# Epoch 283/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0492 - accuracy: 0.7700 - val_loss: 0.0579 - val_accuracy: 0.6000
# Epoch 284/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0482 - accuracy: 0.7750 - val_loss: 0.0608 - val_accuracy: 0.7400
# Epoch 285/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0490 - accuracy: 0.7950 - val_loss: 0.0579 - val_accuracy: 0.7600
# Epoch 286/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0496 - accuracy: 0.7800 - val_loss: 0.0582 - val_accuracy: 0.6000
# Epoch 287/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0486 - accuracy: 0.7600 - val_loss: 0.0610 - val_accuracy: 0.6800
# Epoch 288/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0487 - accuracy: 0.7900 - val_loss: 0.0570 - val_accuracy: 0.8200
# Epoch 289/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0492 - accuracy: 0.7900 - val_loss: 0.0583 - val_accuracy: 0.6600
# Epoch 290/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0485 - accuracy: 0.7700 - val_loss: 0.0608 - val_accuracy: 0.6600
# Epoch 291/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0483 - accuracy: 0.7750 - val_loss: 0.0580 - val_accuracy: 0.6000
# Epoch 292/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0485 - accuracy: 0.7700 - val_loss: 0.0577 - val_accuracy: 0.7000
# Epoch 293/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0478 - accuracy: 0.7850 - val_loss: 0.0592 - val_accuracy: 0.8800
# Epoch 294/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0487 - accuracy: 0.8050 - val_loss: 0.0569 - val_accuracy: 0.7400
# Epoch 295/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0486 - accuracy: 0.7850 - val_loss: 0.0586 - val_accuracy: 0.5800
# Epoch 296/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0492 - accuracy: 0.7500 - val_loss: 0.0605 - val_accuracy: 0.6600
# Epoch 297/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0479 - accuracy: 0.7900 - val_loss: 0.0564 - val_accuracy: 0.8400
# Epoch 298/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0492 - accuracy: 0.8000 - val_loss: 0.0581 - val_accuracy: 0.6600
# Epoch 299/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0492 - accuracy: 0.7450 - val_loss: 0.0611 - val_accuracy: 0.6000
# Epoch 300/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0482 - accuracy: 0.7850 - val_loss: 0.0565 - val_accuracy: 0.8200
# Epoch 301/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0492 - accuracy: 0.7250 - val_loss: 0.0587 - val_accuracy: 0.6600
# Epoch 302/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0478 - accuracy: 0.7600 - val_loss: 0.0640 - val_accuracy: 0.5400
# Epoch 303/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0496 - accuracy: 0.7400 - val_loss: 0.0567 - val_accuracy: 0.7600
# Epoch 304/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0484 - accuracy: 0.8000 - val_loss: 0.0571 - val_accuracy: 0.7600
# Epoch 305/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0489 - accuracy: 0.7900 - val_loss: 0.0604 - val_accuracy: 0.5800
# Epoch 306/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0496 - accuracy: 0.7550 - val_loss: 0.0580 - val_accuracy: 0.6000
# Epoch 307/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0478 - accuracy: 0.7850 - val_loss: 0.0605 - val_accuracy: 0.6600
# Epoch 308/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0488 - accuracy: 0.7850 - val_loss: 0.0575 - val_accuracy: 0.7000
# Epoch 309/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0488 - accuracy: 0.7700 - val_loss: 0.0569 - val_accuracy: 0.7000
# Epoch 310/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0491 - accuracy: 0.7900 - val_loss: 0.0612 - val_accuracy: 0.7200
# Epoch 311/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0494 - accuracy: 0.7650 - val_loss: 0.0583 - val_accuracy: 0.6600
# Epoch 312/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0476 - accuracy: 0.7750 - val_loss: 0.0566 - val_accuracy: 0.8800
# Epoch 313/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0483 - accuracy: 0.8100 - val_loss: 0.0586 - val_accuracy: 0.7000
# Epoch 314/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0475 - accuracy: 0.7800 - val_loss: 0.0589 - val_accuracy: 0.5800
# Epoch 315/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0477 - accuracy: 0.7650 - val_loss: 0.0571 - val_accuracy: 0.7600
# Epoch 316/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0483 - accuracy: 0.7800 - val_loss: 0.0578 - val_accuracy: 0.7400
# Epoch 317/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0484 - accuracy: 0.7650 - val_loss: 0.0607 - val_accuracy: 0.6000
# Epoch 318/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0483 - accuracy: 0.7500 - val_loss: 0.0575 - val_accuracy: 0.8800
# Epoch 319/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0483 - accuracy: 0.7800 - val_loss: 0.0565 - val_accuracy: 0.7600
# Epoch 320/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0479 - accuracy: 0.7950 - val_loss: 0.0580 - val_accuracy: 0.7600
# Epoch 321/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0477 - accuracy: 0.7800 - val_loss: 0.0591 - val_accuracy: 0.6200
# Epoch 322/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0477 - accuracy: 0.7750 - val_loss: 0.0569 - val_accuracy: 0.7200
# Epoch 323/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0483 - accuracy: 0.8000 - val_loss: 0.0584 - val_accuracy: 0.7600
# Epoch 324/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0482 - accuracy: 0.7700 - val_loss: 0.0606 - val_accuracy: 0.5800
# Epoch 325/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0479 - accuracy: 0.7650 - val_loss: 0.0568 - val_accuracy: 0.7200
# Epoch 326/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0493 - accuracy: 0.7850 - val_loss: 0.0579 - val_accuracy: 0.6200
# Epoch 327/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0477 - accuracy: 0.7600 - val_loss: 0.0635 - val_accuracy: 0.6600
# Epoch 328/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0497 - accuracy: 0.7800 - val_loss: 0.0568 - val_accuracy: 0.8800
# Epoch 329/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0490 - accuracy: 0.8150 - val_loss: 0.0581 - val_accuracy: 0.6000
# Epoch 330/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0483 - accuracy: 0.7550 - val_loss: 0.0611 - val_accuracy: 0.6800
# Epoch 331/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0481 - accuracy: 0.7900 - val_loss: 0.0568 - val_accuracy: 0.8600
# Epoch 332/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0488 - accuracy: 0.8150 - val_loss: 0.0573 - val_accuracy: 0.6600
# Epoch 333/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0477 - accuracy: 0.7900 - val_loss: 0.0620 - val_accuracy: 0.6600
# Epoch 334/3000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0486 - accuracy: 0.7750 - val_loss: 0.0569 - val_accuracy: 0.7800
# Epoch 335/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0478 - accuracy: 0.7900 - val_loss: 0.0578 - val_accuracy: 0.6600
# Epoch 336/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0473 - accuracy: 0.7750 - val_loss: 0.0610 - val_accuracy: 0.6000
# Epoch 337/3000
# ...
# Epoch 2890/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.

# 7/7 [==============================] - 0s 6ms/step - loss: 0.0402 - accuracy: 0.7812 - val_loss: 0.0450 - val_accuracy: 0.7500
# Epoch 2920/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0397 - accuracy: 0.7925 - val_loss: 0.0455 - val_accuracy: 0.7250
# Epoch 2921/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 0.7887 - val_loss: 0.0457 - val_accuracy: 0.7550
# Epoch 2922/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.7825 - val_loss: 0.0436 - val_accuracy: 0.7350
# Epoch 2923/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0387 - accuracy: 0.7887 - val_loss: 0.0448 - val_accuracy: 0.7300
# Epoch 2924/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.7887 - val_loss: 0.0443 - val_accuracy: 0.7500
# Epoch 2925/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0387 - accuracy: 0.7763 - val_loss: 0.0467 - val_accuracy: 0.7000
# Epoch 2926/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0408 - accuracy: 0.7738 - val_loss: 0.0448 - val_accuracy: 0.7350
# Epoch 2927/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0401 - accuracy: 0.7812 - val_loss: 0.0445 - val_accuracy: 0.7500
# Epoch 2928/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0395 - accuracy: 0.8000 - val_loss: 0.0446 - val_accuracy: 0.7400
# Epoch 2929/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0387 - accuracy: 0.7962 - val_loss: 0.0435 - val_accuracy: 0.7350
# Epoch 2930/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0387 - accuracy: 0.7987 - val_loss: 0.0450 - val_accuracy: 0.7600
# Epoch 2931/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0393 - accuracy: 0.7862 - val_loss: 0.0450 - val_accuracy: 0.7400
# Epoch 2932/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0398 - accuracy: 0.7825 - val_loss: 0.0457 - val_accuracy: 0.7550
# Epoch 2933/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0394 - accuracy: 0.7775 - val_loss: 0.0492 - val_accuracy: 0.7350
# Epoch 2934/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0410 - accuracy: 0.7713 - val_loss: 0.0456 - val_accuracy: 0.7600
# Epoch 2935/3000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0404 - accuracy: 0.7850 - val_loss: 0.0463 - val_accuracy: 0.7750
# Epoch 2936/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0403 - accuracy: 0.7987 - val_loss: 0.0437 - val_accuracy: 0.7500
# Epoch 2937/3000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0394 - accuracy: 0.7950 - val_loss: 0.0437 - val_accuracy: 0.7550
# Epoch 2938/3000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0394 - accuracy: 0.7987 - val_loss: 0.0436 - val_accuracy: 0.7400
# Epoch 2939/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0386 - accuracy: 0.7950 - val_loss: 0.0435 - val_accuracy: 0.7500
# Epoch 2940/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.7962 - val_loss: 0.0442 - val_accuracy: 0.7450
# Epoch 2941/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0392 - accuracy: 0.8012 - val_loss: 0.0443 - val_accuracy: 0.7500
# Epoch 2942/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0386 - accuracy: 0.7812 - val_loss: 0.0453 - val_accuracy: 0.7550
# Epoch 2943/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.7937 - val_loss: 0.0458 - val_accuracy: 0.7500
# Epoch 2944/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0397 - accuracy: 0.7900 - val_loss: 0.0472 - val_accuracy: 0.7350
# Epoch 2945/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0408 - accuracy: 0.7862 - val_loss: 0.0456 - val_accuracy: 0.7650
# Epoch 2946/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 0.7875 - val_loss: 0.0435 - val_accuracy: 0.7400
# Epoch 2947/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.7912 - val_loss: 0.0439 - val_accuracy: 0.7550
# Epoch 2948/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0392 - accuracy: 0.7962 - val_loss: 0.0440 - val_accuracy: 0.7550
# Epoch 2949/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.7937 - val_loss: 0.0442 - val_accuracy: 0.7550
# Epoch 2950/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.7925 - val_loss: 0.0438 - val_accuracy: 0.7500
# Epoch 2951/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.7987 - val_loss: 0.0436 - val_accuracy: 0.7350
# Epoch 2952/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 0.7788 - val_loss: 0.0439 - val_accuracy: 0.7450
# Epoch 2953/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 0.7875 - val_loss: 0.0451 - val_accuracy: 0.7450
# Epoch 2954/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0424 - accuracy: 0.7825 - val_loss: 0.0459 - val_accuracy: 0.7650
# Epoch 2955/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0405 - accuracy: 0.8037 - val_loss: 0.0448 - val_accuracy: 0.7500
# Epoch 2956/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0416 - accuracy: 0.7950 - val_loss: 0.0437 - val_accuracy: 0.7400
# Epoch 2957/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0398 - accuracy: 0.7912 - val_loss: 0.0446 - val_accuracy: 0.7400
# Epoch 2958/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.7800 - val_loss: 0.0471 - val_accuracy: 0.7350
# Epoch 2959/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0393 - accuracy: 0.7900 - val_loss: 0.0445 - val_accuracy: 0.7400
# Epoch 2960/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0392 - accuracy: 0.7800 - val_loss: 0.0436 - val_accuracy: 0.7450
# Epoch 2961/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.7900 - val_loss: 0.0439 - val_accuracy: 0.7600
# Epoch 2962/3000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0393 - accuracy: 0.7887 - val_loss: 0.0439 - val_accuracy: 0.7500
# Epoch 2963/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0390 - accuracy: 0.7812 - val_loss: 0.0453 - val_accuracy: 0.7550
# Epoch 2964/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0394 - accuracy: 0.7650 - val_loss: 0.0440 - val_accuracy: 0.7500
# Epoch 2965/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0401 - accuracy: 0.7750 - val_loss: 0.0459 - val_accuracy: 0.7500
# Epoch 2966/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0414 - accuracy: 0.7713 - val_loss: 0.0442 - val_accuracy: 0.7600
# Epoch 2967/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0396 - accuracy: 0.7950 - val_loss: 0.0457 - val_accuracy: 0.7550
# Epoch 2968/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0406 - accuracy: 0.7962 - val_loss: 0.0451 - val_accuracy: 0.7550
# Epoch 2969/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0406 - accuracy: 0.7900 - val_loss: 0.0436 - val_accuracy: 0.7500
# Epoch 2970/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0397 - accuracy: 0.7875 - val_loss: 0.0443 - val_accuracy: 0.7350
# Epoch 2971/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0392 - accuracy: 0.7975 - val_loss: 0.0443 - val_accuracy: 0.7450
# Epoch 2972/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0403 - accuracy: 0.7925 - val_loss: 0.0439 - val_accuracy: 0.7400
# Epoch 2973/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.8000 - val_loss: 0.0456 - val_accuracy: 0.7550
# Epoch 2974/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0397 - accuracy: 0.7887 - val_loss: 0.0469 - val_accuracy: 0.7700
# Epoch 2975/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0394 - accuracy: 0.7962 - val_loss: 0.0479 - val_accuracy: 0.7200
# Epoch 2976/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0414 - accuracy: 0.7600 - val_loss: 0.0451 - val_accuracy: 0.7550
# Epoch 2977/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0403 - accuracy: 0.7525 - val_loss: 0.0441 - val_accuracy: 0.7450
# Epoch 2978/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.7675 - val_loss: 0.0450 - val_accuracy: 0.7300
# Epoch 2979/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.7613 - val_loss: 0.0488 - val_accuracy: 0.7550
# Epoch 2980/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0420 - accuracy: 0.7837 - val_loss: 0.0467 - val_accuracy: 0.7350
# Epoch 2981/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0414 - accuracy: 0.8012 - val_loss: 0.0443 - val_accuracy: 0.7550
# Epoch 2982/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0400 - accuracy: 0.8025 - val_loss: 0.0481 - val_accuracy: 0.7650
# Epoch 2983/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0406 - accuracy: 0.7862 - val_loss: 0.0441 - val_accuracy: 0.7500
# Epoch 2984/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0396 - accuracy: 0.7887 - val_loss: 0.0445 - val_accuracy: 0.7400
# Epoch 2985/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0393 - accuracy: 0.7788 - val_loss: 0.0437 - val_accuracy: 0.7450
# Epoch 2986/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0389 - accuracy: 0.7937 - val_loss: 0.0443 - val_accuracy: 0.7350
# Epoch 2987/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0386 - accuracy: 0.8012 - val_loss: 0.0444 - val_accuracy: 0.7450
# Epoch 2988/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0392 - accuracy: 0.7900 - val_loss: 0.0444 - val_accuracy: 0.7500
# Epoch 2989/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0388 - accuracy: 0.7875 - val_loss: 0.0440 - val_accuracy: 0.7600
# Epoch 2990/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0394 - accuracy: 0.7887 - val_loss: 0.0482 - val_accuracy: 0.7900
# Epoch 2991/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0396 - accuracy: 0.7887 - val_loss: 0.0459 - val_accuracy: 0.7650
# Epoch 2992/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0397 - accuracy: 0.7900 - val_loss: 0.0440 - val_accuracy: 0.7400
# Epoch 2993/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0397 - accuracy: 0.7800 - val_loss: 0.0444 - val_accuracy: 0.7450
# Epoch 2994/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0398 - accuracy: 0.7788 - val_loss: 0.0459 - val_accuracy: 0.7400
# Epoch 2995/3000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0410 - accuracy: 0.7900 - val_loss: 0.0436 - val_accuracy: 0.7500
# Epoch 2996/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0386 - accuracy: 0.7812 - val_loss: 0.0443 - val_accuracy: 0.7550
# Epoch 2997/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0387 - accuracy: 0.7962 - val_loss: 0.0453 - val_accuracy: 0.7500
# Epoch 2998/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0389 - accuracy: 0.7875 - val_loss: 0.0472 - val_accuracy: 0.7450
# Epoch 2999/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.7962 - val_loss: 0.0446 - val_accuracy: 0.7400
# Epoch 3000/3000
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.7850 - val_loss: 0.0467 - val_accuracy: 0.7400

# %%
# 学習経過の可視化(大きさ)

val_loss_array = []
for i in range(len(history_position_array)):
    val_loss_array.append(history_position_array[i].history['val_loss'])
plt.figure(figsize=(10,6))
nb_epoch = len(val_loss_array[i])
for i in range(len(val_loss_array)):
    plt.plot(range(nb_epoch), val_loss_array[i], marker='.', label='val_loss%d'%(250*(i+1)))
plt.legend(loc='best', fontsize=10)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('val_loss')
plt.show()

# %%
for i in range(len(val_loss_array)):
    print(val_loss_array[i][-1])
# Out:
# 0.052414387464523315
# 0.05285979434847832
# 0.04456370323896408
# 0.046721335500478745
