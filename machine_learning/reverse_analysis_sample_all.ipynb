# %%
## 必要なライブラリのimport
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Dense, Flatten
from keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import random

# %%
## データについて

### データファイルのpath
no_hole_path = './../tmp_simulation/tmp_data/no_hole_data.csv'
one_hole_path = './../tmp_simulation/tmp_data/one_hole_data.csv'
four_holes_path = './../tmp_simulation/tmp_data/four_holes_data.csv'
nine_holes_path = './../tmp_simulation/tmp_data/nine_holes_data.csv'
sixteen_holes_path = './../tmp_simulation/tmp_data/sixteen_holes_data.csv'
twentyfive_holes_path = './../tmp_simulation/tmp_data/twentyfive_holes_data.csv'

### 入力データと正解データ
no_hole_data = []
size_x_data = []
size_y_data = []
position_x_data = []
position_y_data = []

one_one_one = []
one_one_two = []
one_one_three = []
one_one_four = []
one_one_five = []
one_two_one = []
one_two_two = []
one_two_three = []
one_two_four = []
one_two_five = []
one_three_one = []
one_three_two = []
one_three_three = []
one_three_four = []
one_three_five = []
one_four_one = []
one_four_two = []
one_four_three = []
one_four_four = []
one_four_five = []
one_five_one = []
one_five_two = []
one_five_three = []
one_five_four = []
one_five_five = []
two_one_one = []
two_one_two = []
two_one_three = []
two_one_four = []
two_one_five = []
two_two_one = []
two_two_two = []
two_two_three = []
two_two_four = []
two_two_five = []
two_three_one = []
two_three_two = []
two_three_three = []
two_three_four = []
two_three_five = []
two_four_one = []
two_four_two = []
two_four_three = []
two_four_four = []
two_four_five = []
two_five_one = []
two_five_two = []
two_five_three = []
two_five_four = []
two_five_five = []
three_one_one = []
three_one_two = []
three_one_three = []
three_one_four = []
three_one_five = []
three_two_one = []
three_two_two = []
three_two_three = []
three_two_four = []
three_two_five = []
three_three_one = []
three_three_two = []
three_three_three = []
three_three_four = []
three_three_five = []
three_four_one = []
three_four_two = []
three_four_three = []
three_four_four = []
three_four_five = []
three_five_one = []
three_five_two = []
three_five_three = []
three_five_four = []
three_five_five = []
four_one_one = []
four_one_two = []
four_one_three = []
four_one_four = []
four_one_five = []
four_two_one = []
four_two_two = []
four_two_three = []
four_two_four = []
four_two_five = []
four_three_one = []
four_three_two = []
four_three_three = []
four_three_four = []
four_three_five = []
four_four_one = []
four_four_two = []
four_four_three = []
four_four_four = []
four_four_five = []
four_five_one = []
four_five_two = []
four_five_three = []
four_five_four = []
four_five_five = []
five_one_one = []
five_one_two = []
five_one_three = []
five_one_four = []
five_one_five = []
five_two_one = []
five_two_two = []
five_two_three = []
five_two_four = []
five_two_five = []
five_three_one = []
five_three_two = []
five_three_three = []
five_three_four = []
five_three_five = []
five_four_one = []
five_four_two = []
five_four_three = []
five_four_four = []
five_four_five = []
five_five_one = []
five_five_two = []
five_five_three = []
five_five_four = []
five_five_five = []


### ファイル読み込み

#### 欠陥がない場合の温度データ
with open(no_hole_path) as f:
    for line in f:
        no_hole_data = line.split(',')[:-1]

#### データ分類
with open(one_hole_path) as fs1:
  for line in fs1:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        one_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        one_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        one_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        one_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        one_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        one_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        one_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        one_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        one_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        one_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        one_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        one_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        one_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        one_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        one_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        one_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        one_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        one_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        one_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        one_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        one_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        one_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        one_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        one_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        one_five_five.append(data_array)

with open(four_holes_path) as fs2:
  for line in fs2:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        two_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        two_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        two_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        two_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        two_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        two_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        two_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        two_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        two_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        two_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        two_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        two_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        two_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        two_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        two_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        two_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        two_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        two_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        two_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        two_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        two_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        two_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        two_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        two_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        two_five_five.append(data_array)
with open(nine_holes_path) as fs3:
  for line in fs3:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        three_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        three_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        three_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        three_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        three_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        three_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        three_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        three_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        three_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        three_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        three_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        three_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        three_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        three_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        three_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        three_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        three_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        three_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        three_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        three_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        three_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        three_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        three_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        three_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        three_five_five.append(data_array)
with open(sixteen_holes_path) as fs4:
  for line in fs4:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        four_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        four_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        four_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        four_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        four_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        four_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        four_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        four_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        four_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        four_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        four_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        four_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        four_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        four_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        four_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        four_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        four_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        four_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        four_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        four_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        four_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        four_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        four_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        four_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        four_five_five.append(data_array)
with open(twentyfive_holes_path) as fs5:
  for line in fs5:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        five_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        five_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        five_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        five_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        five_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        five_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        five_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        five_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        five_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        five_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        five_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        five_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        five_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        five_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        five_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        five_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        five_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        five_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        five_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        five_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        five_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        five_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        five_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        five_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        five_five_five.append(data_array)

### 利用データの決定
#### one_one_oneについて
index = []
for i in range(len(one_one_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_one_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_one_twoについて
index = []
for i in range(len(one_one_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_one_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_one_threeについて
index = []
for i in range(len(one_one_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_one_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_one_fourについて
index = []
for i in range(len(one_one_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_one_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_one_fiveについて
index = []
for i in range(len(one_one_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_one_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_two_oneについて
index = []
for i in range(len(one_two_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_two_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_two_twoについて
index = []
for i in range(len(one_two_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_two_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_two_threeについて
index = []
for i in range(len(one_two_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_two_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_two_fourについて
index = []
for i in range(len(one_two_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_two_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_two_fiveについて
index = []
for i in range(len(one_two_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_two_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_three_oneについて
index = []
for i in range(len(one_three_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_three_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_three_twoについて
index = []
for i in range(len(one_three_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_three_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_three_threeについて
index = []
for i in range(len(one_three_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_three_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_three_fourについて
index = []
for i in range(len(one_three_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_three_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_three_fiveについて
index = []
for i in range(len(one_three_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_three_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_four_oneについて
index = []
for i in range(len(one_four_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_four_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_four_twoについて
index = []
for i in range(len(one_four_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_four_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_four_threeについて
index = []
for i in range(len(one_four_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_four_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_four_fourについて
index = []
for i in range(len(one_four_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_four_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_four_fiveについて
index = []
for i in range(len(one_four_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_four_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_five_oneについて
index = []
for i in range(len(one_five_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_five_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_five_twoについて
index = []
for i in range(len(one_five_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_five_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_five_threeについて
index = []
for i in range(len(one_five_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_five_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_five_fourについて
index = []
for i in range(len(one_five_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_five_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### one_five_fiveについて
index = []
for i in range(len(one_five_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = one_five_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_one_oneについて
index = []
for i in range(len(two_one_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_one_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_one_twoについて
index = []
for i in range(len(two_one_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_one_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_one_threeについて
index = []
for i in range(len(two_one_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_one_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_one_fourについて
index = []
for i in range(len(two_one_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_one_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_one_fiveについて
index = []
for i in range(len(two_one_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_one_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_two_oneについて
index = []
for i in range(len(two_two_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_two_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_two_twoについて
index = []
for i in range(len(two_two_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_two_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_two_threeについて
index = []
for i in range(len(two_two_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_two_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_two_fourについて
index = []
for i in range(len(two_two_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_two_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_two_fiveについて
index = []
for i in range(len(two_two_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_two_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_three_oneについて
index = []
for i in range(len(two_three_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_three_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_three_twoについて
index = []
for i in range(len(two_three_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_three_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_three_threeについて
index = []
for i in range(len(two_three_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_three_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_three_fourについて
index = []
for i in range(len(two_three_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_three_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_three_fiveについて
index = []
for i in range(len(two_three_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_three_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_four_oneについて
index = []
for i in range(len(two_four_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_four_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_four_twoについて
index = []
for i in range(len(two_four_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_four_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_four_threeについて
index = []
for i in range(len(two_four_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_four_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_four_fourについて
index = []
for i in range(len(two_four_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_four_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_four_fiveについて
index = []
for i in range(len(two_four_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_four_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_five_oneについて
index = []
for i in range(len(two_five_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_five_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_five_twoについて
index = []
for i in range(len(two_five_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_five_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_five_threeについて
index = []
for i in range(len(two_five_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_five_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_five_fourについて
index = []
for i in range(len(two_five_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_five_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### two_five_fiveについて
index = []
for i in range(len(two_five_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = two_five_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_one_oneについて
index = []
for i in range(len(three_one_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_one_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_one_twoについて
index = []
for i in range(len(three_one_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_one_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_one_threeについて
index = []
for i in range(len(three_one_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_one_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_one_fourについて
index = []
for i in range(len(three_one_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_one_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_one_fiveについて
index = []
for i in range(len(three_one_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_one_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_two_oneについて
index = []
for i in range(len(three_two_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_two_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_two_twoについて
index = []
for i in range(len(three_two_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_two_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_two_threeについて
index = []
for i in range(len(three_two_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_two_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_two_fourについて
index = []
for i in range(len(three_two_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_two_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_two_fiveについて
index = []
for i in range(len(three_two_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_two_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_three_oneについて
index = []
for i in range(len(three_three_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_three_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_three_twoについて
index = []
for i in range(len(three_three_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_three_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_three_threeについて
index = []
for i in range(len(three_three_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_three_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_three_fourについて
index = []
for i in range(len(three_three_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_three_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_three_fiveについて
index = []
for i in range(len(three_three_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_three_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_four_oneについて
index = []
for i in range(len(three_four_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_four_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_four_twoについて
index = []
for i in range(len(three_four_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_four_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_four_threeについて
index = []
for i in range(len(three_four_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_four_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_four_fourについて
index = []
for i in range(len(three_four_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_four_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_four_fiveについて
index = []
for i in range(len(three_four_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_four_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_five_oneについて
index = []
for i in range(len(three_five_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_five_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_five_twoについて
index = []
for i in range(len(three_five_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_five_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_five_threeについて
index = []
for i in range(len(three_five_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_five_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_five_fourについて
index = []
for i in range(len(three_five_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_five_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### three_five_fiveについて
index = []
for i in range(len(three_five_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = three_five_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_one_oneについて
index = []
for i in range(len(four_one_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_one_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_one_twoについて
index = []
for i in range(len(four_one_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_one_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_one_threeについて
index = []
for i in range(len(four_one_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_one_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_one_fourについて
index = []
for i in range(len(four_one_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_one_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_one_fiveについて
index = []
for i in range(len(four_one_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_one_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_two_oneについて
index = []
for i in range(len(four_two_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_two_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_two_twoについて
index = []
for i in range(len(four_two_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_two_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_two_threeについて
index = []
for i in range(len(four_two_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_two_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_two_fourについて
index = []
for i in range(len(four_two_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_two_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_two_fiveについて
index = []
for i in range(len(four_two_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_two_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_three_oneについて
index = []
for i in range(len(four_three_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_three_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_three_twoについて
index = []
for i in range(len(four_three_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_three_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_three_threeについて
index = []
for i in range(len(four_three_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_three_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_three_fourについて
index = []
for i in range(len(four_three_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_three_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_three_fiveについて
index = []
for i in range(len(four_three_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_three_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_four_oneについて
index = []
for i in range(len(four_four_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_four_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_four_twoについて
index = []
for i in range(len(four_four_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_four_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_four_threeについて
index = []
for i in range(len(four_four_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_four_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_four_fourについて
index = []
for i in range(len(four_four_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_four_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_four_fiveについて
index = []
for i in range(len(four_four_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_four_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_five_oneについて
index = []
for i in range(len(four_five_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_five_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_five_twoについて
index = []
for i in range(len(four_five_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_five_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_five_threeについて
index = []
for i in range(len(four_five_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_five_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_five_fourについて
index = []
for i in range(len(four_five_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_five_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### four_five_fiveについて
index = []
for i in range(len(four_five_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = four_five_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_one_oneについて
index = []
for i in range(len(five_one_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_one_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_one_twoについて
index = []
for i in range(len(five_one_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_one_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_one_threeについて
index = []
for i in range(len(five_one_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_one_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_one_fourについて
index = []
for i in range(len(five_one_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_one_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_one_fiveについて
index = []
for i in range(len(five_one_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_one_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_two_oneについて
index = []
for i in range(len(five_two_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_two_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_two_twoについて
index = []
for i in range(len(five_two_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_two_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_two_threeについて
index = []
for i in range(len(five_two_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_two_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_two_fourについて
index = []
for i in range(len(five_two_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_two_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_two_fiveについて
index = []
for i in range(len(five_two_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_two_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_three_oneについて
index = []
for i in range(len(five_three_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_three_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_three_twoについて
index = []
for i in range(len(five_three_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_three_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_three_threeについて
index = []
for i in range(len(five_three_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_three_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_three_fourについて
index = []
for i in range(len(five_three_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_three_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_three_fiveについて
index = []
for i in range(len(five_three_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_three_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_four_oneについて
index = []
for i in range(len(five_four_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_four_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_four_twoについて
index = []
for i in range(len(five_four_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_four_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_four_threeについて
index = []
for i in range(len(five_four_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_four_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_four_fourについて
index = []
for i in range(len(five_four_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_four_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_four_fiveについて
index = []
for i in range(len(five_four_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_four_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_five_oneについて
index = []
for i in range(len(five_five_one)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_five_one[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_five_twoについて
index = []
for i in range(len(five_five_two)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_five_two[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_five_threeについて
index = []
for i in range(len(five_five_three)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_five_three[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_five_fourについて
index = []
for i in range(len(five_five_four)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_five_four[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
#### five_five_fiveについて
index = []
for i in range(len(five_five_five)):
    index.append(i)
data_count = 2
used_index = random.sample(index, data_count)
for i in used_index:
    data_array = five_five_five[i]
    size_x_data.append(data_array[3:-1])
    size_y_data.append(data_array[2])
    position_x_data.append(data_array[3:-1])
    position_y_data.append(data_array[0:2])
    
### 各配列をnp.array型にして各要素を型変換
no_hole_data = np.array(no_hole_data, dtype=float)
size_x_data = np.array(size_x_data, dtype=float)
size_y_data = np.array(size_y_data, dtype=int)
position_x_data = np.array(position_x_data, dtype=float)
position_y_data = np.array(position_y_data, dtype=float)

### データの加工
size_x_data = (size_x_data-no_hole_data)
position_x_data = (position_x_data-no_hole_data)
position_y_data = position_y_data/50
# print(size_y_data.shape)
# print(size_x_data.shape)
# print(size_y_data)
# print(size_x_data)
# print(position_y_data.shape)

### train用とtest用に分割(4:1)
size_x_train, size_x_test, size_y_train, size_y_test = train_test_split(size_x_data, size_y_data, test_size=0.20)
position_x_train, position_x_test, position_y_train, position_y_test = train_test_split(position_x_data, position_y_data, test_size=0.20)


### reshape
size_x_train = size_x_train.reshape(200, 50, 1)
size_x_test = size_x_test.reshape(50, 50, 1)
position_x_train = position_x_train.reshape(200, 50, 1)
position_x_test = position_x_test.reshape(50, 50, 1)

# %%
## CNN(大きさ)

### modelの作成
size_model = Sequential()
### 畳み込み層
size_model.add(Conv1D(32, 3, padding='same', activation='tanh', input_shape=(50, 1)))
### プーリング層
size_model.add(MaxPooling1D(2, padding='same'))
### Flatten層
size_model.add(Flatten())
### 全結合層
size_model.add(Dense(1, activation='linear'))

### optimizer
adam = keras.optimizers.Adam()

###modelのコンパイル
size_model.compile(loss='mse', optimizer=adam, metrics=['accuracy'])

# %%
# 学習(大きさ)
epochs = 1000
batch_size = 128
size_history = size_model.fit(size_x_train, size_y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(size_x_test, size_y_test))
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 0s 91ms/step - loss: 7.1308 - accuracy: 0.2150 - val_loss: 5.6767 - val_accuracy: 0.1400
# Epoch 2/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 5.1859 - accuracy: 0.2150 - val_loss: 4.0600 - val_accuracy: 0.1400
# Epoch 3/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 3.7720 - accuracy: 0.2150 - val_loss: 2.9664 - val_accuracy: 0.1400
# Epoch 4/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8286 - accuracy: 0.2150 - val_loss: 2.3696 - val_accuracy: 0.1400
# Epoch 5/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 2.3983 - accuracy: 0.2150 - val_loss: 2.1907 - val_accuracy: 0.1400
# Epoch 6/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 2.3598 - accuracy: 0.2150 - val_loss: 2.2856 - val_accuracy: 0.1400
# Epoch 7/1000
# 2/2 [==============================] - 0s 18ms/step - loss:
1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2707 - accuracy: 0.2150 - val_loss: 0.1981 - val_accuracy: 0.1400
# Epoch 974/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2668 - accuracy: 0.2150 - val_loss: 0.2125 - val_accuracy: 0.1400
# Epoch 975/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2700 - accuracy: 0.2150 - val_loss: 0.2044 - val_accuracy: 0.1400
# Epoch 976/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2670 - accuracy: 0.2150 - val_loss: 0.1962 - val_accuracy: 0.1400
# Epoch 977/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2695 - accuracy: 0.2150 - val_loss: 0.2028 - val_accuracy: 0.1400
# Epoch 978/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2677 - accuracy: 0.2150 - val_loss: 0.2167 - val_accuracy: 0.1400
# Epoch 979/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2701 - accuracy: 0.2150 - val_loss: 0.1979 - val_accuracy: 0.1400
# Epoch 980/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2664 - accuracy: 0.2150 - val_loss: 0.1967 - val_accuracy: 0.1400
# Epoch 981/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2662 - accuracy: 0.2150 - val_loss: 0.2049 - val_accuracy: 0.1400
# Epoch 982/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2680 - accuracy: 0.2150 - val_loss: 0.2015 - val_accuracy: 0.1400
# Epoch 983/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2664 - accuracy: 0.2150 - val_loss: 0.1955 - val_accuracy: 0.1400
# Epoch 984/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2667 - accuracy: 0.2150 - val_loss: 0.2029 - val_accuracy: 0.1400
# Epoch 985/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2645 - accuracy: 0.2150 - val_loss: 0.2104 - val_accuracy: 0.1400
# Epoch 986/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2667 - accuracy: 0.2150 - val_loss: 0.1995 - val_accuracy: 0.1400
# Epoch 987/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2687 - accuracy: 0.2150 - val_loss: 0.1953 - val_accuracy: 0.1400
# Epoch 988/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2664 - accuracy: 0.2150 - val_loss: 0.2060 - val_accuracy: 0.1400
# Epoch 989/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2673 - accuracy: 0.2150 - val_loss: 0.1962 - val_accuracy: 0.1400
# Epoch 990/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2640 - accuracy: 0.2150 - val_loss: 0.1941 - val_accuracy: 0.1400
# Epoch 991/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2709 - accuracy: 0.2150 - val_loss: 0.1981 - val_accuracy: 0.1400
# Epoch 992/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2628 - accuracy: 0.2150 - val_loss: 0.2085 - val_accuracy: 0.1400
# Epoch 993/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2667 - accuracy: 0.2150 - val_loss: 0.2025 - val_accuracy: 0.1400
# Epoch 994/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2620 - accuracy: 0.2150 - val_loss: 0.1924 - val_accuracy: 0.1400
# Epoch 995/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2690 - accuracy: 0.2150 - val_loss: 0.1940 - val_accuracy: 0.1400
# Epoch 996/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2606 - accuracy: 0.2150 - val_loss: 0.2187 - val_accuracy: 0.1400
# Epoch 997/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2720 - accuracy: 0.2150 - val_loss: 0.2011 - val_accuracy: 0.1400
# Epoch 998/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2601 - accuracy: 0.2150 - val_loss: 0.1930 - val_accuracy: 0.1400
# Epoch 999/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2737 - accuracy: 0.2150 - val_loss: 0.1925 - val_accuracy: 0.1400
# Epoch 1000/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2605 - accuracy: 0.2150 - val_loss: 0.2239 - val_accuracy: 0.1400

# %%
# モデルの評価(大きさ)
size_score = size_model.evaluate(size_x_test, size_y_test, verbose=1)
print('Test loss:', size_score[0])
print('Test accuracy:', size_score[1])
# Out:
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2239 - accuracy: 0.1400
# Test loss: 0.223947674036026
# Test accuracy: 0.14000000059604645

# %%
# 学習経過の可視化(大きさ)
size_loss     = size_history.history['loss']
size_val_loss = size_history.history['val_loss']

nb_epoch = len(size_loss)
plt.plot(range(nb_epoch), size_loss,     marker='.', label='size_loss')
plt.plot(range(nb_epoch), size_val_loss, marker='.', label='size_val_loss')
plt.legend(loc='best', fontsize=10)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
## CNN(位置)

### modelの作成
position_model = Sequential()
### 畳み込み層
position_model.add(Conv1D(32, 3, padding='same', activation='tanh', input_shape=(50, 1)))
### プーリング層
position_model.add(MaxPooling1D(2, padding='same'))
### Flatten層
position_model.add(Flatten())
### 全結合層
position_model.add(Dense(2, activation='linear'))

### optimizer
adam = keras.optimizers.Adam()

###modelのコンパイル
position_model.compile(loss='mse', optimizer=adam, metrics=['accuracy'])

# %%
# 学習(位置)
epochs = 3000
batch_size = 128
position_history = position_model.fit(position_x_train, position_y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(position_x_test, position_y_test))
# Out:
# Epoch 1/3000
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6363 - accuracy: 0.5050 - val_loss: 0.2349 - val_accuracy: 0.4200
# Epoch 2/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2024 - accuracy: 0.5150 - val_loss: 0.0931 - val_accuracy: 0.5400
# Epoch 3/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0973 - accuracy: 0.4650 - val_loss: 0.1483 - val_accuracy: 0.5600
# Epoch 4/3000
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1537 - accuracy: 0.4850 - val_loss: 0.2296 - val_accuracy: 0.5600
# Epoch 5/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2072 - accuracy: 0.4900 - val_loss: 0.2142 - val_accuracy: 0.5800
# Epoch 6/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1811 - accuracy: 0.4950 - val_loss: 0.1445 - val_accuracy: 0.5800
# Epoch 7/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1187 - accuracy: 0.4900 - val_loss: 0.0938 - val_accuracy: 0.5800
# Epoch 8/3000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0826 - accuracy: 0.4900 - val_loss: 0.0798 - val_accuracy: 0.6600
# Epoch 9/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0787 - accuracy: 0.6450 - val_loss: 0.0946 - val_accuracy: 0.4600
# Epoch 10/3000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0969 - accuracy: 0.5300 - val_loss: 0.1104 - val_accuracy: 0.4600
# Epoch 11/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1093 - accuracy: 0.5300 - val_loss: 0.1044 - val_accuracy: 0.4600
# Epoch 12/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1021 - accuracy: 0.5400 - val_loss: 0.0875 - val_accuracy: 0.4600
# Epoch 13/3000
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0854 - accuracy: 0.5500 - val_loss: 0.0764 - val_accuracy: 0.4600
# Epoch 14/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0737 - accuracy: 0.6300 - val_loss: 0.0775 - val_accuracy: 0.6000
# Epoch 15/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0724 - accuracy: 0.6400 - val_loss: 0.0851 - val_accuracy: 0.6800
# Epoch 16/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0775 - accuracy: 0.5400 - val_loss: 0.0880 - val_accuracy: 0.6000
# Epoch 17/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0803 - accuracy: 0.5100 - val_loss: 0.0851 - val_accuracy: 0.6000
# Epoch 18/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0779 - accuracy: 0.5050 - val_loss: 0.0797 - val_accuracy: 0.6400
# Epoch 19/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0727 - accuracy: 0.5450 - val_loss: 0.0760 - val_accuracy: 0.6000
# Epoch 20/3000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0699 - accuracy: 0.6550 - val_loss: 0.0745 - val_accuracy: 0.4600
# Epoch 21/3000
# 2/2 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.64 - 0s 14ms/step - loss: 0.0704 - accuracy: 0.6100 - val_loss: 0.0752 - val_accuracy: 0.4600
# Epoch 22/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0718 - accuracy: 0.5900 - val_loss: 0.0753 - val_accuracy: 0.4600
# Epoch 23/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0720 - accuracy: 0.5900 - val_loss: 0.0748 - val_accuracy: 0.4600
# Epoch 24/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0707 - accuracy: 0.6050 - val_loss: 0.0747 - val_accuracy: 0.4600
# Epoch 25/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0694 - accuracy: 0.6150 - val_loss: 0.0756 - val_accuracy: 0.5800
# Epoch 26/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0691 - accuracy: 0.6400 - val_loss: 0.0759 - val_accuracy: 0.6200
# Epoch 27/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0693 - accuracy: 0.6350 - val_loss: 0.0757 - val_accuracy: 0.6200
# Epoch 28/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0699 - accuracy: 0.5950 - val_loss: 0.0755 - val_accuracy: 0.6200
# Epoch 29/3000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0694 - accuracy: 0.6050 - val_loss: 0.0762 - val_accuracy: 0.6600
# Epoch 30/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0686 - accuracy: 0.7050 - val_loss: 0.0764 - val_accuracy: 0.4800
# Epoch 31/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0686 - accuracy: 0.6300 - val_loss: 0.0749 - val_accuracy: 0.4600
# Epoch 32/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0685 - accuracy: 0.6350 - val_loss: 0.0733 - val_accuracy: 0.6400
# Epoch 33/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0690 - accuracy: 0.6700 - val_loss: 0.0735 - val_accuracy: 0.6000
# Epoch 34/3000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0683 - accuracy: 0.6450 - val_loss: 0.0759 - val_accuracy: 0.4600
# Epoch 35/3000
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0686 - accuracy: 0.6100 - val_loss: 0.0776 - val_accuracy: 0.4600
# Epoch 36/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0685 - accuracy: 0.6150 - val_loss: 0.0742 - val_accuracy: 0.6400
# Epoch 37/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0678 - accuracy: 0.6700 - val_loss: 0.0735 - val_accuracy: 0.6200
# Epoch 38/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0687 - accuracy: 0.6100 - val_loss: 0.0743 - val_accuracy: 0.6000
# Epoch 39/3000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0680 - accuracy: 0.6200 - val_loss: 0.0780 - val_accuracy: 0.4600
# Epoch 40/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0684 - accuracy: 0.6150 - val_loss: 0.0753 - val_accuracy: 0.5000
# Epoch 41/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0671 - accuracy: 0.6850 - val_loss: 0.0727 - val_accuracy: 0.6000
# Epoch 42/3000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0681 - accuracy: 0.6500 - val_loss: 0.0726 - val_accuracy: 0.5800
# Epoch 43/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0677 - accuracy: 0.6500 - val_loss: 0.0750 - val_accuracy: 0.4600
# Epoch 44/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0673 - accuracy: 0.6250 - val_loss: 0.0763 - val_accuracy: 0.4600
# Epoch 45/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0682 - accuracy: 0.6100 - val_loss: 0.0745 - val_accuracy: 0.5000
# Epoch 46/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0671 - accuracy: 0.6800 - val_loss: 0.0722 - val_accuracy: 0.6200
# Epoch 47/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0679 - accuracy: 0.6450 - val_loss: 0.0728 - val_accuracy: 0.6400
# Epoch 48/3000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0669 - accuracy: 0.6600 - val_loss: 0.0763 - val_accuracy: 0.5600
# Epoch 49/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.

# 2/2 [==============================] - 0s 22ms/step - loss: 0.0642 - accuracy: 0.6650 - val_loss: 0.0700 - val_accuracy: 0.6600
# Epoch 80/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0638 - accuracy: 0.7100 - val_loss: 0.0696 - val_accuracy: 0.6600
# Epoch 81/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0639 - accuracy: 0.6600 - val_loss: 0.0714 - val_accuracy: 0.6600
# Epoch 82/3000
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0638 - accuracy: 0.7100 - val_loss: 0.0732 - val_accuracy: 0.5000
# Epoch 83/3000
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0640 - accuracy: 0.6650 - val_loss: 0.0700 - val_accuracy: 0.6800
# Epoch 84/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0633 - accuracy: 0.6950 - val_loss: 0.0685 - val_accuracy: 0.6800
# Epoch 85/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0640 - accuracy: 0.6650 - val_loss: 0.0690 - val_accuracy: 0.6600
# Epoch 86/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0636 - accuracy: 0.7150 - val_loss: 0.0710 - val_accuracy: 0.4800
# Epoch 87/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0635 - accuracy: 0.6350 - val_loss: 0.0702 - val_accuracy: 0.5000
# Epoch 88/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0633 - accuracy: 0.7000 - val_loss: 0.0685 - val_accuracy: 0.6600
# Epoch 89/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0637 - accuracy: 0.6600 - val_loss: 0.0681 - val_accuracy: 0.6800
# Epoch 90/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0633 - accuracy: 0.6950 - val_loss: 0.0715 - val_accuracy: 0.5800
# Epoch 91/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0640 - accuracy: 0.6800 - val_loss: 0.0716 - val_accuracy: 0.6400
# Epoch 92/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0632 - accuracy: 0.6900 - val_loss: 0.0679 - val_accuracy: 0.6800
# Epoch 93/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0637 - accuracy: 0.6550 - val_loss: 0.0678 - val_accuracy: 0.6800
# Epoch 94/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0630 - accuracy: 0.6800 - val_loss: 0.0685 - val_accuracy: 0.6600
# Epoch 95/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0629 - accuracy: 0.6450 - val_loss: 0.0698 - val_accuracy: 0.5200
# Epoch 96/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0627 - accuracy: 0.7250 - val_loss: 0.0688 - val_accuracy: 0.6600
# Epoch 97/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0625 - accuracy: 0.6800 - val_loss: 0.0680 - val_accuracy: 0.6800
# Epoch 98/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0626 - accuracy: 0.6800 - val_loss: 0.0696 - val_accuracy: 0.6800
# Epoch 99/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0624 - accuracy: 0.7200 - val_loss: 0.0710 - val_accuracy: 0.5600
# Epoch 100/3000
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0626 - accuracy: 0.7100 - val_loss: 0.0696 - val_accuracy: 0.5600
# Epoch 101/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0625 - accuracy: 0.7300 - val_loss: 0.0673 - val_accuracy: 0.6800
# Epoch 102/3000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0627 - accuracy: 0.7050 - val_loss: 0.0675 - val_accuracy: 0.7000
# Epoch 103/3000
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0623 - accuracy: 0.6950 - val_loss: 0.0710 - val_accuracy: 0.6400
# Epoch 104/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0626 - accuracy: 0.7050 - val_loss: 0.0688 - val_accuracy: 0.7200
# Epoch 105/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0619 - accuracy: 0.6750 - val_loss: 0.0667 - val_accuracy: 0.7000
# Epoch 106/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0629 - accuracy: 0.6400 - val_loss: 0.0673 - val_accuracy: 0.6800
# Epoch 107/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0620 - accuracy: 0.7050 - val_loss: 0.0706 - val_accuracy: 0.4600
# Epoch 108/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0624 - accuracy: 0.6250 - val_loss: 0.0676 - val_accuracy: 0.6400
# Epoch 109/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.

# 2/2 [==============================] - 0s 22ms/step - loss: 0.0595 - accuracy: 0.6950 - val_loss: 0.0643 - val_accuracy: 0.7400
# Epoch 140/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0596 - accuracy: 0.7150 - val_loss: 0.0649 - val_accuracy: 0.6000
# Epoch 141/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0598 - accuracy: 0.7150 - val_loss: 0.0661 - val_accuracy: 0.5200
# Epoch 142/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0594 - accuracy: 0.7050 - val_loss: 0.0645 - val_accuracy: 0.7600
# Epoch 143/3000
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0593 - accuracy: 0.7050 - val_loss: 0.0643 - val_accuracy: 0.7400
# Epoch 144/3000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0597 - accuracy: 0.6900 - val_loss: 0.0653 - val_accuracy: 0.7200
# Epoch 145/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0593 - accuracy: 0.7000 - val_loss: 0.0655 - val_accuracy: 0.7000
# Epoch 146/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0590 - accuracy: 0.7450 - val_loss: 0.0650 - val_accuracy: 0.7200
# Epoch 147/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0589 - accuracy: 0.7550 - val_loss: 0.0642 - val_accuracy: 0.7400
# Epoch 148/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0590 - accuracy: 0.7450 - val_loss: 0.0639 - val_accuracy: 0.7400
# Epoch 149/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0589 - accuracy: 0.7200 - val_loss: 0.0651 - val_accuracy: 0.7600
# Epoch 150/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0590 - accuracy: 0.7050 - val_loss: 0.0640 - val_accuracy: 0.7400
# Epoch 151/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0590 - accuracy: 0.7200 - val_loss: 0.0640 - val_accuracy: 0.7400
# Epoch 152/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0587 - accuracy: 0.7150 - val_loss: 0.0631 - val_accuracy: 0.7400
# Epoch 153/3000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0585 - accuracy: 0.7250 - val_loss: 0.0648 - val_accuracy: 0.6200
# Epoch 154/3000
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0587 - accuracy: 0.7700 - val_loss: 0.0643 - val_accuracy: 0.7000
# Epoch 155/3000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0584 - accuracy: 0.7550 - val_loss: 0.0626 - val_accuracy: 0.7600
# Epoch 156/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0586 - accuracy: 0.6950 - val_loss: 0.0626 - val_accuracy: 0.7200
# Epoch 157/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0583 - accuracy: 0.6900 - val_loss: 0.0652 - val_accuracy: 0.7000
# Epoch 158/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0585 - accuracy: 0.7900 - val_loss: 0.0647 - val_accuracy: 0.7200
# Epoch 159/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0583 - accuracy: 0.7500 - val_loss: 0.0621 - val_accuracy: 0.7600
# Epoch 160/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0584 - accuracy: 0.6950 - val_loss: 0.0629 - val_accuracy: 0.7400
# Epoch 161/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0579 - accuracy: 0.7550 - val_loss: 0.0655 - val_accuracy: 0.6400
# Epoch 162/3000
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0584 - accuracy: 0.7600 - val_loss: 0.0631 - val_accuracy: 0.7600
# Epoch 163/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0580 - accuracy: 0.7400 - val_loss: 0.0623 - val_accuracy: 0.7400
# Epoch 164/3000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0578 - accuracy: 0.7350 - val_loss: 0.0638 - val_accuracy: 0.7400
# Epoch 165/3000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0579 - accuracy: 0.7650 - val_loss: 0.0635 - val_accuracy: 0.7600
# Epoch 166/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0578 - accuracy: 0.7400 - val_loss: 0.0616 - val_accuracy: 0.7400
# Epoch 167/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0579 - accuracy: 0.7100 - val_loss: 0.0621 - val_accuracy: 0.7600
# Epoch 168/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0587 - accuracy: 0.7100 - val_loss: 0.0647 - val_accuracy: 0.5600
# Epoch 169/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.
3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0530 - accuracy: 0.7250 - val_loss: 0.0524 - val_accuracy: 0.8000
# Epoch 290/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0527 - accuracy: 0.7300 - val_loss: 0.0540 - val_accuracy: 0.8000
# Epoch 291/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0527 - accuracy: 0.7350 - val_loss: 0.0551 - val_accuracy: 0.8200
# Epoch 292/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0527 - accuracy: 0.8100 - val_loss: 0.0549 - val_accuracy: 0.8000
# Epoch 293/3000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0526 - accuracy: 0.8250 - val_loss: 0.0525 - val_accuracy: 0.8000
# Epoch 294/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0529 - accuracy: 0.7250 - val_loss: 0.0535 - val_accuracy: 0.8200
# Epoch 295/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0521 - accuracy: 0.7600 - val_loss: 0.0570 - val_accuracy: 0.8200
# Epoch 296/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0532 - accuracy: 0.8100 - val_loss: 0.0531 - val_accuracy: 0.7800
# Epoch 297/3000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0520 - accuracy: 0.7400 - val_loss: 0.0520 - val_accuracy: 0.8000
# Epoch 298/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0533 - accuracy: 0.7250 - val_loss: 0.0536 - val_accuracy: 0.7800
# Epoch 299/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0521 - accuracy: 0.8250 - val_loss: 0.0589 - val_accuracy: 0.5800
# Epoch 300/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0552 - accuracy: 0.7450 - val_loss: 0.0541 - val_accuracy: 0.8200
# Epoch 301/3000
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0535 - accuracy: 0.6900 - val_loss: 0.0521 - val_accuracy: 0.7600
# Epoch 302/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0544 - accuracy: 0.6900 - val_loss: 0.0562 - val_accuracy: 0.5800
# Epoch 303/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0547 - accuracy: 0.6950 - val_loss: 0.0588 - val_accuracy: 0.5600
# Epoch 304/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0530 - accuracy: 0.7300 - val_loss: 0.0519 - val_accuracy: 0.7800
# Epoch 305/3000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0552 - accuracy: 0.6500 - val_loss: 0.0522 - val_accuracy: 0.8000
# Epoch 306/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0524 - accuracy: 0.7250 - val_loss: 0.0604 - val_accuracy: 0.5800
# Epoch 307/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0557 - accuracy: 0.6950 - val_loss: 0.0531 - val_accuracy: 0.8600
# Epoch 308/3000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0534 - accuracy: 0.7850 - val_loss: 0.0522 - val_accuracy: 0.7600
# Epoch 309/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0548 - accuracy: 0.6600 - val_loss: 0.0563 - val_accuracy: 0.8400
# Epoch 310/3000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0559 - accuracy: 0.7500 - val_loss: 0.0582 - val_accuracy: 0.5800
# Epoch 311/3000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0529 - accuracy: 0.7450 - val_loss: 0.0519 - val_accuracy: 0.7800
# Epoch 312/3000
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0556 - accuracy: 0.6850 - val_loss: 0.0517 - val_accuracy: 0.8000
# Epoch 313/3000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0515 - accuracy: 0.8200 - val_loss: 0.0611 - val_accuracy: 0.5800
# Epoch 314/3000
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0558 - accuracy: 0.7150 - val_loss: 0.0538 - val_accuracy: 0.8000
# Epoch 315/3000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0522 - accuracy: 0.7400 - val_loss: 0.0519 - val_accuracy: 0.7800
# Epoch 316/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0551 - accuracy: 0.6900 - val_loss: 0.0535 - val_accuracy: 0.8000
# Epoch 317/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0527 - accuracy: 0.8000 - val_loss: 0.0598 - val_accuracy: 0.5800
# Epoch 318/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0537 - accuracy: 0.7700 - val_loss: 0.0515 - val_accuracy: 0.8000
# Epoch 319/3000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.
3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0429 - accuracy: 0.7650 - val_loss: 0.0683 - val_accuracy: 0.7800
# Epoch 2993/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0438 - accuracy: 0.8200 - val_loss: 0.0670 - val_accuracy: 0.8000
# Epoch 2994/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0431 - accuracy: 0.8300 - val_loss: 0.0660 - val_accuracy: 0.8400
# Epoch 2995/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0430 - accuracy: 0.7600 - val_loss: 0.0685 - val_accuracy: 0.6800
# Epoch 2996/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0437 - accuracy: 0.7600 - val_loss: 0.0666 - val_accuracy: 0.6800
# Epoch 2997/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0429 - accuracy: 0.8050 - val_loss: 0.0654 - val_accuracy: 0.8600
# Epoch 2998/3000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0436 - accuracy: 0.7350 - val_loss: 0.0671 - val_accuracy: 0.8400
# Epoch 2999/3000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0438 - accuracy: 0.8150 - val_loss: 0.0662 - val_accuracy: 0.6800
# Epoch 3000/3000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0426 - accuracy: 0.7600 - val_loss: 0.0657 - val_accuracy: 0.8400

# %%
# モデルの評価(位置)
position_score =position_model.evaluate(position_x_test, position_y_test, verbose=1)
print('Test loss:', position_score[0])
print('Test accuracy:', position_score[1])
# Out:
# 2/2 [==============================] - 0s 803us/step - loss: 0.0657 - accuracy: 0.8400
# Test loss: 0.06570013612508774
# Test accuracy: 0.8399999737739563

# %%
# 学習経過の可視化(位置)
position_loss     = position_history.history['loss']
position_val_loss = position_history.history['val_loss']

nb_epoch = len(position_loss)
plt.plot(range(nb_epoch), position_loss,     marker='.', label='position_loss')
plt.plot(range(nb_epoch), position_val_loss, marker='.', label='position_val_loss')
plt.legend(loc='best', fontsize=10)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# データ数250で繰り返し行いlossの大きさと安定性を確認する

# %%
## 必要なライブラリのimport
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Dense, Flatten
from keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import random

# %%
## データについて

### データファイルのpath
no_hole_path = './../tmp_simulation/tmp_data/no_hole_data.csv'
one_hole_path = './../tmp_simulation/tmp_data/one_hole_data.csv'
four_holes_path = './../tmp_simulation/tmp_data/four_holes_data.csv'
nine_holes_path = './../tmp_simulation/tmp_data/nine_holes_data.csv'
sixteen_holes_path = './../tmp_simulation/tmp_data/sixteen_holes_data.csv'
twentyfive_holes_path = './../tmp_simulation/tmp_data/twentyfive_holes_data.csv'

### 入力データと正解データ
no_hole_data = []

one_one_one = []
one_one_two = []
one_one_three = []
one_one_four = []
one_one_five = []
one_two_one = []
one_two_two = []
one_two_three = []
one_two_four = []
one_two_five = []
one_three_one = []
one_three_two = []
one_three_three = []
one_three_four = []
one_three_five = []
one_four_one = []
one_four_two = []
one_four_three = []
one_four_four = []
one_four_five = []
one_five_one = []
one_five_two = []
one_five_three = []
one_five_four = []
one_five_five = []
two_one_one = []
two_one_two = []
two_one_three = []
two_one_four = []
two_one_five = []
two_two_one = []
two_two_two = []
two_two_three = []
two_two_four = []
two_two_five = []
two_three_one = []
two_three_two = []
two_three_three = []
two_three_four = []
two_three_five = []
two_four_one = []
two_four_two = []
two_four_three = []
two_four_four = []
two_four_five = []
two_five_one = []
two_five_two = []
two_five_three = []
two_five_four = []
two_five_five = []
three_one_one = []
three_one_two = []
three_one_three = []
three_one_four = []
three_one_five = []
three_two_one = []
three_two_two = []
three_two_three = []
three_two_four = []
three_two_five = []
three_three_one = []
three_three_two = []
three_three_three = []
three_three_four = []
three_three_five = []
three_four_one = []
three_four_two = []
three_four_three = []
three_four_four = []
three_four_five = []
three_five_one = []
three_five_two = []
three_five_three = []
three_five_four = []
three_five_five = []
four_one_one = []
four_one_two = []
four_one_three = []
four_one_four = []
four_one_five = []
four_two_one = []
four_two_two = []
four_two_three = []
four_two_four = []
four_two_five = []
four_three_one = []
four_three_two = []
four_three_three = []
four_three_four = []
four_three_five = []
four_four_one = []
four_four_two = []
four_four_three = []
four_four_four = []
four_four_five = []
four_five_one = []
four_five_two = []
four_five_three = []
four_five_four = []
four_five_five = []
five_one_one = []
five_one_two = []
five_one_three = []
five_one_four = []
five_one_five = []
five_two_one = []
five_two_two = []
five_two_three = []
five_two_four = []
five_two_five = []
five_three_one = []
five_three_two = []
five_three_three = []
five_three_four = []
five_three_five = []
five_four_one = []
five_four_two = []
five_four_three = []
five_four_four = []
five_four_five = []
five_five_one = []
five_five_two = []
five_five_three = []
five_five_four = []
five_five_five = []


### ファイル読み込み

#### 欠陥がない場合の温度データ
with open(no_hole_path) as f:
    for line in f:
        no_hole_data = line.split(',')[:-1]

#### データ分類
with open(one_hole_path) as fs1:
  for line in fs1:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        one_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        one_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        one_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        one_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        one_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        one_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        one_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        one_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        one_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        one_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        one_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        one_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        one_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        one_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        one_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        one_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        one_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        one_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        one_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        one_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        one_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        one_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        one_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        one_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        one_five_five.append(data_array)

with open(four_holes_path) as fs2:
  for line in fs2:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        two_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        two_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        two_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        two_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        two_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        two_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        two_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        two_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        two_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        two_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        two_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        two_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        two_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        two_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        two_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        two_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        two_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        two_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        two_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        two_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        two_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        two_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        two_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        two_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        two_five_five.append(data_array)
with open(nine_holes_path) as fs3:
  for line in fs3:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        three_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        three_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        three_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        three_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        three_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        three_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        three_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        three_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        three_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        three_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        three_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        three_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        three_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        three_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        three_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        three_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        three_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        three_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        three_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        three_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        three_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        three_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        three_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        three_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        three_five_five.append(data_array)
with open(sixteen_holes_path) as fs4:
  for line in fs4:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        four_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        four_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        four_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        four_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        four_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        four_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        four_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        four_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        four_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        four_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        four_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        four_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        four_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        four_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        four_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        four_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        four_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        four_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        four_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        four_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        four_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        four_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        four_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        four_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        four_five_five.append(data_array)
with open(twentyfive_holes_path) as fs5:
  for line in fs5:
    data_array = line.split(',')
    position = np.array(data_array[0:2], dtype=float)
    if (0<position[0] and position[0]<10 and 0 < position[1] and position[1] < 10):
        five_one_one.append(data_array)
    if (0<position[0] and position[0]<10 and 10 < position[1] and position[1] < 20):
        five_one_two.append(data_array)
    if (0<position[0] and position[0]<10 and 20 < position[1] and position[1] < 30):
        five_one_three.append(data_array)
    if (0<position[0] and position[0]<10 and 30 < position[1] and position[1] < 40):
        five_one_four.append(data_array)
    if (0<position[0] and position[0]<10 and 40 < position[1] and position[1] < 50):
        five_one_five.append(data_array)
    if (10<position[0] and position[0]<20 and 0 < position[1] and position[1] < 10):
        five_two_one.append(data_array)
    if (10<position[0] and position[0]<20 and 10 < position[1] and position[1] < 20):
        five_two_two.append(data_array)
    if (10<position[0] and position[0]<20 and 20 < position[1] and position[1] < 30):
        five_two_three.append(data_array)
    if (10<position[0] and position[0]<20 and 30 < position[1] and position[1] < 40):
        five_two_four.append(data_array)
    if (10<position[0] and position[0]<20 and 40 < position[1] and position[1] < 50):
        five_two_five.append(data_array)
    if (20<position[0] and position[0]<30 and 0 < position[1] and position[1] < 10):
        five_three_one.append(data_array)
    if (20<position[0] and position[0]<30 and 10 < position[1] and position[1] < 20):
        five_three_two.append(data_array)
    if (20<position[0] and position[0]<30 and 20 < position[1] and position[1] < 30):
        five_three_three.append(data_array)
    if (20<position[0] and position[0]<30 and 30 < position[1] and position[1] < 40):
        five_three_four.append(data_array)
    if (20<position[0] and position[0]<30 and 40 < position[1] and position[1] < 50):
        five_three_five.append(data_array)
    if (30<position[0] and position[0]<40 and 0 < position[1] and position[1] < 10):
        five_four_one.append(data_array)
    if (30<position[0] and position[0]<40 and 10 < position[1] and position[1] < 20):
        five_four_two.append(data_array)
    if (30<position[0] and position[0]<40 and 20 < position[1] and position[1] < 30):
        five_four_three.append(data_array)
    if (30<position[0] and position[0]<40 and 30 < position[1] and position[1] < 40):
        five_four_four.append(data_array)
    if (30<position[0] and position[0]<40 and 40 < position[1] and position[1] < 50):
        five_four_five.append(data_array)
    if (40<position[0] and position[0]<50 and 0 < position[1] and position[1] < 10):
        five_five_one.append(data_array)
    if (40<position[0] and position[0]<50 and 10 < position[1] and position[1] < 20):
        five_five_two.append(data_array)
    if (40<position[0] and position[0]<50 and 20 < position[1] and position[1] < 30):
        five_five_three.append(data_array)
    if (40<position[0] and position[0]<50 and 30 < position[1] and position[1] < 40):
        five_five_four.append(data_array)
    if (40<position[0] and position[0]<50 and 40 < position[1] and position[1] < 50):
        five_five_five.append(data_array)

### 利用データの決定
size_x_train_array = []
size_x_test_array = []
position_x_train_array = []
position_x_test_array = []
size_y_train_array = []
size_y_test_array = []
position_y_train_array = []
position_y_test_array = []
for i in range(10):
    size_x_data = []
    size_y_data = []
    position_x_data = []
    position_y_data = []
    #### one_one_oneについて
    index = []
    for i in range(len(one_one_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_one_twoについて
    index = []
    for i in range(len(one_one_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_one_threeについて
    index = []
    for i in range(len(one_one_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_one_fourについて
    index = []
    for i in range(len(one_one_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_one_fiveについて
    index = []
    for i in range(len(one_one_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_oneについて
    index = []
    for i in range(len(one_two_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_twoについて
    index = []
    for i in range(len(one_two_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_threeについて
    index = []
    for i in range(len(one_two_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_fourについて
    index = []
    for i in range(len(one_two_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_two_fiveについて
    index = []
    for i in range(len(one_two_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_oneについて
    index = []
    for i in range(len(one_three_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_twoについて
    index = []
    for i in range(len(one_three_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_threeについて
    index = []
    for i in range(len(one_three_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_fourについて
    index = []
    for i in range(len(one_three_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_three_fiveについて
    index = []
    for i in range(len(one_three_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_oneについて
    index = []
    for i in range(len(one_four_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_twoについて
    index = []
    for i in range(len(one_four_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_threeについて
    index = []
    for i in range(len(one_four_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_fourについて
    index = []
    for i in range(len(one_four_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_four_fiveについて
    index = []
    for i in range(len(one_four_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_oneについて
    index = []
    for i in range(len(one_five_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_twoについて
    index = []
    for i in range(len(one_five_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_threeについて
    index = []
    for i in range(len(one_five_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_fourについて
    index = []
    for i in range(len(one_five_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### one_five_fiveについて
    index = []
    for i in range(len(one_five_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = one_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_oneについて
    index = []
    for i in range(len(two_one_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_twoについて
    index = []
    for i in range(len(two_one_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_threeについて
    index = []
    for i in range(len(two_one_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_fourについて
    index = []
    for i in range(len(two_one_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_one_fiveについて
    index = []
    for i in range(len(two_one_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_oneについて
    index = []
    for i in range(len(two_two_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_twoについて
    index = []
    for i in range(len(two_two_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_threeについて
    index = []
    for i in range(len(two_two_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_fourについて
    index = []
    for i in range(len(two_two_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_two_fiveについて
    index = []
    for i in range(len(two_two_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_oneについて
    index = []
    for i in range(len(two_three_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_twoについて
    index = []
    for i in range(len(two_three_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_threeについて
    index = []
    for i in range(len(two_three_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_fourについて
    index = []
    for i in range(len(two_three_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_three_fiveについて
    index = []
    for i in range(len(two_three_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_oneについて
    index = []
    for i in range(len(two_four_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_twoについて
    index = []
    for i in range(len(two_four_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_threeについて
    index = []
    for i in range(len(two_four_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_fourについて
    index = []
    for i in range(len(two_four_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_four_fiveについて
    index = []
    for i in range(len(two_four_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_oneについて
    index = []
    for i in range(len(two_five_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_twoについて
    index = []
    for i in range(len(two_five_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_threeについて
    index = []
    for i in range(len(two_five_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_fourについて
    index = []
    for i in range(len(two_five_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### two_five_fiveについて
    index = []
    for i in range(len(two_five_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = two_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_oneについて
    index = []
    for i in range(len(three_one_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_twoについて
    index = []
    for i in range(len(three_one_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_threeについて
    index = []
    for i in range(len(three_one_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_fourについて
    index = []
    for i in range(len(three_one_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_one_fiveについて
    index = []
    for i in range(len(three_one_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_oneについて
    index = []
    for i in range(len(three_two_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_twoについて
    index = []
    for i in range(len(three_two_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_threeについて
    index = []
    for i in range(len(three_two_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_fourについて
    index = []
    for i in range(len(three_two_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_two_fiveについて
    index = []
    for i in range(len(three_two_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_oneについて
    index = []
    for i in range(len(three_three_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_twoについて
    index = []
    for i in range(len(three_three_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_threeについて
    index = []
    for i in range(len(three_three_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_fourについて
    index = []
    for i in range(len(three_three_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_three_fiveについて
    index = []
    for i in range(len(three_three_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_oneについて
    index = []
    for i in range(len(three_four_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_twoについて
    index = []
    for i in range(len(three_four_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_threeについて
    index = []
    for i in range(len(three_four_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_fourについて
    index = []
    for i in range(len(three_four_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_four_fiveについて
    index = []
    for i in range(len(three_four_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_oneについて
    index = []
    for i in range(len(three_five_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_twoについて
    index = []
    for i in range(len(three_five_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_threeについて
    index = []
    for i in range(len(three_five_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_fourについて
    index = []
    for i in range(len(three_five_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### three_five_fiveについて
    index = []
    for i in range(len(three_five_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = three_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_oneについて
    index = []
    for i in range(len(four_one_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_twoについて
    index = []
    for i in range(len(four_one_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_threeについて
    index = []
    for i in range(len(four_one_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_fourについて
    index = []
    for i in range(len(four_one_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_one_fiveについて
    index = []
    for i in range(len(four_one_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_oneについて
    index = []
    for i in range(len(four_two_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_twoについて
    index = []
    for i in range(len(four_two_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_threeについて
    index = []
    for i in range(len(four_two_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_fourについて
    index = []
    for i in range(len(four_two_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_two_fiveについて
    index = []
    for i in range(len(four_two_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_oneについて
    index = []
    for i in range(len(four_three_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_twoについて
    index = []
    for i in range(len(four_three_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_threeについて
    index = []
    for i in range(len(four_three_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_fourについて
    index = []
    for i in range(len(four_three_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_three_fiveについて
    index = []
    for i in range(len(four_three_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_oneについて
    index = []
    for i in range(len(four_four_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_twoについて
    index = []
    for i in range(len(four_four_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_threeについて
    index = []
    for i in range(len(four_four_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_fourについて
    index = []
    for i in range(len(four_four_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_four_fiveについて
    index = []
    for i in range(len(four_four_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_oneについて
    index = []
    for i in range(len(four_five_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_twoについて
    index = []
    for i in range(len(four_five_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_threeについて
    index = []
    for i in range(len(four_five_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_fourについて
    index = []
    for i in range(len(four_five_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### four_five_fiveについて
    index = []
    for i in range(len(four_five_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = four_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_oneについて
    index = []
    for i in range(len(five_one_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_twoについて
    index = []
    for i in range(len(five_one_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_threeについて
    index = []
    for i in range(len(five_one_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_fourについて
    index = []
    for i in range(len(five_one_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_one_fiveについて
    index = []
    for i in range(len(five_one_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_one_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_oneについて
    index = []
    for i in range(len(five_two_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_twoについて
    index = []
    for i in range(len(five_two_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_threeについて
    index = []
    for i in range(len(five_two_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_fourについて
    index = []
    for i in range(len(five_two_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_two_fiveについて
    index = []
    for i in range(len(five_two_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_two_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_oneについて
    index = []
    for i in range(len(five_three_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_twoについて
    index = []
    for i in range(len(five_three_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_threeについて
    index = []
    for i in range(len(five_three_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_fourについて
    index = []
    for i in range(len(five_three_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_three_fiveについて
    index = []
    for i in range(len(five_three_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_three_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_oneについて
    index = []
    for i in range(len(five_four_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_twoについて
    index = []
    for i in range(len(five_four_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_threeについて
    index = []
    for i in range(len(five_four_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_fourについて
    index = []
    for i in range(len(five_four_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_four_fiveについて
    index = []
    for i in range(len(five_four_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_four_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_oneについて
    index = []
    for i in range(len(five_five_one)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_one[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_twoについて
    index = []
    for i in range(len(five_five_two)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_two[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_threeについて
    index = []
    for i in range(len(five_five_three)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_three[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_fourについて
    index = []
    for i in range(len(five_five_four)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_four[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])
    #### five_five_fiveについて
    index = []
    for i in range(len(five_five_five)):
        index.append(i)
    data_count = 2
    used_index = random.sample(index, data_count)
    for i in used_index:
        data_array = five_five_five[i]
        size_x_data.append(data_array[3:-1])
        size_y_data.append(data_array[2])
        position_x_data.append(data_array[3:-1])
        position_y_data.append(data_array[0:2])

    ### 各配列をnp.array型にして各要素を型変換
    no_hole_data = np.array(no_hole_data, dtype=float)
    size_x_data = np.array(size_x_data, dtype=float)
    size_y_data = np.array(size_y_data, dtype=int)
    position_x_data = np.array(position_x_data, dtype=float)
    position_y_data = np.array(position_y_data, dtype=float)

    ### データの加工
    size_x_data = (size_x_data-no_hole_data)
    position_x_data = (position_x_data-no_hole_data)
    position_y_data = position_y_data/50
    # print(size_y_data.shape)
    # print(size_x_data.shape)
    # print(size_y_data)
    # print(size_x_data)
    # print(position_y_data.shape)

    ### train用とtest用に分割(4:1)
    size_x_train, size_x_test, size_y_train, size_y_test = train_test_split(size_x_data, size_y_data, test_size=0.20)
    position_x_train, position_x_test, position_y_train, position_y_test = train_test_split(position_x_data, position_y_data, test_size=0.20)


    ### reshape
    size_x_train = size_x_train.reshape(200, 50, 1)
    size_x_test = size_x_test.reshape(50, 50, 1)
    position_x_train = position_x_train.reshape(200, 50, 1)
    position_x_test = position_x_test.reshape(50, 50, 1)

    ### append
    size_x_train_array.append(size_x_train)
    size_x_test_array.append(size_x_test)
    position_x_train_array.append(position_x_train)
    position_x_test_array.append(position_x_test)
    size_y_train_array.append(size_y_train)
    size_y_test_array.append(size_y_test)
    position_y_train_array.append(position_y_train)
    position_y_test_array.append(position_y_test)

# %%
## CNN(大きさ)
size_model_array = []
for i in range(len(size_x_train_array)):
    ### modelの作成
    size_model = Sequential()
    ### 畳み込み層
    size_model.add(Conv1D(32, 3, padding='same', activation='tanh', input_shape=(50, 1)))
    ### プーリング層
    size_model.add(MaxPooling1D(2, padding='same'))
    ### Flatten層
    size_model.add(Flatten())
    ### 全結合層
    size_model.add(Dense(1, activation='linear'))

    ### optimizer
    adam = keras.optimizers.Adam()

    ###modelのコンパイル
    size_model.compile(loss='mse', optimizer=adam, metrics=['accuracy'])
    
    size_model_array.append(size_model)

# %%
# 学習(大きさ)
size_history_array = []
epochs = 1000
batch_size = 128
for i in range(len(size_model_array)):
    size_history = size_model_array[i].fit(size_x_train_array[i], size_y_train_array[i], batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(size_x_test_array[i], size_y_test_array[i]))
    size_history_array.append(size_history)
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 0s 90ms/step - loss: 10.0142 - accuracy: 0.0000e+00 - val_loss: 9.2150 - val_accuracy: 0.1800
# Epoch 2/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 7.0229 - accuracy: 0.2050 - val_loss: 6.4779 - val_accuracy: 0.1800
# Epoch 3/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 4.7431 - accuracy: 0.2050 - val_loss: 4.4865 - val_accuracy: 0.1800
# Epoch 4/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 3.1960 - accuracy: 0.2050 - val_loss: 3.2007 - val_accuracy: 0.1800
# Epoch 5/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 2.3915 - accuracy: 0.2050 - val_loss: 2.5364 - val_accuracy: 0.1800
# Epoch 6/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 2.1146 - accuracy: 0.2050 - val_loss: 2.3449 - val_accuracy: 0.1800
# Epoch 7/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 2.2315 - accuracy: 0.2050 - val_loss: 2.4083 - val_accuracy: 0.1800
# Epoch 8/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 2.4883 - accuracy: 0.2050 - val_loss: 2.5191 - val_accuracy: 0.1800
# Epoch 9/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6950 - accuracy: 0.2050 - val_loss: 2.5592 - val_accuracy: 0.1800
# Epoch 10/1000
# 2/2 [==============================] - 0s 75ms/step - loss: 2.7448 - accuracy: 0.2050 - val_loss: 2.5104 - val_accuracy: 0.1800
# Epoch 11/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 2.6490 - accuracy: 0.2050 - val_loss: 2.4154 - val_accuracy: 0.1800
# Epoch 12/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 2.4680 - accuracy: 0.2050 - val_loss: 2.3382 - val_accuracy: 0.1800
# Epoch 13/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 2.2659 - accuracy: 0.2050 - val_loss: 2.3162 - val_accuracy: 0.1800
# Epoch 14/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 2.1526 - accuracy: 0.2050 - val_loss: 2.3599 - val_accuracy: 0.1800
# Epoch 15/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0974 - accuracy: 0.2050 - val_loss: 2.4501 - val_accuracy: 0.1800
# Epoch 16/1000
# 2/2 [==============================] - 0s 67ms/step - loss: 2.0875 - accuracy: 0.2050 - val_loss: 2.5481 - val_accuracy: 0.1800
# Epoch 17/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 2.1001 - accuracy: 0.2050 - val_loss: 2.6203 - val_accuracy: 0.1800
# Epoch 18/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 2.1312 - accuracy: 0.2050 - val_loss: 2.6575 - val_accuracy: 0.1800
# Epoch 19/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 2.1445 - accuracy: 0.2050 - val_loss: 2.6522 - val_accuracy: 0.1800
# Epoch 20/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 2.1386 - accuracy: 0.2050 - val_loss: 2.6098 - val_accuracy: 0.1800
# Epoch 21/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 2.1136 - accuracy: 0.2050 - val_loss: 2.5447 - val_accuracy: 0.1800
# Epoch 22/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 2.0925 - accuracy: 0.2050 - val_loss: 2.4666 - val_accuracy: 0.1800
# Epoch 23/1000
# 2/2 [==============================] - 0s 45ms/step - loss: 2.0610 - accuracy: 0.2050 - val_loss: 2.4028 - val_accuracy: 0.1800
# Epoch 24/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 2.0489 - accuracy: 0.2050 - val_loss: 2.3523 - val_accuracy: 0.1800
# Epoch 25/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 2.0537 - accuracy: 0.2050 - val_loss: 2.3175 - val_accuracy: 0.1800
# Epoch 26/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0559 - accuracy: 0.2050 - val_loss: 2.2994 - val_accuracy: 0.1800
# Epoch 27/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.0578 - accuracy: 0.2050 - val_loss: 2.2923 - val_accuracy: 0.1800
# Epoch 28/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 2.0567 - accuracy: 0.2050 - val_loss: 2.2914 - val_accuracy: 0.1800
# Epoch 29/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0515 - accuracy: 0.2050 - val_loss: 2.2978 - val_accuracy: 0.1800
# Epoch 30/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 2.0435 - accuracy: 0.2050 - val_loss: 2.3124 - val_accuracy: 0.1800
# Epoch 31/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 2.0348 - accuracy: 0.2050 - val_loss: 2.3307 - val_accuracy: 0.1800
# Epoch 32/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 2.0330 - accuracy: 0.2050 - val_loss: 2.3508 - val_accuracy: 0.1800
# Epoch 33/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 2.0300 - accuracy: 0.2050 - val_loss: 2.3644 - val_accuracy: 0.1800
# Epoch 34/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 2.0307 - accuracy: 0.2050 - val_loss: 2.3697 - val_accuracy: 0.1800
# Epoch 35/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 2.0288 - accuracy: 0.2050 - val_loss: 2.3631 - val_accuracy: 0.1800
# Epoch 36/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0257 - accuracy: 0.2050 - val_loss: 2.3484 - val_accuracy: 0.1800
# Epoch 37/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 2.0224 - accuracy: 0.2050 - val_loss: 2.3330 - val_accuracy: 0.1800
# Epoch 38/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0184 - accuracy: 0.2050 - val_loss: 2.3194 - val_accuracy: 0.1800
# Epoch 39/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0160 - accuracy: 0.2050 - val_loss: 2.3034 - val_accuracy: 0.1800
# Epoch 40/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 2.0145 - accuracy: 0.2050 - val_loss: 2.2901 - val_accuracy: 0.1800
# Epoch 41/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 2.0129 - accuracy: 0.2050 - val_loss: 2.2820 - val_accuracy: 0.1800
# Epoch 42/1000
# 2/2 [==============================] - 0s 45ms/step - loss: 2.0129 - accuracy: 0.2050 - val_loss: 2.2769 - val_accuracy: 0.1800
# Epoch 43/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 2.0100 - accuracy: 0.2050 - val_loss: 2.2802 - val_accuracy: 0.1800
# Epoch 44/1000
# 2/2 [==============================] - 0s 56ms/step - loss: 2.0057 - accuracy: 0.2050 - val_loss: 2.2919 - val_accuracy: 0.1800
# Epoch 45/1000
# 2/2 [==============================] - 0s 40ms/step - loss: 2.0037 - accuracy: 0.2050 - val_loss: 2.3065 - val_accuracy: 0.1800
# Epoch 46/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.0037 - accuracy: 0.2050 - val_loss: 2.3165 - val_accuracy: 0.1800
# Epoch 47/1000
# 2/2 [==============================] - 0s 46ms/step - loss: 2.0035 - accuracy: 0.2050 - val_loss: 2.3195 - val_accuracy: 0.1800
# Epoch 48/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 2.0005 - accuracy: 0.2050 - val_loss: 2.3100 - val_accuracy: 0.1800
# Epoch 49/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.9978 - accuracy: 0.2050 - val_loss: 2.2939 - val_accuracy: 0.1800
# Epoch 50/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.9954 - accuracy: 0.2050 - val_loss: 2.2796 - val_accuracy: 0.1800
# Epoch 51/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 1.9920 - accuracy: 0.2050 - val_loss: 2.2706 - val_accuracy: 0.1800
# Epoch 52/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.9899 - accuracy: 0.2050 - val_loss: 2.2620 - val_accuracy: 0.1800
# Epoch 53/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.9881 - accuracy: 0.2050 - val_loss: 2.2520 - val_accuracy: 0.1800
# Epoch 54/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.9876 - accuracy: 0.2050 - val_loss: 2.2471 - val_accuracy: 0.1800
# Epoch 55/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.9848 - accuracy: 0.2050 - val_loss: 2.2494 - val_accuracy: 0.1800
# Epoch 56/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.9821 - accuracy: 0.2050 - val_loss: 2.2560 - val_accuracy: 0.1800
# Epoch 57/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.9834 - accuracy: 0.2050 - val_loss: 2.2698 - val_accuracy: 0.1800
# Epoch 58/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.9779 - accuracy: 0.2050 - val_loss: 2.2724 - val_accuracy: 0.1800
# Epoch 59/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 1.9782 - accuracy: 0.2050 - val_loss: 2.2748 - val_accuracy: 0.1800
# Epoch 60/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 1.9740 - accuracy: 0.2050 - val_loss: 2.2641 - val_accuracy: 0.1800
# Epoch 61/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 1.9715 - accuracy: 0.2050 - val_loss: 2.2537 - val_accuracy: 0.1800
# Epoch 62/1000
# 2/2 [==============================] - 0s 38ms/step - loss: 1.9692 - accuracy: 0.2050 - val_loss: 2.2458 - val_accuracy: 0.1800
# Epoch 63/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 1.9673 - accuracy: 0.2050 - val_loss: 2.2382 - val_accuracy: 0.1800
# Epoch 64/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 1.9647 - accuracy: 0.2050 - val_loss: 2.2339 - val_accuracy: 0.1800
# Epoch 65/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 1.9629 - accuracy: 0.2050 - val_loss: 2.2321 - val_accuracy: 0.1800
# Epoch 66/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 1.9607 - accuracy: 0.2050 - val_loss: 2.2309 - val_accuracy: 0.1800
# Epoch 67/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 1.9583 - accuracy: 0.2050 - val_loss: 2.2283 - val_accuracy: 0.1800
# Epoch 68/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 1.9567 - accuracy: 0.2050 - val_loss: 2.2273 - val_accuracy: 0.1800
# Epoch 69/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.9542 - accuracy: 0.2050 - val_loss: 2.2234 - val_accuracy: 0.1800
# Epoch 70/1000
# 2/2 [==============================] - 0s 94ms/step - loss: 1.9533 - accuracy: 0.2050 - val_loss: 2.2263 - val_accuracy: 0.1800
# Epoch 71/1000
# 2/2 [==============================] - 0s 56ms/step - loss: 1.9495 - accuracy: 0.2050 - val_loss: 2.2217 - val_accuracy: 0.1800
# Epoch 72/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.9470 - accuracy: 0.2050 - val_loss: 2.2223 - val_accuracy: 0.1800
# Epoch 73/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 1.9443 - accuracy: 0.2050 - val_loss: 2.2209 - val_accuracy: 0.1800
# Epoch 74/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.9421 - accuracy: 0.2050 - val_loss: 2.2195 - val_accuracy: 0.1800
# Epoch 75/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 1.9396 - accuracy: 0.2050 - val_loss: 2.2201 - val_accuracy: 0.1800
# Epoch 76/1000
# 2/2 [==============================] - 0s 86ms/step - loss: 1.9375 - accuracy: 0.2050 - val_loss: 2.2199 - val_accuracy: 0.1800
# Epoch 77/1000
# 2/2 [==============================] - 0s 74ms/step - loss: 1.9351 - accuracy: 0.2050 - val_loss: 2.2215 - val_accuracy: 0.1800
# Epoch 78/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.9331 - accuracy: 0.2050 - val_loss: 2.2217 - val_accuracy: 0.1800
# Epoch 79/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.9314 - accuracy: 0.2050 - val_loss: 2.2167 - val_accuracy: 0.1800
# Epoch 80/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 1.9275 - accuracy: 0.2050 - val_loss: 2.2026 - val_accuracy: 0.1800
# Epoch 81/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.9258 - accuracy: 0.2050 - val_loss: 2.1848 - val_accuracy: 0.1800
# Epoch 82/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.9238 - accuracy: 0.2050 - val_loss: 2.1768 - val_accuracy: 0.1800
# Epoch 83/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.9221 - accuracy: 0.2050 - val_loss: 2.1757 - val_accuracy: 0.1800
# Epoch 84/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.9203 - accuracy: 0.2050 - val_loss: 2.1834 - val_accuracy: 0.1800
# Epoch 85/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.9157 - accuracy: 0.2050 - val_loss: 2.1876 - val_accuracy: 0.1800
# Epoch 86/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 1.9124 - accuracy: 0.2050 - val_loss: 2.1896 - val_accuracy: 0.1800
# Epoch 87/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.9105 - accuracy: 0.2050 - val_loss: 2.1921 - val_accuracy: 0.1800
# Epoch 88/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.9078 - accuracy: 0.2050 - val_loss: 2.1983 - val_accuracy: 0.1800
# Epoch 89/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.9049 - accuracy: 0.2050 - val_loss: 2.1982 - val_accuracy: 0.1800
# Epoch 90/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.9027 - accuracy: 0.2050 - val_loss: 2.1934 - val_accuracy: 0.1800
# Epoch 91/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8992 - accuracy: 0.2050 - val_loss: 2.1811 - val_accuracy: 0.1800
# Epoch 92/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8976 - accuracy: 0.2050 - val_loss: 2.1626 - val_accuracy: 0.1800
# Epoch 93/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.8943 - accuracy: 0.2050 - val_loss: 2.1559 - val_accuracy: 0.1800
# Epoch 94/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8925 - accuracy: 0.2050 - val_loss: 2.1514 - val_accuracy: 0.1800
# Epoch 95/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8902 - accuracy: 0.2050 - val_loss: 2.1567 - val_accuracy: 0.1800
# Epoch 96/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.8913 - accuracy: 0.2050 - val_loss: 2.1625 - val_accuracy: 0.1800
# Epoch 97/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.8822 - accuracy: 0.2050 - val_loss: 2.1553 - val_accuracy: 0.1800
# Epoch 98/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.8808 - accuracy: 0.2050 - val_loss: 2.1485 - val_accuracy: 0.1800
# Epoch 99/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.8773 - accuracy: 0.2050 - val_loss: 2.1527 - val_accuracy: 0.1800
# Epoch 100/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 1.8736 - accuracy: 0.2050 - val_loss: 2.1643 - val_accuracy: 0.1800
# Epoch 101/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8702 - accuracy: 0.2050 - val_loss: 2.1706 - val_accuracy: 0.1800
# Epoch 102/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.8689 - accuracy: 0.2050 - val_loss: 2.1711 - val_accuracy: 0.1800
# Epoch 103/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8651 - accuracy: 0.2050 - val_loss: 2.1592 - val_accuracy: 0.1800
# Epoch 104/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8627 - accuracy: 0.2050 - val_loss: 2.1397 - val_accuracy: 0.1800
# Epoch 105/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 1.8593 - accuracy: 0.2050 - val_loss: 2.1297 - val_accuracy: 0.1800
# Epoch 106/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8546 - accuracy: 0.2050 - val_loss: 2.1313 - val_accuracy: 0.1800
# Epoch 107/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.8511 - accuracy: 0.2050 - val_loss: 2.1324 - val_accuracy: 0.1800
# Epoch 108/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.8504 - accuracy: 0.2050 - val_loss: 2.1357 - val_accuracy: 0.1800
# Epoch 109/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.8445 - accuracy: 0.2050 - val_loss: 2.1262 - val_accuracy: 0.1800
# Epoch 110/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.8412 - accuracy: 0.2050 - val_loss: 2.1168 - val_accuracy: 0.1800
# Epoch 111/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.8380 - accuracy: 0.2050 - val_loss: 2.1042 - val_accuracy: 0.1800
# Epoch 112/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 1.8351 - accuracy: 0.2050 - val_loss: 2.0949 - val_accuracy: 0.1800
# Epoch 113/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.8324 - accuracy: 0.2050 - val_loss: 2.0888 - val_accuracy: 0.1800
# Epoch 114/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.8292 - accuracy: 0.2050 - val_loss: 2.0845 - val_accuracy: 0.1800
# Epoch 115/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.8256 - accuracy: 0.2050 - val_loss: 2.0873 - val_accuracy: 0.1800
# Epoch 116/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.8246 - accuracy: 0.2050 - val_loss: 2.1015 - val_accuracy: 0.1800
# Epoch 117/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.8191 - accuracy: 0.2050 - val_loss: 2.1017 - val_accuracy: 0.1800
# Epoch 118/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.8136 - accuracy: 0.2050 - val_loss: 2.0877 - val_accuracy: 0.1800
# Epoch 119/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.8097 - accuracy: 0.2050 - val_loss: 2.0699 - val_accuracy: 0.1800
# Epoch 120/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.8065 - accuracy: 0.2050 - val_loss: 2.0569 - val_accuracy: 0.1800
# Epoch 121/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.8040 - accuracy: 0.2050 - val_loss: 2.0505 - val_accuracy: 0.1800
# Epoch 122/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.8005 - accuracy: 0.2050 - val_loss: 2.0507 - val_accuracy: 0.1800
# Epoch 123/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.7973 - accuracy: 0.2050 - val_loss: 2.0569 - val_accuracy: 0.1800
# Epoch 124/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.7918 - accuracy: 0.2050 - val_loss: 2.0581 - val_accuracy: 0.1800
# Epoch 125/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 1.7877 - accuracy: 0.2050 - val_loss: 2.0651 - val_accuracy: 0.1800
# Epoch 126/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.7830 - accuracy: 0.2050 - val_loss: 2.0639 - val_accuracy: 0.1800
# Epoch 127/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.7794 - accuracy: 0.2050 - val_loss: 2.0610 - val_accuracy: 0.1800
# Epoch 128/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.7751 - accuracy: 0.2050 - val_loss: 2.0517 - val_accuracy: 0.1800
# Epoch 129/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.7743 - accuracy: 0.2050 - val_loss: 2.0418 - val_accuracy: 0.1800
# Epoch 130/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.7670 - accuracy: 0.2050 - val_loss: 2.0454 - val_accuracy: 0.1800
# Epoch 131/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.7626 - accuracy: 0.2050 - val_loss: 2.0503 - val_accuracy: 0.1800
# Epoch 132/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.7602 - accuracy: 0.2050 - val_loss: 2.0492 - val_accuracy: 0.1800
# Epoch 133/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.7546 - accuracy: 0.2050 - val_loss: 2.0324 - val_accuracy: 0.1800
# Epoch 134/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.7508 - accuracy: 0.2050 - val_loss: 2.0136 - val_accuracy: 0.1800
# Epoch 135/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.7462 - accuracy: 0.2050 - val_loss: 2.0035 - val_accuracy: 0.1800
# Epoch 136/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.7423 - accuracy: 0.2050 - val_loss: 2.0008 - val_accuracy: 0.1800
# Epoch 137/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.7400 - accuracy: 0.2050 - val_loss: 2.0065 - val_accuracy: 0.1800
# Epoch 138/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.7333 - accuracy: 0.2050 - val_loss: 2.0015 - val_accuracy: 0.1800
# Epoch 139/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.7289 - accuracy: 0.2050 - val_loss: 2.0035 - val_accuracy: 0.1800
# Epoch 140/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.7239 - accuracy: 0.2050 - val_loss: 1.9975 - val_accuracy: 0.1800
# Epoch 141/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.7215 - accuracy: 0.2050 - val_loss: 1.9912 - val_accuracy: 0.1800
# Epoch 142/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.7147 - accuracy: 0.2050 - val_loss: 1.9993 - val_accuracy: 0.1800
# Epoch 143/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.7126 - accuracy: 0.2050 - val_loss: 2.0123 - val_accuracy: 0.1800
# Epoch 144/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.7078 - accuracy: 0.2050 - val_loss: 2.0026 - val_accuracy: 0.1800
# Epoch 145/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.7044 - accuracy: 0.2050 - val_loss: 1.9793 - val_accuracy: 0.1800
# Epoch 146/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.6964 - accuracy: 0.2050 - val_loss: 1.9669 - val_accuracy: 0.1800
# Epoch 147/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.6917 - accuracy: 0.2050 - val_loss: 1.9588 - val_accuracy: 0.1800
# Epoch 148/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.6864 - accuracy: 0.2050 - val_loss: 1.9580 - val_accuracy: 0.1800
# Epoch 149/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.6831 - accuracy: 0.2050 - val_loss: 1.9572 - val_accuracy: 0.1800
# Epoch 150/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.6770 - accuracy: 0.2050 - val_loss: 1.9459 - val_accuracy: 0.1800
# Epoch 151/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.6718 - accuracy: 0.2050 - val_loss: 1.9287 - val_accuracy: 0.1800
# Epoch 152/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6680 - accuracy: 0.2050 - val_loss: 1.9230 - val_accuracy: 0.1800
# Epoch 153/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.6628 - accuracy: 0.2050 - val_loss: 1.9287 - val_accuracy: 0.1800
# Epoch 154/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.6567 - accuracy: 0.2050 - val_loss: 1.9382 - val_accuracy: 0.1800
# Epoch 155/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.6502 - accuracy: 0.2050 - val_loss: 1.9570 - val_accuracy: 0.1800
# Epoch 156/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.6497 - accuracy: 0.2050 - val_loss: 1.9683 - val_accuracy: 0.1800
# Epoch 157/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.6462 - accuracy: 0.2050 - val_loss: 1.9516 - val_accuracy: 0.1800
# Epoch 158/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.6387 - accuracy: 0.2050 - val_loss: 1.9337 - val_accuracy: 0.1800
# Epoch 159/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.6314 - accuracy: 0.2050 - val_loss: 1.9012 - val_accuracy: 0.1800
# Epoch 160/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.6260 - accuracy: 0.2050 - val_loss: 1.8802 - val_accuracy: 0.1800
# Epoch 161/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6220 - accuracy: 0.2050 - val_loss: 1.8743 - val_accuracy: 0.1800
# Epoch 162/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.6168 - accuracy: 0.2050 - val_loss: 1.8784 - val_accuracy: 0.1800
# Epoch 163/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6120 - accuracy: 0.2050 - val_loss: 1.8872 - val_accuracy: 0.1800
# Epoch 164/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.6045 - accuracy: 0.2050 - val_loss: 1.8888 - val_accuracy: 0.1800
# Epoch 165/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.5998 - accuracy: 0.2050 - val_loss: 1.8979 - val_accuracy: 0.1800
# Epoch 166/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.5943 - accuracy: 0.2050 - val_loss: 1.8917 - val_accuracy: 0.1800
# Epoch 167/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.5879 - accuracy: 0.2050 - val_loss: 1.8795 - val_accuracy: 0.1800
# Epoch 168/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.5823 - accuracy: 0.2050 - val_loss: 1.8620 - val_accuracy: 0.1800
# Epoch 169/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.5785 - accuracy: 0.2050 - val_loss: 1.8517 - val_accuracy: 0.1800
# Epoch 170/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.5718 - accuracy: 0.2050 - val_loss: 1.8579 - val_accuracy: 0.1800
# Epoch 171/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.5665 - accuracy: 0.2050 - val_loss: 1.8624 - val_accuracy: 0.1800
# Epoch 172/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.5620 - accuracy: 0.2050 - val_loss: 1.8579 - val_accuracy: 0.1800
# Epoch 173/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5552 - accuracy: 0.2050 - val_loss: 1.8657 - val_accuracy: 0.1800
# Epoch 174/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.5499 - accuracy: 0.2050 - val_loss: 1.8614 - val_accuracy: 0.1800
# Epoch 175/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 1.5445 - accuracy: 0.2050 - val_loss: 1.8486 - val_accuracy: 0.1800
# Epoch 176/1000
# 2/2 [==============================] - 0s 49ms/step - loss: 1.5409 - accuracy: 0.2050 - val_loss: 1.8270 - val_accuracy: 0.1800
# Epoch 177/1000
# 2/2 [==============================] - 0s 41ms/step - loss: 1.5329 - accuracy: 0.2050 - val_loss: 1.8213 - val_accuracy: 0.1800
# Epoch 178/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 1.5266 - accuracy: 0.2050 - val_loss: 1.8231 - val_accuracy: 0.1800
# Epoch 179/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 1.5266 - accuracy: 0.2050 - val_loss: 1.8250 - val_accuracy: 0.1800
# Epoch 180/1000
# 2/2 [==============================] - 0s 46ms/step - loss: 1.5174 - accuracy: 0.2050 - val_loss: 1.8005 - val_accuracy: 0.1800
# Epoch 181/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5097 - accuracy: 0.2050 - val_loss: 1.7679 - val_accuracy: 0.1800
# Epoch 182/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 1.5137 - accuracy: 0.2050 - val_loss: 1.7545 - val_accuracy: 0.1800
# Epoch 183/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.5088 - accuracy: 0.2050 - val_loss: 1.7730 - val_accuracy: 0.1800
# Epoch 184/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.4985 - accuracy: 0.2050 - val_loss: 1.7890 - val_accuracy: 0.1800
# Epoch 185/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.4878 - accuracy: 0.2050 - val_loss: 1.7893 - val_accuracy: 0.1800
# Epoch 186/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.4822 - accuracy: 0.2050 - val_loss: 1.7822 - val_accuracy: 0.1800
# Epoch 187/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.4770 - accuracy: 0.2050 - val_loss: 1.7740 - val_accuracy: 0.1800
# Epoch 188/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4715 - accuracy: 0.2050 - val_loss: 1.7685 - val_accuracy: 0.1800
# Epoch 189/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.4659 - accuracy: 0.2050 - val_loss: 1.7723 - val_accuracy: 0.1800
# Epoch 190/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.4599 - accuracy: 0.2050 - val_loss: 1.7859 - val_accuracy: 0.1800
# Epoch 191/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.4552 - accuracy: 0.2050 - val_loss: 1.7839 - val_accuracy: 0.1800
# Epoch 192/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 1.4500 - accuracy: 0.2050 - val_loss: 1.7706 - val_accuracy: 0.1800
# Epoch 193/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.4423 - accuracy: 0.2050 - val_loss: 1.7434 - val_accuracy: 0.1800
# Epoch 194/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.4406 - accuracy: 0.2050 - val_loss: 1.7170 - val_accuracy: 0.1800
# Epoch 195/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.4340 - accuracy: 0.2050 - val_loss: 1.7171 - val_accuracy: 0.1800
# Epoch 196/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.4270 - accuracy: 0.2050 - val_loss: 1.7218 - val_accuracy: 0.1800
# Epoch 197/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.4218 - accuracy: 0.2050 - val_loss: 1.7393 - val_accuracy: 0.1800
# Epoch 198/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.4161 - accuracy: 0.2050 - val_loss: 1.7407 - val_accuracy: 0.1800
# Epoch 199/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.4099 - accuracy: 0.2050 - val_loss: 1.7220 - val_accuracy: 0.1800
# Epoch 200/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.4025 - accuracy: 0.2050 - val_loss: 1.7096 - val_accuracy: 0.1800
# Epoch 201/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.3978 - accuracy: 0.2050 - val_loss: 1.6953 - val_accuracy: 0.1800
# Epoch 202/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3920 - accuracy: 0.2050 - val_loss: 1.6944 - val_accuracy: 0.1800
# Epoch 203/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.3856 - accuracy: 0.2050 - val_loss: 1.7021 - val_accuracy: 0.1800
# Epoch 204/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.3815 - accuracy: 0.2050 - val_loss: 1.7076 - val_accuracy: 0.1800
# Epoch 205/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3752 - accuracy: 0.2050 - val_loss: 1.6936 - val_accuracy: 0.1800
# Epoch 206/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.3690 - accuracy: 0.2050 - val_loss: 1.6731 - val_accuracy: 0.1800
# Epoch 207/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.3674 - accuracy: 0.2050 - val_loss: 1.6560 - val_accuracy: 0.1800
# Epoch 208/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.3588 - accuracy: 0.2050 - val_loss: 1.6660 - val_accuracy: 0.1800
# Epoch 209/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.3519 - accuracy: 0.2050 - val_loss: 1.6770 - val_accuracy: 0.1800
# Epoch 210/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.3465 - accuracy: 0.2050 - val_loss: 1.6927 - val_accuracy: 0.1800
# Epoch 211/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 1.3446 - accuracy: 0.2050 - val_loss: 1.7037 - val_accuracy: 0.1800
# Epoch 212/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.3397 - accuracy: 0.2050 - val_loss: 1.6770 - val_accuracy: 0.1800
# Epoch 213/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3302 - accuracy: 0.2050 - val_loss: 1.6347 - val_accuracy: 0.1800
# Epoch 214/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.3239 - accuracy: 0.2050 - val_loss: 1.6096 - val_accuracy: 0.1800
# Epoch 215/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.3238 - accuracy: 0.2050 - val_loss: 1.6034 - val_accuracy: 0.1800
# Epoch 216/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.3211 - accuracy: 0.2050 - val_loss: 1.6074 - val_accuracy: 0.1800
# Epoch 217/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.3102 - accuracy: 0.2050 - val_loss: 1.6105 - val_accuracy: 0.1800
# Epoch 218/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3045 - accuracy: 0.2050 - val_loss: 1.6198 - val_accuracy: 0.1800
# Epoch 219/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2966 - accuracy: 0.2050 - val_loss: 1.6231 - val_accuracy: 0.1800
# Epoch 220/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.2912 - accuracy: 0.2050 - val_loss: 1.6342 - val_accuracy: 0.1800
# Epoch 221/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2861 - accuracy: 0.2050 - val_loss: 1.6287 - val_accuracy: 0.1800
# Epoch 222/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.2818 - accuracy: 0.2050 - val_loss: 1.6233 - val_accuracy: 0.1800
# Epoch 223/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.2790 - accuracy: 0.2050 - val_loss: 1.6012 - val_accuracy: 0.1800
# Epoch 224/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.2695 - accuracy: 0.2050 - val_loss: 1.6023 - val_accuracy: 0.1800
# Epoch 225/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.2631 - accuracy: 0.2050 - val_loss: 1.6133 - val_accuracy: 0.1800
# Epoch 226/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.2598 - accuracy: 0.2050 - val_loss: 1.6155 - val_accuracy: 0.1800
# Epoch 227/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.2537 - accuracy: 0.2050 - val_loss: 1.5971 - val_accuracy: 0.1800
# Epoch 228/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 1.2477 - accuracy: 0.2050 - val_loss: 1.5721 - val_accuracy: 0.1800
# Epoch 229/1000
# 2/2 [==============================] - 0s 51ms/step - loss: 1.2426 - accuracy: 0.2050 - val_loss: 1.5626 - val_accuracy: 0.1800
# Epoch 230/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 1.2389 - accuracy: 0.2050 - val_loss: 1.5639 - val_accuracy: 0.1800
# Epoch 231/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2320 - accuracy: 0.2050 - val_loss: 1.5606 - val_accuracy: 0.1800
# Epoch 232/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.2271 - accuracy: 0.2050 - val_loss: 1.5696 - val_accuracy: 0.1800
# Epoch 233/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.2202 - accuracy: 0.2050 - val_loss: 1.5926 - val_accuracy: 0.1800
# Epoch 234/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.2175 - accuracy: 0.2050 - val_loss: 1.5961 - val_accuracy: 0.1800
# Epoch 235/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.2144 - accuracy: 0.2050 - val_loss: 1.5792 - val_accuracy: 0.1800
# Epoch 236/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.2070 - accuracy: 0.2050 - val_loss: 1.5447 - val_accuracy: 0.1800
# Epoch 237/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1993 - accuracy: 0.2050 - val_loss: 1.5217 - val_accuracy: 0.1800
# Epoch 238/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 1.1955 - accuracy: 0.2050 - val_loss: 1.5006 - val_accuracy: 0.1800
# Epoch 239/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1941 - accuracy: 0.2050 - val_loss: 1.5013 - val_accuracy: 0.1800
# Epoch 240/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1880 - accuracy: 0.2050 - val_loss: 1.5175 - val_accuracy: 0.1800
# Epoch 241/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1841 - accuracy: 0.2050 - val_loss: 1.5616 - val_accuracy: 0.1800
# Epoch 242/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.1784 - accuracy: 0.2050 - val_loss: 1.5582 - val_accuracy: 0.1800
# Epoch 243/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.1734 - accuracy: 0.2050 - val_loss: 1.5391 - val_accuracy: 0.1800
# Epoch 244/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1703 - accuracy: 0.2050 - val_loss: 1.5081 - val_accuracy: 0.1800
# Epoch 245/1000
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1623 - accuracy: 0.2050 - val_loss: 1.4981 - val_accuracy: 0.1800
# Epoch 246/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 1.1552 - accuracy: 0.2050 - val_loss: 1.4727 - val_accuracy: 0.1800
# Epoch 247/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 1.1527 - accuracy: 0.2050 - val_loss: 1.4704 - val_accuracy: 0.1800
# Epoch 248/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.1481 - accuracy: 0.2050 - val_loss: 1.4892 - val_accuracy: 0.1800
# Epoch 249/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1396 - accuracy: 0.2050 - val_loss: 1.4930 - val_accuracy: 0.1800
# Epoch 250/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.1389 - accuracy: 0.2050 - val_loss: 1.4875 - val_accuracy: 0.1800
# Epoch 251/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1302 - accuracy: 0.2050 - val_loss: 1.4995 - val_accuracy: 0.1800
# Epoch 252/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.1282 - accuracy: 0.2050 - val_loss: 1.5046 - val_accuracy: 0.1800
# Epoch 253/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.1233 - accuracy: 0.2050 - val_loss: 1.4789 - val_accuracy: 0.1800
# Epoch 254/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1162 - accuracy: 0.2050 - val_loss: 1.4461 - val_accuracy: 0.1800
# Epoch 255/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1164 - accuracy: 0.2050 - val_loss: 1.4343 - val_accuracy: 0.1800
# Epoch 256/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 1.1083 - accuracy: 0.2050 - val_loss: 1.4538 - val_accuracy: 0.1800
# Epoch 257/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0995 - accuracy: 0.2050 - val_loss: 1.4926 - val_accuracy: 0.1800
# Epoch 258/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1017 - accuracy: 0.2050 - val_loss: 1.5145 - val_accuracy: 0.1800
# Epoch 259/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 1.1040 - accuracy: 0.2050 - val_loss: 1.4907 - val_accuracy: 0.1800
# Epoch 260/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0991 - accuracy: 0.2050 - val_loss: 1.4326 - val_accuracy: 0.1800
# Epoch 261/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0876 - accuracy: 0.2050 - val_loss: 1.4137 - val_accuracy: 0.1800
# Epoch 262/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0810 - accuracy: 0.2050 - val_loss: 1.4241 - val_accuracy: 0.1800
# Epoch 263/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.0764 - accuracy: 0.2050 - val_loss: 1.4451 - val_accuracy: 0.1800
# Epoch 264/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0735 - accuracy: 0.2050 - val_loss: 1.4436 - val_accuracy: 0.1800
# Epoch 265/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0664 - accuracy: 0.2050 - val_loss: 1.4159 - val_accuracy: 0.1800
# Epoch 266/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0634 - accuracy: 0.2050 - val_loss: 1.3960 - val_accuracy: 0.1800
# Epoch 267/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0617 - accuracy: 0.2050 - val_loss: 1.4006 - val_accuracy: 0.1800
# Epoch 268/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0566 - accuracy: 0.2050 - val_loss: 1.4314 - val_accuracy: 0.1800
# Epoch 269/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 1.0504 - accuracy: 0.2050 - val_loss: 1.4320 - val_accuracy: 0.1800
# Epoch 270/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0487 - accuracy: 0.2050 - val_loss: 1.4129 - val_accuracy: 0.1800
# Epoch 271/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0411 - accuracy: 0.2050 - val_loss: 1.4033 - val_accuracy: 0.1800
# Epoch 272/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0368 - accuracy: 0.2050 - val_loss: 1.3903 - val_accuracy: 0.1800
# Epoch 273/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0318 - accuracy: 0.2050 - val_loss: 1.3710 - val_accuracy: 0.1800
# Epoch 274/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0289 - accuracy: 0.2050 - val_loss: 1.3596 - val_accuracy: 0.1800
# Epoch 275/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0277 - accuracy: 0.2050 - val_loss: 1.3606 - val_accuracy: 0.1800
# Epoch 276/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0211 - accuracy: 0.2050 - val_loss: 1.3603 - val_accuracy: 0.1800
# Epoch 277/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0168 - accuracy: 0.2050 - val_loss: 1.3622 - val_accuracy: 0.1800
# Epoch 278/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 1.0110 - accuracy: 0.2050 - val_loss: 1.3779 - val_accuracy: 0.1800
# Epoch 279/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0089 - accuracy: 0.2050 - val_loss: 1.3827 - val_accuracy: 0.1800
# Epoch 280/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0056 - accuracy: 0.2050 - val_loss: 1.3627 - val_accuracy: 0.1800
# Epoch 281/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0009 - accuracy: 0.2050 - val_loss: 1.3464 - val_accuracy: 0.1800
# Epoch 282/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9980 - accuracy: 0.2050 - val_loss: 1.3206 - val_accuracy: 0.1800
# Epoch 283/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.9962 - accuracy: 0.2050 - val_loss: 1.3228 - val_accuracy: 0.1800
# Epoch 284/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9891 - accuracy: 0.2050 - val_loss: 1.3221 - val_accuracy: 0.1800
# Epoch 285/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.9841 - accuracy: 0.2050 - val_loss: 1.3360 - val_accuracy: 0.1800
# Epoch 286/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.9795 - accuracy: 0.2050 - val_loss: 1.3584 - val_accuracy: 0.1800
# Epoch 287/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.9794 - accuracy: 0.2050 - val_loss: 1.3550 - val_accuracy: 0.1800
# Epoch 288/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.9749 - accuracy: 0.2050 - val_loss: 1.3260 - val_accuracy: 0.1800
# Epoch 289/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.9680 - accuracy: 0.2050 - val_loss: 1.2936 - val_accuracy: 0.1800
# Epoch 290/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9669 - accuracy: 0.2050 - val_loss: 1.2801 - val_accuracy: 0.1800
# Epoch 291/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9640 - accuracy: 0.2050 - val_loss: 1.2904 - val_accuracy: 0.1800
# Epoch 292/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9567 - accuracy: 0.2050 - val_loss: 1.3165 - val_accuracy: 0.1800
# Epoch 293/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9559 - accuracy: 0.2050 - val_loss: 1.3476 - val_accuracy: 0.1800
# Epoch 294/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9589 - accuracy: 0.2050 - val_loss: 1.3273 - val_accuracy: 0.1800
# Epoch 295/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9519 - accuracy: 0.2050 - val_loss: 1.2989 - val_accuracy: 0.1800
# Epoch 296/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9428 - accuracy: 0.2050 - val_loss: 1.2793 - val_accuracy: 0.1800
# Epoch 297/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.9376 - accuracy: 0.2050 - val_loss: 1.2569 - val_accuracy: 0.1800
# Epoch 298/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9378 - accuracy: 0.2050 - val_loss: 1.2445 - val_accuracy: 0.1800
# Epoch 299/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9367 - accuracy: 0.2050 - val_loss: 1.2548 - val_accuracy: 0.1800
# Epoch 300/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.9275 - accuracy: 0.2050 - val_loss: 1.2730 - val_accuracy: 0.1800
# Epoch 301/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9233 - accuracy: 0.2050 - val_loss: 1.2955 - val_accuracy: 0.1800
# Epoch 302/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9234 - accuracy: 0.2050 - val_loss: 1.2930 - val_accuracy: 0.1800
# Epoch 303/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9183 - accuracy: 0.2050 - val_loss: 1.2641 - val_accuracy: 0.1800
# Epoch 304/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9146 - accuracy: 0.2050 - val_loss: 1.2389 - val_accuracy: 0.1800
# Epoch 305/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9105 - accuracy: 0.2050 - val_loss: 1.2372 - val_accuracy: 0.1800
# Epoch 306/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9071 - accuracy: 0.2050 - val_loss: 1.2401 - val_accuracy: 0.1800
# Epoch 307/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.9016 - accuracy: 0.2050 - val_loss: 1.2597 - val_accuracy: 0.1800
# Epoch 308/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9006 - accuracy: 0.2050 - val_loss: 1.2807 - val_accuracy: 0.1800
# Epoch 309/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.9002 - accuracy: 0.2050 - val_loss: 1.2566 - val_accuracy: 0.1800
# Epoch 310/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.8916 - accuracy: 0.2050 - val_loss: 1.2217 - val_accuracy: 0.1800
# Epoch 311/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.8915 - accuracy: 0.2050 - val_loss: 1.1942 - val_accuracy: 0.1800
# Epoch 312/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.8886 - accuracy: 0.2050 - val_loss: 1.2007 - val_accuracy: 0.1800
# Epoch 313/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8806 - accuracy: 0.2050 - val_loss: 1.2230 - val_accuracy: 0.1800
# Epoch 314/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.8766 - accuracy: 0.2050 - val_loss: 1.2490 - val_accuracy: 0.1800
# Epoch 315/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8798 - accuracy: 0.2050 - val_loss: 1.2590 - val_accuracy: 0.1800
# Epoch 316/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8812 - accuracy: 0.2050 - val_loss: 1.2185 - val_accuracy: 0.1800
# Epoch 317/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.8672 - accuracy: 0.2050 - val_loss: 1.1881 - val_accuracy: 0.1800
# Epoch 318/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8633 - accuracy: 0.2050 - val_loss: 1.1688 - val_accuracy: 0.1800
# Epoch 319/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.8632 - accuracy: 0.2050 - val_loss: 1.1659 - val_accuracy: 0.1800
# Epoch 320/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8578 - accuracy: 0.2050 - val_loss: 1.1850 - val_accuracy: 0.1800
# Epoch 321/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.8530 - accuracy: 0.2050 - val_loss: 1.2031 - val_accuracy: 0.1800
# Epoch 322/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8541 - accuracy: 0.2050 - val_loss: 1.1939 - val_accuracy: 0.1800
# Epoch 323/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8533 - accuracy: 0.2050 - val_loss: 1.1588 - val_accuracy: 0.1800
# Epoch 324/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8465 - accuracy: 0.2050 - val_loss: 1.1554 - val_accuracy: 0.1800
# Epoch 325/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.8398 - accuracy: 0.2050 - val_loss: 1.1434 - val_accuracy: 0.1800
# Epoch 326/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.8381 - accuracy: 0.2050 - val_loss: 1.1477 - val_accuracy: 0.1800
# Epoch 327/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8325 - accuracy: 0.2050 - val_loss: 1.1696 - val_accuracy: 0.1800
# Epoch 328/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8301 - accuracy: 0.2050 - val_loss: 1.1976 - val_accuracy: 0.1800
# Epoch 329/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8342 - accuracy: 0.2050 - val_loss: 1.1780 - val_accuracy: 0.1800
# Epoch 330/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8292 - accuracy: 0.2050 - val_loss: 1.1331 - val_accuracy: 0.1800
# Epoch 331/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8223 - accuracy: 0.2050 - val_loss: 1.1163 - val_accuracy: 0.1800
# Epoch 332/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8172 - accuracy: 0.2050 - val_loss: 1.1250 - val_accuracy: 0.1800
# Epoch 333/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.8127 - accuracy: 0.2050 - val_loss: 1.1317 - val_accuracy: 0.1800
# Epoch 334/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.8100 - accuracy: 0.2050 - val_loss: 1.1396 - val_accuracy: 0.1800
# Epoch 335/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8086 - accuracy: 0.2050 - val_loss: 1.1266 - val_accuracy: 0.1800
# Epoch 336/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.8038 - accuracy: 0.2050 - val_loss: 1.1024 - val_accuracy: 0.1800
# Epoch 337/1000
# ...
# Epoch 890/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2009 - accuracy: 0.1950 - val_loss: 1.1751 - val_accuracy: 0.2200
# Epoch 891/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2032 - accuracy: 0.1950 - val_loss: 1.1746 - val_accuracy: 0.2200
# Epoch 892/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1997 - accuracy: 0.1950 - val_loss: 1.1967 - val_accuracy: 0.2200
# Epoch 893/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2055 - accuracy: 0.1950 - val_loss: 1.1878 - val_accuracy: 0.2200
# Epoch 894/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1990 - accuracy: 0.1950 - val_loss: 1.1721 - val_accuracy: 0.2200
# Epoch 895/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2064 - accuracy: 0.1950 - val_loss: 1.1763 - val_accuracy: 0.2200
# Epoch 896/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2050 - accuracy: 0.1950 - val_loss: 1.1888 - val_accuracy: 0.2200
# Epoch 897/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2026 - accuracy: 0.1950 - val_loss: 1.1718 - val_accuracy: 0.2200
# Epoch 898/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2013 - accuracy: 0.1950 - val_loss: 1.1738 - val_accuracy: 0.2200
# Epoch 899/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2000 - accuracy: 0.1950 - val_loss: 1.1763 - val_accuracy: 0.2200
# Epoch 900/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2000 - accuracy: 0.1950 - val_loss: 1.1803 - val_accuracy: 0.2200
# Epoch 901/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2002 - accuracy: 0.1950 - val_loss: 1.1732 - val_accuracy: 0.2200
# Epoch 902/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2007 - accuracy: 0.1950 - val_loss: 1.1712 - val_accuracy: 0.2200
# Epoch 903/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2006 - accuracy: 0.1950 - val_loss: 1.1867 - val_accuracy: 0.2200
# Epoch 904/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2009 - accuracy: 0.1950 - val_loss: 1.1937 - val_accuracy: 0.2200
# Epoch 905/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2035 - accuracy: 0.1950 - val_loss: 1.1783 - val_accuracy: 0.2200
# Epoch 906/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2000 - accuracy: 0.1950 - val_loss: 1.1823 - val_accuracy: 0.2200
# Epoch 907/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1998 - accuracy: 0.1950 - val_loss: 1.1871 - val_accuracy: 0.2200
# Epoch 908/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1997 - accuracy: 0.1950 - val_loss: 1.1776 - val_accuracy: 0.2200
# Epoch 909/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1996 - accuracy: 0.1950 - val_loss: 1.1759 - val_accuracy: 0.2200
# Epoch 910/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1997 - accuracy: 0.1950 - val_loss: 1.1775 - val_accuracy: 0.2200
# Epoch 911/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1993 - accuracy: 0.1950 - val_loss: 1.1799 - val_accuracy: 0.2200
# Epoch 912/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1993 - accuracy: 0.1950 - val_loss: 1.1761 - val_accuracy: 0.2200
# Epoch 913/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1992 - accuracy: 0.1950 - val_loss: 1.1760 - val_accuracy: 0.2200
# Epoch 914/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1994 - accuracy: 0.1950 - val_loss: 1.1801 - val_accuracy: 0.2200
# Epoch 915/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1991 - accuracy: 0.1950 - val_loss: 1.1794 - val_accuracy: 0.2200
# Epoch 916/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1993 - accuracy: 0.1950 - val_loss: 1.1808 - val_accuracy: 0.2200
# Epoch 917/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1999 - accuracy: 0.1950 - val_loss: 1.1782 - val_accuracy: 0.2200
# Epoch 918/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1998 - accuracy: 0.1950 - val_loss: 1.1747 - val_accuracy: 0.2200
# Epoch 919/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2006 - accuracy: 0.1950 - val_loss: 1.1862 - val_accuracy: 0.2200
# Epoch 920/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2006 - accuracy: 0.1950 - val_loss: 1.1969 - val_accuracy: 0.2200
# Epoch 921/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2016 - accuracy: 0.1950 - val_loss: 1.1778 - val_accuracy: 0.2200
# Epoch 922/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2004 - accuracy: 0.1950 - val_loss: 1.1789 - val_accuracy: 0.2200
# Epoch 923/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2005 - accuracy: 0.1950 - val_loss: 1.1871 - val_accuracy: 0.2200
# Epoch 924/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2014 - accuracy: 0.1950 - val_loss: 1.1891 - val_accuracy: 0.2200
# Epoch 925/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2026 - accuracy: 0.1950 - val_loss: 1.1750 - val_accuracy: 0.2200
# Epoch 926/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1997 - accuracy: 0.1950 - val_loss: 1.1896 - val_accuracy: 0.2200
# Epoch 927/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2006 - accuracy: 0.1950 - val_loss: 1.1958 - val_accuracy: 0.2200
# Epoch 928/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2005 - accuracy: 0.1950 - val_loss: 1.1725 - val_accuracy: 0.2200
# Epoch 929/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2053 - accuracy: 0.1950 - val_loss: 1.1690 - val_accuracy: 0.2200
# Epoch 930/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2046 - accuracy: 0.1950 - val_loss: 1.1942 - val_accuracy: 0.2200
# Epoch 931/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2050 - accuracy: 0.1950 - val_loss: 1.1808 - val_accuracy: 0.2200
# Epoch 932/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1992 - accuracy: 0.1950 - val_loss: 1.1691 - val_accuracy: 0.2200
# Epoch 933/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2004 - accuracy: 0.1950 - val_loss: 1.1681 - val_accuracy: 0.2200
# Epoch 934/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1978 - accuracy: 0.1950 - val_loss: 1.1841 - val_accuracy: 0.2200
# Epoch 935/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2016 - accuracy: 0.1950 - val_loss: 1.1746 - val_accuracy: 0.2200
# Epoch 936/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1987 - accuracy: 0.1950 - val_loss: 1.1625 - val_accuracy: 0.2200
# Epoch 937/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2008 - accuracy: 0.1950 - val_loss: 1.1683 - val_accuracy: 0.2200
# Epoch 938/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2001 - accuracy: 0.1950 - val_loss: 1.1734 - val_accuracy: 0.2200
# Epoch 939/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2014 - accuracy: 0.1950 - val_loss: 1.1656 - val_accuracy: 0.2200
# Epoch 940/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1980 - accuracy: 0.1950 - val_loss: 1.1773 - val_accuracy: 0.2200
# Epoch 941/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1994 - accuracy: 0.1950 - val_loss: 1.1751 - val_accuracy: 0.2200
# Epoch 942/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1983 - accuracy: 0.1950 - val_loss: 1.1675 - val_accuracy: 0.2200
# Epoch 943/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1994 - accuracy: 0.1950 - val_loss: 1.1733 - val_accuracy: 0.2200
# Epoch 944/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2030 - accuracy: 0.1950 - val_loss: 1.1833 - val_accuracy: 0.2200
# Epoch 945/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2007 - accuracy: 0.1950 - val_loss: 1.1966 - val_accuracy: 0.2200
# Epoch 946/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2047 - accuracy: 0.1950 - val_loss: 1.1723 - val_accuracy: 0.2200
# Epoch 947/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2013 - accuracy: 0.1950 - val_loss: 1.1794 - val_accuracy: 0.2200
# Epoch 948/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1978 - accuracy: 0.1950 - val_loss: 1.2011 - val_accuracy: 0.2200
# Epoch 949/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2032 - accuracy: 0.1950 - val_loss: 1.1768 - val_accuracy: 0.2200
# Epoch 950/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2009 - accuracy: 0.1950 - val_loss: 1.1736 - val_accuracy: 0.2200
# Epoch 951/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2044 - accuracy: 0.1950 - val_loss: 1.1977 - val_accuracy: 0.2200
# Epoch 952/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2020 - accuracy: 0.1950 - val_loss: 1.2018 - val_accuracy: 0.2200
# Epoch 953/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1999 - accuracy: 0.1950 - val_loss: 1.1858 - val_accuracy: 0.2200
# Epoch 954/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2029 - accuracy: 0.1950 - val_loss: 1.1963 - val_accuracy: 0.2200
# Epoch 955/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1985 - accuracy: 0.1950 - val_loss: 1.2218 - val_accuracy: 0.2200
# Epoch 956/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2035 - accuracy: 0.1950 - val_loss: 1.1902 - val_accuracy: 0.2200
# Epoch 957/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2010 - accuracy: 0.1950 - val_loss: 1.1843 - val_accuracy: 0.2200
# Epoch 958/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2047 - accuracy: 0.1950 - val_loss: 1.2065 - val_accuracy: 0.2200
# Epoch 959/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2011 - accuracy: 0.1950 - val_loss: 1.2120 - val_accuracy: 0.2200
# Epoch 960/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2035 - accuracy: 0.1950 - val_loss: 1.1807 - val_accuracy: 0.2200
# Epoch 961/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2050 - accuracy: 0.1950 - val_loss: 1.1836 - val_accuracy: 0.2200
# Epoch 962/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2022 - accuracy: 0.1950 - val_loss: 1.2061 - val_accuracy: 0.2200
# Epoch 963/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2021 - accuracy: 0.1950 - val_loss: 1.1710 - val_accuracy: 0.2200
# Epoch 964/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2001 - accuracy: 0.1950 - val_loss: 1.1680 - val_accuracy: 0.2200
# Epoch 965/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2032 - accuracy: 0.1950 - val_loss: 1.1820 - val_accuracy: 0.2200
# Epoch 966/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1982 - accuracy: 0.1950 - val_loss: 1.1816 - val_accuracy: 0.2200
# Epoch 967/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1991 - accuracy: 0.1950 - val_loss: 1.1792 - val_accuracy: 0.2200
# Epoch 968/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1999 - accuracy: 0.1950 - val_loss: 1.1768 - val_accuracy: 0.2200
# Epoch 969/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2019 - accuracy: 0.1950 - val_loss: 1.1916 - val_accuracy: 0.2200
# Epoch 970/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1980 - accuracy: 0.1950 - val_loss: 1.1822 - val_accuracy: 0.2200
# Epoch 971/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1974 - accuracy: 0.1950 - val_loss: 1.1825 - val_accuracy: 0.2200
# Epoch 972/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1972 - accuracy: 0.1950 - val_loss: 1.1913 - val_accuracy: 0.2200
# Epoch 973/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1994 - accuracy: 0.1950 - val_loss: 1.1906 - val_accuracy: 0.2200
# Epoch 974/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1970 - accuracy: 0.1950 - val_loss: 1.1813 - val_accuracy: 0.2200
# Epoch 975/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1996 - accuracy: 0.1950 - val_loss: 1.1882 - val_accuracy: 0.2200
# Epoch 976/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1975 - accuracy: 0.1950 - val_loss: 1.1937 - val_accuracy: 0.2200
# Epoch 977/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1972 - accuracy: 0.1950 - val_loss: 1.1857 - val_accuracy: 0.2200
# Epoch 978/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1979 - accuracy: 0.1950 - val_loss: 1.1856 - val_accuracy: 0.2200
# Epoch 979/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1974 - accuracy: 0.1950 - val_loss: 1.2004 - val_accuracy: 0.2200
# Epoch 980/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1981 - accuracy: 0.1950 - val_loss: 1.2010 - val_accuracy: 0.2200
# Epoch 981/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1992 - accuracy: 0.1950 - val_loss: 1.1857 - val_accuracy: 0.2200
# Epoch 982/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2026 - accuracy: 0.1950 - val_loss: 1.1822 - val_accuracy: 0.2200
# Epoch 983/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1997 - accuracy: 0.1950 - val_loss: 1.2077 - val_accuracy: 0.2200
# Epoch 984/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2011 - accuracy: 0.1950 - val_loss: 1.1923 - val_accuracy: 0.2200
# Epoch 985/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1962 - accuracy: 0.1950 - val_loss: 1.1805 - val_accuracy: 0.2200
# Epoch 986/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1989 - accuracy: 0.1950 - val_loss: 1.1816 - val_accuracy: 0.2200
# Epoch 987/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1992 - accuracy: 0.1950 - val_loss: 1.1871 - val_accuracy: 0.2200
# Epoch 988/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1974 - accuracy: 0.1950 - val_loss: 1.1749 - val_accuracy: 0.2200
# Epoch 989/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1973 - accuracy: 0.1950 - val_loss: 1.1790 - val_accuracy: 0.2200
# Epoch 990/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1979 - accuracy: 0.1950 - val_loss: 1.1806 - val_accuracy: 0.2200
# Epoch 991/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1961 - accuracy: 0.1950 - val_loss: 1.1721 - val_accuracy: 0.2200
# Epoch 992/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1985 - accuracy: 0.1950 - val_loss: 1.1745 - val_accuracy: 0.2200
# Epoch 993/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1980 - accuracy: 0.1950 - val_loss: 1.1854 - val_accuracy: 0.2200
# Epoch 994/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1980 - accuracy: 0.1950 - val_loss: 1.1754 - val_accuracy: 0.2200
# Epoch 995/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1964 - accuracy: 0.1950 - val_loss: 1.1764 - val_accuracy: 0.2200
# Epoch 996/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1967 - accuracy: 0.1950 - val_loss: 1.1774 - val_accuracy: 0.2200
# Epoch 997/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1981 - accuracy: 0.1950 - val_loss: 1.1835 - val_accuracy: 0.2200
# Epoch 998/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1976 - accuracy: 0.1950 - val_loss: 1.1962 - val_accuracy: 0.2200
# Epoch 999/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1976 - accuracy: 0.1950 - val_loss: 1.1853 - val_accuracy: 0.2200
# Epoch 1000/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1976 - accuracy: 0.1950 - val_loss: 1.1865 - val_accuracy: 0.2200

# %%
# 学習経過の可視化(大きさ)

val_loss_array = []
for i in range(len(size_history_array)):
    val_loss_array.append(size_history_array[i].history['val_loss'])
plt.figure(figsize=(10,6))
nb_epoch = len(val_loss_array[i])
for i in range(len(val_loss_array)):
    plt.plot(range(nb_epoch), val_loss_array[i], marker='.', label='val_loss%d'%(i+1))
plt.legend(loc='best', fontsize=10)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('val_loss')
plt.show()

# %%
# モデルの評価(大きさ)
size_loss_array = []
for i in range(len(size_model_array)):
    size_score = size_model_array[i].evaluate(size_x_test_array[i], size_y_test_array[i], verbose=1)
    size_loss = size_score[0]
    size_loss_array.append(size_loss)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2807 - accuracy: 0.1800
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2130 - accuracy: 0.2000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3281 - accuracy: 0.1200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5286 - accuracy: 0.1400
# 2/2 [==============================] - 0s 1ms/step - loss: 0.6333 - accuracy: 0.2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3036 - accuracy: 0.2600
# 2/2 [==============================] - 0s 1ms/step - loss: 0.4959 - accuracy: 0.2600
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2868 - accuracy: 0.2600
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1870 - accuracy: 0.2400
# 2/2 [==============================] - 0s 1ms/step - loss: 1.1865 - accuracy: 0.2200

# %%
stdev = np.std(np.array(size_loss_array))
mean = np.mean(np.array(size_loss_array))

print(stdev)
print(mean)
# Out:
# 0.28300039576383756
# 0.44435653984546664
